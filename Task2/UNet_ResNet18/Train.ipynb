# %%
# !pip install git+https://github.com/innat/medic-ai.git -q
# !pip install scikit-learn nibabel -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for medicai (pyproject.toml) ... done

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import json
import math
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split

import keras
import torch

from medicai.models import UNet,AttentionUNet
from medicai.losses import BinaryDiceCELoss
from medicai.metrics import BinaryDiceMetric
from medicai.transforms import (
    Compose,
    ScaleIntensityRange,
    CropForeground,
    RandCropByPosNegLabel,
    RandFlip,
    RandRotate90,
    RandShiftIntensity,
)

print(f"Backend : {keras.config.backend()}")
print(f"Keras   : {keras.version()}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
    print(f"VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# 2026-03-23 07:06:32.677864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774249592.892580      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774249592.955429      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774249593.493148      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774249593.493186      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774249593.493189      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774249593.493191      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Backend : torch
# Keras   : 3.10.0
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
CT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/gsoc-coca-segment/data_totalseg/inputs")
GT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/coca-gt/kaggle/working/gsoc-coca-gt")
OUT_DIR = Path("/kaggle/working/heart_seg_output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
CROP_SHAPE    = (128, 128, 128)
HU_MIN        = -175
HU_MAX        = 400
BATCH_SIZE    = 2
NUM_SAMPLES   = 1
EPOCHS        = 200
WARMUP_EPOCHS = 10
LEARNING_RATE = 3e-4
MIN_LR        = 1e-6
WEIGHT_DECAY  = 5e-4
VAL_SPLIT     = 0.15
SEED          = 50

# %%
import medicai
print(medicai.models.list_models())
# Out:
#                      Model Registry Catalog
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Segmentor        ┃ Backbone Family ┃ Variants                 ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ • attention_unet │ convnext        │ • convnext_base          │
# │ • deeplabv3plus  │                 │ • convnext_large         │
# │ • unet           │                 │ • convnext_small         │
# │ • unet_plus_plus │                 │ • convnext_tiny          │
# │ • upernet        │                 │ • convnext_v2_atto       │
# │                  │                 │ • convnext_v2_base       │
# │                  │                 │ • convnext_v2_femto      │
# │                  │                 │ • convnext_v2_huge       │
# │                  │                 │ • convnext_v2_large      │
# │                  │                 │ • convnext_v2_nano       │
# │                  │                 │ • convnext_v2_pico       │
# │                  │                 │ • convnext_v2_small      │
# │                  │                 │ • convnext_v2_tiny       │
# │                  │                 │ • convnext_xlarge        │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ densenet        │ • densenet121            │
# │ • deeplabv3plus  │                 │ • densenet169            │
# │ • trans_unet     │                 │ • densenet201            │
# │ • unet           │                 │ • densenet264            │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ efficientnet    │ • efficientnet_b0        │
# │ • deeplabv3plus  │                 │ • efficientnet_b1        │
# │ • trans_unet     │                 │ • efficientnet_b2        │
# │ • unet           │                 │ • efficientnet_b3        │
# │ • unet_plus_plus │                 │ • efficientnet_b4        │
# │ • upernet        │                 │ • efficientnet_b5        │
# │                  │                 │ • efficientnet_b6        │
# │                  │                 │ • efficientnet_b7        │
# │                  │                 │ • efficientnet_b8        │
# │                  │                 │ • efficientnet_l2        │
# │                  │                 │ • efficientnet_v2_b0     │
# │                  │                 │ • efficientnet_v2_b1     │
# │                  │                 │ • efficientnet_v2_b2     │
# │                  │                 │ • efficientnet_v2_b3     │
# │                  │                 │ • efficientnet_v2_l      │
# │                  │                 │ • efficientnet_v2_m      │
# │                  │                 │ • efficientnet_v2_s      │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • segformer      │ mit             │ • mit_b0                 │
# │ • upernet        │                 │ • mit_b1                 │
# │                  │                 │ • mit_b2                 │
# │                  │                 │ • mit_b3                 │
# │                  │                 │ • mit_b4                 │
# │                  │                 │ • mit_b5                 │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ resnet          │ • resnet101              │
# │ • deeplabv3plus  │                 │ • resnet101_v2           │
# │ • trans_unet     │                 │ • resnet152              │
# │ • unet           │                 │ • resnet152_v2           │
# │ • unet_plus_plus │                 │ • resnet18               │
# │ • upernet        │                 │ • resnet200_vd           │
# │                  │                 │ • resnet34               │
# │                  │                 │ • resnet50               │
# │                  │                 │ • resnet50_v2            │
# │                  │                 │ • resnet50_vd            │
# │                  │                 │ • resnext101             │
# │                  │                 │ • resnext50              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ senet           │ • seresnet101            │
# │ • deeplabv3plus  │                 │ • seresnet101_v2         │
# │ • trans_unet     │                 │ • seresnet152            │
# │ • unet           │                 │ • seresnet152_v2         │
# │ • unet_plus_plus │                 │ • seresnet18             │
# │ • upernet        │                 │ • seresnet200_vd         │
# │                  │                 │ • seresnet34             │
# │                  │                 │ • seresnet50             │
# │                  │                 │ • seresnet50_v2          │
# │                  │                 │ • seresnet50_vd          │
# │                  │                 │ • seresnext101           │
# │                  │                 │ • seresnext50            │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • swin_unetr     │ swin            │ • swin_base              │
# │ • upernet        │                 │ • swin_base_v2           │
# │                  │                 │ • swin_small             │
# │                  │                 │ • swin_small_v2          │
# │                  │                 │ • swin_tiny              │
# │                  │                 │ • swin_tiny_v2           │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr_plusplus │ unetr_plusplus  │ • unetr_plusplus_encoder │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr          │ vit             │ • vit_base               │
# │                  │                 │ • vit_huge               │
# │                  │                 │ • vit_large              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ xception        │ • xception               │
# │ • trans_unet     │                 │                          │
# │ • unet           │                 │                          │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# └──────────────────┴─────────────────┴──────────────────────────┘

# %%
def discover_pairs(ct_dir, gt_dir):
    pairs = []
    for ct_path in sorted(list(ct_dir.glob("*_img.nii.gz")) + list(ct_dir.glob("*_img.nii"))):
        scan_id = ct_path.name.replace("_img.nii.gz", "").replace("_img.nii", "")
        for ext in (".nii.gz", ".nii"):
            gt_path = gt_dir / scan_id / f"{scan_id}_binary{ext}"
            if gt_path.exists():
                pairs.append({"scan_id": scan_id, "image": str(ct_path), "label": str(gt_path)})
                break
    return pairs

pairs = discover_pairs(CT_DIR, GT_DIR)
print(f"Found {len(pairs)} pairs")

train_pairs, val_pairs = train_test_split(pairs, test_size=VAL_SPLIT, random_state=SEED)
print(f"Train={len(train_pairs)}  Val={len(val_pairs)}")
# Out:
# Found 47 pairs
# Train=39  Val=8

# %%
def load_pair(image_path, label_path):
    image_nii = nib.load(image_path)
    label_nii = nib.load(label_path)
    image  = image_nii.get_fdata().astype(np.float32)
    label  = label_nii.get_fdata().astype(np.float32)
    affine = np.array(image_nii.affine, dtype=np.float32)
    image  = np.transpose(image, (2, 1, 0))
    label  = np.transpose(label, (2, 1, 0))
    affine[:, :3] = affine[:, [2, 1, 0]]
    label = (label > 0.5).astype(np.float32)
    image = image[..., np.newaxis]
    label = label[..., np.newaxis]
    return {"image": image, "label": label}, {"affine": affine}

_d, _ = load_pair(pairs[0]["image"], pairs[0]["label"])
print(f"image: {_d['image'].shape}   label: {_d['label'].shape}")
print(f"Label fraction: {_d['label'].mean():.4f}")
# Out:
# image: (219, 309, 309, 1)   label: (219, 309, 309, 1)
# Label fraction: 0.1100

# %%
train_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=2, neg=1, num_samples=NUM_SAMPLES,
        image_reference_key="image", image_threshold=0,
    ),
    RandFlip(keys=["image", "label"], spatial_axis=[0], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[1], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[2], prob=0.5),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(0, 1)),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(1, 2)),
    RandShiftIntensity(keys=["image"], offsets=0.2, prob=0.8),
])

val_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=1, neg=0, num_samples=1,
        image_reference_key="image", image_threshold=0,
    ),
])

print("Transforms ready")
# Out:
# Transforms ready

# %%
class HeartSegDataset(keras.utils.PyDataset):
    def __init__(self, pairs, transform, batch_size, num_samples=1, shuffle=False, **kw):
        super().__init__(**kw)
        self.pairs      = pairs
        self.transform  = transform
        self.batch_size = batch_size
        self.num_samples = num_samples
        self.shuffle    = shuffle
        self._build_index()

    def _build_index(self):
        self._index = [(vi, ci) for vi in range(len(self.pairs))
                                for ci in range(self.num_samples)]
        if self.shuffle:
            np.random.shuffle(self._index)

    def __len__(self):
        return math.ceil(len(self._index) / self.batch_size)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self._index)

    def __getitem__(self, idx):
        batch = self._index[idx * self.batch_size : (idx + 1) * self.batch_size]
        images, labels = [], []
        for vi, ci in batch:
            p = self.pairs[vi]
            data, meta = load_pair(p["image"], p["label"])
            out = self.transform(data, meta)
            img, lbl = out["image"], out["label"]
            if isinstance(img, list):
                ci = min(ci, len(img) - 1)
                img, lbl = img[ci], lbl[ci]
            if hasattr(img, "numpy"): img = img.numpy()
            if hasattr(lbl, "numpy"): lbl = lbl.numpy()
            images.append(img)
            labels.append(lbl)
        return np.stack(images), np.stack(labels)


train_ds = HeartSegDataset(
    train_pairs, train_transform,
    batch_size=BATCH_SIZE, num_samples=NUM_SAMPLES, shuffle=True,
)
val_ds = HeartSegDataset(
    val_pairs, val_transform,
    batch_size=1, num_samples=1, shuffle=False,
)

_x, _y = train_ds[0]
print(f"Batch: {_x.shape}  [{_x.min():.2f}, {_x.max():.2f}]")
print(f"Label: {_y.shape}  heart voxels={int(_y.sum())}")
print(f"Steps/epoch: {len(train_ds)} train, {len(val_ds)} val")
# Out:
# I0000 00:00:1774249612.622083      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Batch: (2, 128, 128, 128, 1)  [0.00, 1.12]
# Label: (2, 128, 128, 128, 1)  heart voxels=1536178
# Steps/epoch: 20 train, 8 val

# %%
model = UNet(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='resnet18',
    classifier_activation=None,
)

print(f"Parameters: {model.count_params():,}")
model.summary(line_length=100)
# Out:
# Parameters: 42,622,289
# Model: "UNet3D"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 128, 128, 128,   │              0 │ -                       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_pad (ZeroPadding3D)   │ (None, 134, 134, 134,   │              0 │ input_layer[0][0]       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_conv (Conv3D)         │ (None, 64, 64, 64, 64)  │         21,952 │ conv1_pad[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_bn                    │ (None, 64, 64, 64, 64)  │            256 │ conv1_conv[0][0]        │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_relu (Activation)     │ (None, 64, 64, 64, 64)  │              0 │ conv1_bn[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool1_pad (ZeroPadding3D)   │ (None, 66, 66, 66, 64)  │              0 │ conv1_relu[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool1_pool (MaxPooling3D)   │ (None, 32, 32, 32, 64)  │              0 │ pool1_pad[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ pool1_pool[0][0]        │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block0_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_relu        │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_2_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_2_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_add (Add)     │ (None, 32, 32, 32, 64)  │              0 │ pool1_pool[0][0],       │
# │                             │                         │                │ stack0_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_out           │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_relu        │ (None, 32, 32, 32, 64)  │              0 │ stack0_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_2_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_2_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_add (Add)     │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_out[0][0… │
# │                             │                         │                │ stack0_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_out           │ (None, 32, 32, 32, 64)  │              0 │ stack0_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_pad         │ (None, 34, 34, 34, 64)  │              0 │ stack0_block1_out[0][0] │
# │ (ZeroPadding3D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_conv        │ (None, 16, 16, 16, 128) │        221,184 │ stack1_block0_1_pad[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_bn          │ (None, 16, 16, 16, 128) │            512 │ stack1_block0_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_relu        │ (None, 16, 16, 16, 128) │              0 │ stack1_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_0_conv        │ (None, 16, 16, 16, 128) │          8,192 │ stack0_block1_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_2_conv        │ (None, 16, 16, 16, 128) │        442,368 │ stack1_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_0_bn          │ (None, 16, 16, 16, 128) │            512 │ stack1_block0_0_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_2_bn          │ (None, 16, 16, 16, 128) │            512 │ stack1_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_add (Add)     │ (None, 16, 16, 16, 128) │              0 │ stack1_block0_0_bn[0][… │
# │                             │                         │                │ stack1_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_out           │ (None, 16, 16, 16, 128) │              0 │ stack1_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_1_conv        │ (None, 16, 16, 16, 128) │        442,368 │ stack1_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_1_bn          │ (None, 16, 16, 16, 128) │            512 │ stack1_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_1_relu        │ (None, 16, 16, 16, 128) │              0 │ stack1_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_2_conv        │ (None, 16, 16, 16, 128) │        442,368 │ stack1_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_2_bn          │ (None, 16, 16, 16, 128) │            512 │ stack1_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_add (Add)     │ (None, 16, 16, 16, 128) │              0 │ stack1_block0_out[0][0… │
# │                             │                         │                │ stack1_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block1_out           │ (None, 16, 16, 16, 128) │              0 │ stack1_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_1_pad         │ (None, 18, 18, 18, 128) │              0 │ stack1_block1_out[0][0] │
# │ (ZeroPadding3D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_1_conv        │ (None, 8, 8, 8, 256)    │        884,736 │ stack2_block0_1_pad[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_1_bn          │ (None, 8, 8, 8, 256)    │          1,024 │ stack2_block0_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_1_relu        │ (None, 8, 8, 8, 256)    │              0 │ stack2_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_0_conv        │ (None, 8, 8, 8, 256)    │         32,768 │ stack1_block1_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_2_conv        │ (None, 8, 8, 8, 256)    │      1,769,472 │ stack2_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_0_bn          │ (None, 8, 8, 8, 256)    │          1,024 │ stack2_block0_0_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_2_bn          │ (None, 8, 8, 8, 256)    │          1,024 │ stack2_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_add (Add)     │ (None, 8, 8, 8, 256)    │              0 │ stack2_block0_0_bn[0][… │
# │                             │                         │                │ stack2_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block0_out           │ (None, 8, 8, 8, 256)    │              0 │ stack2_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_1_conv        │ (None, 8, 8, 8, 256)    │      1,769,472 │ stack2_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_1_bn          │ (None, 8, 8, 8, 256)    │          1,024 │ stack2_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_1_relu        │ (None, 8, 8, 8, 256)    │              0 │ stack2_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_2_conv        │ (None, 8, 8, 8, 256)    │      1,769,472 │ stack2_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_2_bn          │ (None, 8, 8, 8, 256)    │          1,024 │ stack2_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_add (Add)     │ (None, 8, 8, 8, 256)    │              0 │ stack2_block0_out[0][0… │
# │                             │                         │                │ stack2_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack2_block1_out           │ (None, 8, 8, 8, 256)    │              0 │ stack2_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_1_pad         │ (None, 10, 10, 10, 256) │              0 │ stack2_block1_out[0][0] │
# │ (ZeroPadding3D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_1_conv        │ (None, 4, 4, 4, 512)    │      3,538,944 │ stack3_block0_1_pad[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_1_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block0_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_1_relu        │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_0_conv        │ (None, 4, 4, 4, 512)    │        131,072 │ stack2_block1_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_2_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_0_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block0_0_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_2_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_add (Add)     │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_0_bn[0][… │
# │                             │                         │                │ stack3_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_out           │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_relu        │ (None, 4, 4, 4, 512)    │              0 │ stack3_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_2_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_2_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_add (Add)     │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_out[0][0… │
# │                             │                         │                │ stack3_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_out           │ (None, 4, 4, 4, 512)    │              0 │ stack3_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_upsampling_… │ (None, 8, 8, 8, 512)    │              0 │ stack3_block1_out[0][0] │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_concat       │ (None, 8, 8, 8, 768)    │              0 │ decoder_stage5_upsampl… │
# │ (Concatenate)               │                         │                │ stack2_block1_out[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_conv… │ (None, 8, 8, 8, 256)    │      5,308,416 │ decoder_stage5_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_conv… │ (None, 8, 8, 8, 256)    │      1,769,472 │ decoder_stage5_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_upsampling_… │ (None, 16, 16, 16, 256) │              0 │ decoder_stage5_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_concat       │ (None, 16, 16, 16, 384) │              0 │ decoder_stage4_upsampl… │
# │ (Concatenate)               │                         │                │ stack1_block1_out[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_conv… │ (None, 16, 16, 16, 128) │      1,327,104 │ decoder_stage4_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_conv… │ (None, 16, 16, 16, 128) │        442,368 │ decoder_stage4_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_upsampling_… │ (None, 32, 32, 32, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_concat       │ (None, 32, 32, 32, 192) │              0 │ decoder_stage3_upsampl… │
# │ (Concatenate)               │                         │                │ stack0_block1_out[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_conv… │ (None, 32, 32, 32, 64)  │        331,776 │ decoder_stage3_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_conv… │ (None, 32, 32, 32, 64)  │        110,592 │ decoder_stage3_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_upsampling_… │ (None, 64, 64, 64, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_concat       │ (None, 64, 64, 64, 128) │              0 │ decoder_stage2_upsampl… │
# │ (Concatenate)               │                         │                │ conv1_relu[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_conv… │ (None, 64, 64, 64, 32)  │        110,592 │ decoder_stage2_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_conv… │ (None, 64, 64, 64, 32)  │         27,648 │ decoder_stage2_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_upsampling_… │ (None, 128, 128, 128,   │              0 │ decoder_stage2_conv_2_… │
# │ (UpSampling3D)              │ 32)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_conv… │ (None, 128, 128, 128,   │         13,824 │ decoder_stage1_upsampl… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_1_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_1_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_conv… │ (None, 128, 128, 128,   │          6,912 │ decoder_stage1_conv_1_… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_2_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_2_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3d (Conv3D)             │ (None, 128, 128, 128,   │             17 │ decoder_stage1_conv_2_… │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ predictions (Activation)    │ (None, 128, 128, 128,   │              0 │ conv3d[0][0]            │
# │                             │ 1)                      │                │                         │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 42,622,289 (162.59 MB)
#  Trainable params: 42,610,705 (162.55 MB)
#  Non-trainable params: 11,584 (45.25 KB)

# %%
def warmup_cosine_lr(epoch, current_lr):
    if epoch < WARMUP_EPOCHS:
        return MIN_LR + (LEARNING_RATE - MIN_LR) * (epoch / WARMUP_EPOCHS)
    progress = (epoch - WARMUP_EPOCHS) / max(EPOCHS - WARMUP_EPOCHS, 1)
    return MIN_LR + 0.5 * (LEARNING_RATE - MIN_LR) * (1 + math.cos(math.pi * progress))

for e in [0, 10, 50, 100, 199]:
    print(f"Epoch {e:>3d}  LR = {warmup_cosine_lr(e, None):.2e}")
# Out:
# Epoch   0  LR = 1.00e-06
# Epoch  10  LR = 3.00e-04
# Epoch  50  LR = 2.68e-04
# Epoch 100  LR = 1.63e-04
# Epoch 199  LR = 1.02e-06

# %%
model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=MIN_LR,
        weight_decay=WEIGHT_DECAY,
    ),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

callbacks = [
    keras.callbacks.LearningRateScheduler(warmup_cosine_lr, verbose=0),
    keras.callbacks.ModelCheckpoint(
        filepath=str(OUT_DIR / "best_model.keras"),
        monitor="val_binary_dice_metric", mode="max",
        save_best_only=True, verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_binary_dice_metric", mode="max",
        patience=50, restore_best_weights=True, verbose=1,
    ),
    keras.callbacks.CSVLogger(str(OUT_DIR / "training_log.csv")),
]

print("Compiled")
# Out:
# Compiled

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

print(f"\nBest val Dice: {max(history.history.get('val_binary_dice_metric', [0])):.4f}")
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 99s 5s/step - binary_dice_score: 0.2428 - loss: 1.3716 - val_binary_dice_score: 0.0476 - val_loss: 1.2392 - learning_rate: 1.0000e-06
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.4631 - loss: 1.2348 - val_binary_dice_score: 0.5618 - val_loss: 1.2547 - learning_rate: 3.0900e-05
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.7446 - loss: 0.9522 - val_binary_dice_score: 0.8310 - val_loss: 0.9809 - learning_rate: 6.0800e-05
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.7979 - loss: 0.7517 - val_binary_dice_score: 0.5125 - val_loss: 1.0986 - learning_rate: 9.0700e-05
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7620 - loss: 0.7974 - val_binary_dice_score: 1.9684e-05 - val_loss: 4.0047 - learning_rate: 1.2060e-04
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7133 - loss: 0.8703 - val_binary_dice_score: 1.7151e-04 - val_loss: 3.4468 - learning_rate: 1.5050e-04
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7846 - loss: 0.7704 - val_binary_dice_score: 0.0011 - val_loss: 1.6248 - learning_rate: 1.8040e-04
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8103 - loss: 0.7038 - val_binary_dice_score: 0.5200 - val_loss: 0.9268 - learning_rate: 2.1030e-04
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7167 - loss: 0.8557 - val_binary_dice_score: 0.7661 - val_loss: 0.8084 - learning_rate: 2.4020e-04
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7440 - loss: 0.8109 - val_binary_dice_score: 9.4935e-04 - val_loss: 2.6317 - learning_rate: 2.7010e-04
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7356 - loss: 0.8782 - val_binary_dice_score: 6.1591e-06 - val_loss: 5.1037 - learning_rate: 3.0000e-04
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8019 - loss: 0.7006 - val_binary_dice_score: 0.8230 - val_loss: 0.6895 - learning_rate: 2.9998e-04
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8469 - loss: 0.5868 - val_binary_dice_score: 0.8168 - val_loss: 0.6273 - learning_rate: 2.9992e-04
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7711 - loss: 0.7549 - val_binary_dice_score: 0.8630 - val_loss: 0.5047 - learning_rate: 2.9982e-04
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8114 - loss: 0.6692 - val_binary_dice_score: 0.8304 - val_loss: 0.9224 - learning_rate: 2.9967e-04
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7916 - loss: 0.6725 - val_binary_dice_score: 0.8085 - val_loss: 0.7667 - learning_rate: 2.9949e-04
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8291 - loss: 0.6537 - val_binary_dice_score: 0.5566 - val_loss: 1.1908 - learning_rate: 2.9926e-04
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7864 - loss: 0.6745 - val_binary_dice_score: 0.0053 - val_loss: 1.9459 - learning_rate: 2.9900e-04
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7812 - loss: 0.7243 - val_binary_dice_score: 0.8893 - val_loss: 0.4195 - learning_rate: 2.9869e-04
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8288 - loss: 0.6116 - val_binary_dice_score: 1.3058e-13 - val_loss: 2.5232 - learning_rate: 2.9835e-04
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8151 - loss: 0.6000 - val_binary_dice_score: 0.5407 - val_loss: 0.9219 - learning_rate: 2.9796e-04
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7078 - loss: 0.8206 - val_binary_dice_score: 0.7681 - val_loss: 0.7581 - learning_rate: 2.9753e-04
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8273 - loss: 0.5821 - val_binary_dice_score: 0.7951 - val_loss: 0.8223 - learning_rate: 2.9707e-04
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7698 - loss: 0.7200 - val_binary_dice_score: 0.8779 - val_loss: 0.4309 - learning_rate: 2.9656e-04
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8084 - loss: 0.6532 - val_binary_dice_score: 0.7287 - val_loss: 0.7591 - learning_rate: 2.9601e-04
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8136 - loss: 0.6613 - val_binary_dice_score: 1.2172e-13 - val_loss: 2.0187 - learning_rate: 2.9543e-04
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8286 - loss: 0.5707 - val_binary_dice_score: 0.6575 - val_loss: 0.6996 - learning_rate: 2.9480e-04
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8207 - loss: 0.6130 - val_binary_dice_score: 0.9095 - val_loss: 0.3729 - learning_rate: 2.9413e-04
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8379 - loss: 0.5982 - val_binary_dice_score: 0.8793 - val_loss: 0.4813 - learning_rate: 2.9343e-04
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8278 - loss: 0.6163 - val_binary_dice_score: 0.2481 - val_loss: 1.3857 - learning_rate: 2.9268e-04
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8399 - loss: 0.5658 - val_binary_dice_score: 0.8934 - val_loss: 0.4210 - learning_rate: 2.9190e-04
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8207 - loss: 0.6100 - val_binary_dice_score: 0.8033 - val_loss: 0.6092 - learning_rate: 2.9108e-04
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8352 - loss: 0.5714 - val_binary_dice_score: 0.8953 - val_loss: 0.4369 - learning_rate: 2.9022e-04
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7944 - loss: 0.6432 - val_binary_dice_score: 0.5645 - val_loss: 1.4470 - learning_rate: 2.8932e-04
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8226 - loss: 0.5982 - val_binary_dice_score: 0.8131 - val_loss: 0.5832 - learning_rate: 2.8838e-04
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7996 - loss: 0.6428 - val_binary_dice_score: 0.7853 - val_loss: 0.7047 - learning_rate: 2.8741e-04
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8211 - loss: 0.6219 - val_binary_dice_score: 0.0041 - val_loss: 1.7411 - learning_rate: 2.8640e-04
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8123 - loss: 0.6459 - val_binary_dice_score: 0.0198 - val_loss: 1.4616 - learning_rate: 2.8535e-04
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.7882 - loss: 0.6874 - val_binary_dice_score: 0.7432 - val_loss: 0.8118 - learning_rate: 2.8426e-04
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8105 - loss: 0.6701 - val_binary_dice_score: 0.8676 - val_loss: 0.4586 - learning_rate: 2.8314e-04
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8507 - loss: 0.5214 - val_binary_dice_score: 0.7971 - val_loss: 0.9662 - learning_rate: 2.8198e-04
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8087 - loss: 0.6551 - val_binary_dice_score: 0.8805 - val_loss: 0.5223 - learning_rate: 2.8079e-04
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8424 - loss: 0.5794 - val_binary_dice_score: 0.0030 - val_loss: 2.2822 - learning_rate: 2.7956e-04
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8568 - loss: 0.4893 - val_binary_dice_score: 0.8665 - val_loss: 0.5359 - learning_rate: 2.7829e-04
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8320 - loss: 0.5776 - val_binary_dice_score: 0.8686 - val_loss: 0.5245 - learning_rate: 2.7699e-04
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8368 - loss: 0.5922 - val_binary_dice_score: 0.4607 - val_loss: 1.0885 - learning_rate: 2.7566e-04
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8296 - loss: 0.5367 - val_binary_dice_score: 0.8755 - val_loss: 0.4661 - learning_rate: 2.7429e-04
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8536 - loss: 0.5178 - val_binary_dice_score: 0.9181 - val_loss: 0.3294 - learning_rate: 2.7288e-04
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8544 - loss: 0.5043 - val_binary_dice_score: 0.8482 - val_loss: 0.5730 - learning_rate: 2.7145e-04
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7735 - loss: 0.7141 - val_binary_dice_score: 0.8844 - val_loss: 0.4712 - learning_rate: 2.6998e-04
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7990 - loss: 0.6251 - val_binary_dice_score: 0.8840 - val_loss: 0.4754 - learning_rate: 2.6848e-04
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7905 - loss: 0.6651 - val_binary_dice_score: 0.0572 - val_loss: 2.0923 - learning_rate: 2.6694e-04
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8513 - loss: 0.5282 - val_binary_dice_score: 0.9094 - val_loss: 0.3515 - learning_rate: 2.6538e-04
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8068 - loss: 0.6433 - val_binary_dice_score: 0.6539 - val_loss: 1.0116 - learning_rate: 2.6378e-04
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8126 - loss: 0.5880 - val_binary_dice_score: 0.3681 - val_loss: 1.7712 - learning_rate: 2.6215e-04
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8202 - loss: 0.5914 - val_binary_dice_score: 0.0070 - val_loss: 2.6287 - learning_rate: 2.6049e-04
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8040 - loss: 0.6105 - val_binary_dice_score: 0.8041 - val_loss: 0.8379 - learning_rate: 2.5880e-04
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8188 - loss: 0.6116 - val_binary_dice_score: 0.8054 - val_loss: 0.5705 - learning_rate: 2.5708e-04
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8066 - loss: 0.6032 - val_binary_dice_score: 0.4205 - val_loss: 1.4892 - learning_rate: 2.5533e-04
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8110 - loss: 0.5841 - val_binary_dice_score: 0.8848 - val_loss: 0.4272 - learning_rate: 2.5356e-04
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8809 - loss: 0.4319 - val_binary_dice_score: 0.9133 - val_loss: 0.3649 - learning_rate: 2.5175e-04
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7778 - loss: 0.6954 - val_binary_dice_score: 0.8840 - val_loss: 0.4433 - learning_rate: 2.4992e-04
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8454 - loss: 0.5605 - val_binary_dice_score: 0.9068 - val_loss: 0.3718 - learning_rate: 2.4806e-04
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7797 - loss: 0.6553 - val_binary_dice_score: 0.8089 - val_loss: 0.6623 - learning_rate: 2.4618e-04
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8491 - loss: 0.5716 - val_binary_dice_score: 0.9098 - val_loss: 0.3632 - learning_rate: 2.4426e-04
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8066 - loss: 0.6305 - val_binary_dice_score: 0.8804 - val_loss: 0.5175 - learning_rate: 2.4232e-04
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8294 - loss: 0.5581 - val_binary_dice_score: 0.8549 - val_loss: 0.5923 - learning_rate: 2.4036e-04
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8403 - loss: 0.5199 - val_binary_dice_score: 0.2721 - val_loss: 1.6133 - learning_rate: 2.3837e-04
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8271 - loss: 0.5684 - val_binary_dice_score: 0.9198 - val_loss: 0.3277 - learning_rate: 2.3636e-04
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8449 - loss: 0.5891 - val_binary_dice_score: 0.8452 - val_loss: 0.5527 - learning_rate: 2.3433e-04
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8609 - loss: 0.4962 - val_binary_dice_score: 0.5880 - val_loss: 1.0006 - learning_rate: 2.3227e-04
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8188 - loss: 0.5578 - val_binary_dice_score: 0.8228 - val_loss: 0.5275 - learning_rate: 2.3019e-04
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8758 - loss: 0.4479 - val_binary_dice_score: 3.1372e-05 - val_loss: 2.5872 - learning_rate: 2.2809e-04
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7987 - loss: 0.6458 - val_binary_dice_score: 0.8883 - val_loss: 0.4433 - learning_rate: 2.2596e-04
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8168 - loss: 0.5552 - val_binary_dice_score: 0.8873 - val_loss: 0.4245 - learning_rate: 2.2382e-04
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8110 - loss: 0.6382 - val_binary_dice_score: 0.0013 - val_loss: 2.1427 - learning_rate: 2.2165e-04
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7263 - loss: 0.7457 - val_binary_dice_score: 0.8803 - val_loss: 0.4530 - learning_rate: 2.1947e-04
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8627 - loss: 0.5006 - val_binary_dice_score: 0.0290 - val_loss: 2.1071 - learning_rate: 2.1727e-04
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8343 - loss: 0.5457 - val_binary_dice_score: 0.8867 - val_loss: 0.4162 - learning_rate: 2.1505e-04
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8669 - loss: 0.4925 - val_binary_dice_score: 9.4456e-06 - val_loss: 2.8075 - learning_rate: 2.1281e-04
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.7981 - loss: 0.6270 - val_binary_dice_score: 0.8901 - val_loss: 0.4126 - learning_rate: 2.1055e-04
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8486 - loss: 0.5421 - val_binary_dice_score: 0.9035 - val_loss: 0.3461 - learning_rate: 2.0828e-04
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8744 - loss: 0.4265 - val_binary_dice_score: 0.8747 - val_loss: 0.4638 - learning_rate: 2.0599e-04
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.7928 - loss: 0.6316 - val_binary_dice_score: 0.7367 - val_loss: 0.7392 - learning_rate: 2.0369e-04
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8021 - loss: 0.6681 - val_binary_dice_score: 0.8803 - val_loss: 0.3927 - learning_rate: 2.0137e-04
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8705 - loss: 0.4483 - val_binary_dice_score: 0.8961 - val_loss: 0.3910 - learning_rate: 1.9904e-04
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8335 - loss: 0.5015 - val_binary_dice_score: 0.0051 - val_loss: 1.9605 - learning_rate: 1.9670e-04
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8199 - loss: 0.5942 - val_binary_dice_score: 0.8983 - val_loss: 0.4059 - learning_rate: 1.9434e-04
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7998 - loss: 0.6793 - val_binary_dice_score: 0.9061 - val_loss: 0.3977 - learning_rate: 1.9197e-04
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8776 - loss: 0.4347 - val_binary_dice_score: 0.0159 - val_loss: 1.8166 - learning_rate: 1.8959e-04
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8424 - loss: 0.5135 - val_binary_dice_score: 0.8981 - val_loss: 0.3867 - learning_rate: 1.8720e-04
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8656 - loss: 0.4482 - val_binary_dice_score: 0.9335 - val_loss: 0.2926 - learning_rate: 1.8480e-04
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7870 - loss: 0.6729 - val_binary_dice_score: 0.5793 - val_loss: 1.4038 - learning_rate: 1.8239e-04
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8441 - loss: 0.5199 - val_binary_dice_score: 0.4796 - val_loss: 1.2592 - learning_rate: 1.7997e-04
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8130 - loss: 0.5573 - val_binary_dice_score: 0.8692 - val_loss: 0.5833 - learning_rate: 1.7754e-04
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8492 - loss: 0.5248 - val_binary_dice_score: 0.8966 - val_loss: 0.4040 - learning_rate: 1.7511e-04
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8421 - loss: 0.4867 - val_binary_dice_score: 0.5463 - val_loss: 1.2059 - learning_rate: 1.7267e-04
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8389 - loss: 0.5512 - val_binary_dice_score: 0.8906 - val_loss: 0.3845 - learning_rate: 1.7022e-04
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8754 - loss: 0.4676 - val_binary_dice_score: 0.8829 - val_loss: 0.4118 - learning_rate: 1.6776e-04
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8752 - loss: 0.4718 - val_binary_dice_score: 0.8830 - val_loss: 0.4273 - learning_rate: 1.6531e-04
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8700 - loss: 0.4578 - val_binary_dice_score: 0.7945 - val_loss: 0.9163 - learning_rate: 1.6285e-04
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8494 - loss: 0.4780 - val_binary_dice_score: 0.1800 - val_loss: 1.5984 - learning_rate: 1.6038e-04
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8790 - loss: 0.4705 - val_binary_dice_score: 0.8546 - val_loss: 0.5594 - learning_rate: 1.5791e-04
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7872 - loss: 0.7211 - val_binary_dice_score: 0.9004 - val_loss: 0.4098 - learning_rate: 1.5544e-04
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8873 - loss: 0.4460 - val_binary_dice_score: 0.8997 - val_loss: 0.3823 - learning_rate: 1.5297e-04
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.7619 - loss: 0.7313 - val_binary_dice_score: 0.9307 - val_loss: 0.2685 - learning_rate: 1.5050e-04
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8831 - loss: 0.4234 - val_binary_dice_score: 0.5348 - val_loss: 1.4433 - learning_rate: 1.4803e-04
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8432 - loss: 0.4866 - val_binary_dice_score: 0.9067 - val_loss: 0.3525 - learning_rate: 1.4556e-04
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8611 - loss: 0.4590 - val_binary_dice_score: 0.7698 - val_loss: 0.6465 - learning_rate: 1.4309e-04
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8110 - loss: 0.6387 - val_binary_dice_score: 0.9433 - val_loss: 0.2792 - learning_rate: 1.4062e-04
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8491 - loss: 0.5119 - val_binary_dice_score: 0.6392 - val_loss: 1.0761 - learning_rate: 1.3815e-04
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8750 - loss: 0.4372 - val_binary_dice_score: 0.9261 - val_loss: 0.2940 - learning_rate: 1.3569e-04
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8790 - loss: 0.4220 - val_binary_dice_score: 0.2580 - val_loss: 1.7995 - learning_rate: 1.3324e-04
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8644 - loss: 0.4697 - val_binary_dice_score: 0.8128 - val_loss: 0.7977 - learning_rate: 1.3078e-04
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8598 - loss: 0.4565 - val_binary_dice_score: 0.9278 - val_loss: 0.2993 - learning_rate: 1.2833e-04
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8555 - loss: 0.4482 - val_binary_dice_score: 0.8816 - val_loss: 0.4242 - learning_rate: 1.2589e-04
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8711 - loss: 0.4808 - val_binary_dice_score: 0.8902 - val_loss: 0.4180 - learning_rate: 1.2346e-04
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8819 - loss: 0.5167 - val_binary_dice_score: 0.2646 - val_loss: 1.4900 - learning_rate: 1.2103e-04
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8603 - loss: 0.4683 - val_binary_dice_score: 0.8167 - val_loss: 0.7499 - learning_rate: 1.1861e-04
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8832 - loss: 0.4371 - val_binary_dice_score: 0.9186 - val_loss: 0.3676 - learning_rate: 1.1620e-04
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8343 - loss: 0.5393 - val_binary_dice_score: 0.8652 - val_loss: 0.4734 - learning_rate: 1.1380e-04
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8637 - loss: 0.4707 - val_binary_dice_score: 0.9351 - val_loss: 0.2767 - learning_rate: 1.1141e-04
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8133 - loss: 0.6208 - val_binary_dice_score: 0.8952 - val_loss: 0.4499 - learning_rate: 1.0903e-04
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8747 - loss: 0.4386 - val_binary_dice_score: 0.9010 - val_loss: 0.4146 - learning_rate: 1.0666e-04
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8648 - loss: 0.4518 - val_binary_dice_score: 0.7951 - val_loss: 0.7859 - learning_rate: 1.0430e-04
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8419 - loss: 0.5285 - val_binary_dice_score: 0.8741 - val_loss: 0.4427 - learning_rate: 1.0196e-04
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8630 - loss: 0.4771 - val_binary_dice_score: 0.9267 - val_loss: 0.2933 - learning_rate: 9.9626e-05
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8840 - loss: 0.4299 - val_binary_dice_score: 0.8555 - val_loss: 0.5517 - learning_rate: 9.7309e-05
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8187 - loss: 0.5768 - val_binary_dice_score: 0.9051 - val_loss: 0.3852 - learning_rate: 9.5006e-05
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8378 - loss: 0.5529 - val_binary_dice_score: 0.9014 - val_loss: 0.3820 - learning_rate: 9.2718e-05
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9010 - loss: 0.3720 - val_binary_dice_score: 0.9399 - val_loss: 0.2638 - learning_rate: 9.0447e-05
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8616 - loss: 0.4674 - val_binary_dice_score: 0.8552 - val_loss: 0.5007 - learning_rate: 8.8191e-05
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8768 - loss: 0.4421 - val_binary_dice_score: 0.8190 - val_loss: 0.5990 - learning_rate: 8.5953e-05
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8606 - loss: 0.4984 - val_binary_dice_score: 0.9136 - val_loss: 0.3449 - learning_rate: 8.3732e-05
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8535 - loss: 0.4673 - val_binary_dice_score: 0.8643 - val_loss: 0.4777 - learning_rate: 8.1529e-05
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8951 - loss: 0.3676 - val_binary_dice_score: 0.9116 - val_loss: 0.3559 - learning_rate: 7.9346e-05
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8956 - loss: 0.3423 - val_binary_dice_score: 0.8878 - val_loss: 0.4613 - learning_rate: 7.7182e-05
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8541 - loss: 0.5497 - val_binary_dice_score: 0.9059 - val_loss: 0.3444 - learning_rate: 7.5038e-05
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8653 - loss: 0.4807 - val_binary_dice_score: 0.9324 - val_loss: 0.2936 - learning_rate: 7.2914e-05
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8832 - loss: 0.4222 - val_binary_dice_score: 0.8824 - val_loss: 0.4311 - learning_rate: 7.0812e-05
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8593 - loss: 0.4876 - val_binary_dice_score: 0.9107 - val_loss: 0.3551 - learning_rate: 6.8731e-05
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8124 - loss: 0.5147 - val_binary_dice_score: 0.5039 - val_loss: 1.3385 - learning_rate: 6.6673e-05
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8870 - loss: 0.4243 - val_binary_dice_score: 0.9128 - val_loss: 0.3139 - learning_rate: 6.4638e-05
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8182 - loss: 0.5887 - val_binary_dice_score: 0.8725 - val_loss: 0.5019 - learning_rate: 6.2626e-05
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8413 - loss: 0.5172 - val_binary_dice_score: 0.9292 - val_loss: 0.2971 - learning_rate: 6.0638e-05
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8637 - loss: 0.4424 - val_binary_dice_score: 0.8984 - val_loss: 0.3619 - learning_rate: 5.8675e-05
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8816 - loss: 0.4411 - val_binary_dice_score: 0.9087 - val_loss: 0.3536 - learning_rate: 5.6737e-05
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9005 - loss: 0.4139 - val_binary_dice_score: 0.9004 - val_loss: 0.3744 - learning_rate: 5.4825e-05
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8674 - loss: 0.4746 - val_binary_dice_score: 0.7277 - val_loss: 0.8939 - learning_rate: 5.2938e-05
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8703 - loss: 0.4124 - val_binary_dice_score: 0.9094 - val_loss: 0.3520 - learning_rate: 5.1079e-05
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8854 - loss: 0.4308 - val_binary_dice_score: 0.9263 - val_loss: 0.3105 - learning_rate: 4.9246e-05
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8573 - loss: 0.4962 - val_binary_dice_score: 0.7836 - val_loss: 0.7409 - learning_rate: 4.7442e-05
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8554 - loss: 0.5006 - val_binary_dice_score: 0.8410 - val_loss: 0.4951 - learning_rate: 4.5665e-05
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8674 - loss: 0.4281 - val_binary_dice_score: 0.9218 - val_loss: 0.3301 - learning_rate: 4.3917e-05
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8711 - loss: 0.4206 - val_binary_dice_score: 0.8973 - val_loss: 0.3741 - learning_rate: 4.2198e-05
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8607 - loss: 0.4901 - val_binary_dice_score: 0.9278 - val_loss: 0.3067 - learning_rate: 4.0509e-05
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8674 - loss: 0.4417 - val_binary_dice_score: 0.8022 - val_loss: 0.7724 - learning_rate: 3.8850e-05
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8608 - loss: 0.4631 - val_binary_dice_score: 0.8673 - val_loss: 0.5068 - learning_rate: 3.7222e-05
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8575 - loss: 0.5150 - val_binary_dice_score: 0.8917 - val_loss: 0.4013 - learning_rate: 3.5624e-05
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8921 - loss: 0.3810 - val_binary_dice_score: 0.9049 - val_loss: 0.3592 - learning_rate: 3.4058e-05
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8524 - loss: 0.4744 - val_binary_dice_score: 0.8984 - val_loss: 0.3708 - learning_rate: 3.2523e-05
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8171 - loss: 0.5488 - val_binary_dice_score: 0.9310 - val_loss: 0.2780 - learning_rate: 3.1021e-05
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8813 - loss: 0.4796 - val_binary_dice_score: 0.9194 - val_loss: 0.3110 - learning_rate: 2.9552e-05
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8668 - loss: 0.4343 - val_binary_dice_score: 0.9283 - val_loss: 0.2824 - learning_rate: 2.8116e-05
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8667 - loss: 0.4572 - val_binary_dice_score: 0.8832 - val_loss: 0.4573 - learning_rate: 2.6713e-05
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8954 - loss: 0.3809 - val_binary_dice_score: 0.9062 - val_loss: 0.3581 - learning_rate: 2.5344e-05
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8854 - loss: 0.3823 - val_binary_dice_score: 0.9247 - val_loss: 0.3036 - learning_rate: 2.4009e-05
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9211 - loss: 0.2937 - val_binary_dice_score: 0.9221 - val_loss: 0.3032 - learning_rate: 2.2708e-05
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9142 - loss: 0.3283 - val_binary_dice_score: 0.9213 - val_loss: 0.3051 - learning_rate: 2.1443e-05
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - binary_dice_score: 0.8721 - loss: 0.4783 - val_binary_dice_score: 0.8165 - val_loss: 0.5393 - learning_rate: 2.0213e-05
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8329 - loss: 0.4936 - val_binary_dice_score: 0.9322 - val_loss: 0.2750 - learning_rate: 1.9019e-05
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8639 - loss: 0.4451 - val_binary_dice_score: 0.8759 - val_loss: 0.4520 - learning_rate: 1.7860e-05
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8849 - loss: 0.4304 - val_binary_dice_score: 0.9172 - val_loss: 0.3232 - learning_rate: 1.6738e-05
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8881 - loss: 0.3978 - val_binary_dice_score: 0.8759 - val_loss: 0.4256 - learning_rate: 1.5652e-05
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9015 - loss: 0.3482 - val_binary_dice_score: 0.8787 - val_loss: 0.4280 - learning_rate: 1.4604e-05
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8503 - loss: 0.4996 - val_binary_dice_score: 0.8993 - val_loss: 0.3648 - learning_rate: 1.3592e-05
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8899 - loss: 0.3759 - val_binary_dice_score: 0.8710 - val_loss: 0.4422 - learning_rate: 1.2618e-05
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8909 - loss: 0.4030 - val_binary_dice_score: 0.9014 - val_loss: 0.3487 - learning_rate: 1.1681e-05
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8864 - loss: 0.3954 - val_binary_dice_score: 0.8944 - val_loss: 0.3979 - learning_rate: 1.0783e-05
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8719 - loss: 0.4128 - val_binary_dice_score: 0.9320 - val_loss: 0.2809 - learning_rate: 9.9223e-06
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8671 - loss: 0.4699 - val_binary_dice_score: 0.9273 - val_loss: 0.2985 - learning_rate: 9.1003e-06
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8611 - loss: 0.4607 - val_binary_dice_score: 0.9285 - val_loss: 0.2900 - learning_rate: 8.3171e-06
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8707 - loss: 0.4334 - val_binary_dice_score: 0.9065 - val_loss: 0.3824 - learning_rate: 7.5727e-06
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8791 - loss: 0.3920 - val_binary_dice_score: 0.9309 - val_loss: 0.2895 - learning_rate: 6.8673e-06
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8951 - loss: 0.3678 - val_binary_dice_score: 0.8756 - val_loss: 0.4132 - learning_rate: 6.2013e-06
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8608 - loss: 0.4864 - val_binary_dice_score: 0.9196 - val_loss: 0.3158 - learning_rate: 5.5747e-06
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9084 - loss: 0.3487 - val_binary_dice_score: 0.9126 - val_loss: 0.3632 - learning_rate: 4.9877e-06
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8811 - loss: 0.4430 - val_binary_dice_score: 0.9292 - val_loss: 0.2897 - learning_rate: 4.4405e-06
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8990 - loss: 0.3691 - val_binary_dice_score: 0.9041 - val_loss: 0.3726 - learning_rate: 3.9332e-06
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - binary_dice_score: 0.8993 - loss: 0.3433 - val_binary_dice_score: 0.9277 - val_loss: 0.2839 - learning_rate: 3.4660e-06
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8990 - loss: 0.3727 - val_binary_dice_score: 0.9122 - val_loss: 0.3519 - learning_rate: 3.0390e-06
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9174 - loss: 0.3112 - val_binary_dice_score: 0.9315 - val_loss: 0.2847 - learning_rate: 2.6523e-06
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8676 - loss: 0.4180 - val_binary_dice_score: 0.9193 - val_loss: 0.3420 - learning_rate: 2.3060e-06
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8835 - loss: 0.3804 - val_binary_dice_score: 0.9245 - val_loss: 0.3219 - learning_rate: 2.0003e-06
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8559 - loss: 0.4702 - val_binary_dice_score: 0.8776 - val_loss: 0.4154 - learning_rate: 1.7351e-06
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.9267 - loss: 0.3051 - val_binary_dice_score: 0.9206 - val_loss: 0.3120 - learning_rate: 1.5106e-06
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8881 - loss: 0.4030 - val_binary_dice_score: 0.8993 - val_loss: 0.3592 - learning_rate: 1.3269e-06
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8984 - loss: 0.3734 - val_binary_dice_score: 0.8925 - val_loss: 0.3767 - learning_rate: 1.1839e-06
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8988 - loss: 0.3822 - val_binary_dice_score: 0.9077 - val_loss: 0.3404 - learning_rate: 1.0817e-06
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8586 - loss: 0.4939 - val_binary_dice_score: 0.8795 - val_loss: 0.4116 - learning_rate: 1.0204e-06
#
# Best val Dice: 0.0000

# %%
metric_key = [k for k in history.history.keys() if "dice" in k and "val" not in k][0]
val_metric_key = [k for k in history.history.keys() if "dice" in k and "val" in k][0]

fig, axes = plt.subplots(1, 3, figsize=(18, 4))

axes[0].plot(history.history["loss"],     label="Train", alpha=0.8)
axes[0].plot(history.history["val_loss"], label="Val", alpha=0.8)
axes[0].set_title("Loss"); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history[metric_key],     label="Train", alpha=0.8)
axes[1].plot(history.history[val_metric_key], label="Val", alpha=0.8)
axes[1].axhline(y=0.90, color='red', linestyle='--', alpha=0.5, label='Target')
axes[1].set_title("Dice"); axes[1].set_ylim(0, 1)
axes[1].legend(); axes[1].grid(alpha=0.3)

n = len(history.history["loss"])
axes[2].plot([warmup_cosine_lr(e, None) for e in range(n)])
axes[2].set_title("LR"); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(str(OUT_DIR / "training_curves.png"), dpi=150)
plt.show()

final_train = history.history[metric_key][-1]
final_val   = history.history[val_metric_key][-1]
print(f"Train Dice: {final_train:.4f}  Val Dice: {final_val:.4f}  Gap: {final_train - final_val:.4f}")
# Out:
# Train Dice: 0.8664  Val Dice: 0.8795  Gap: -0.0130

# %%
from medicai.utils.inference import SlidingWindowInference

def predict_volume(model, image_path, label_path):
    data, meta = load_pair(image_path, label_path)
    pre = Compose([
        ScaleIntensityRange(
            keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForeground(keys=("image", "label"), source_key="image"),
    ])
    out = pre(data, meta)
    ct = out["image"]
    gt = out["label"]
    if hasattr(ct, "numpy"): ct = ct.numpy()
    if hasattr(gt, "numpy"): gt = gt.numpy()

    swi = SlidingWindowInference(
        model=model, num_classes=1, roi_size=CROP_SHAPE,
        sw_batch_size=2, overlap=0.5, mode='gaussian',
    )
    pred     = np.array(swi(ct[np.newaxis]))[0]
    pred_bin = (1.0 / (1.0 + np.exp(-pred)) > 0.5).astype(np.float32)
    inter    = (pred_bin * gt).sum()
    dice     = float(2.0 * inter / (pred_bin.sum() + gt.sum() + 1e-6))
    return ct, gt, pred_bin, dice

# %%
best_model = keras.models.load_model(
    str(OUT_DIR / "best_model.keras"),
    custom_objects={
        "BinaryDiceCELoss": BinaryDiceCELoss,
        "BinaryDiceMetric": BinaryDiceMetric,
    },
    compile=False,
)
best_model.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=MIN_LR, weight_decay=WEIGHT_DECAY),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

results = []
for p in val_pairs:
    _, _, _, dice = predict_volume(best_model, p["image"], p["label"])
    results.append({"scan_id": p["scan_id"], "dice": dice})
    print(f"  {p['scan_id']}  Dice={dice:.4f}")

dices = [r["dice"] for r in results]
print(f"\nMean={np.mean(dices):.4f}  Std={np.std(dices):.4f}  Min={np.min(dices):.4f}  Max={np.max(dices):.4f}")
# Out:
# Total patch 48: 100%|██████████| 24/24 [00:09<00:00,  2.49it/s]
#   be9fa3df918a  Dice=0.8313
# Total patch 48: 100%|██████████| 24/24 [00:09<00:00,  2.49it/s]
#   092c97ecec4b  Dice=0.7375
# Total patch 75: 100%|██████████| 38/38 [00:15<00:00,  2.51it/s]
#   ed66d74f6692  Dice=0.8769
# Total patch 48: 100%|██████████| 24/24 [00:09<00:00,  2.59it/s]
#   d86566fdb41c  Dice=0.9084
# Total patch 27: 100%|██████████| 14/14 [00:05<00:00,  2.61it/s]
#   2eb903f4f204  Dice=0.8909
# Total patch 32: 100%|██████████| 16/16 [00:06<00:00,  2.49it/s]
#   4d9723eef946  Dice=0.8658
# Total patch 75: 100%|██████████| 38/38 [00:14<00:00,  2.66it/s]
#   43ca4b1f6495  Dice=0.8059
# Total patch 32: 100%|██████████| 16/16 [00:06<00:00,  2.60it/s]
#   8781c0349102  Dice=0.6650
#
# Mean=0.8227  Std=0.0785  Min=0.6650  Max=0.9084

# %%
def visualise(ct, gt, pred, scan_id, dice, n_slices=6):
    D = ct.shape[0]
    idxs = np.linspace(D // 4, 3 * D // 4, n_slices, dtype=int)
    fig, axes = plt.subplots(3, n_slices, figsize=(3 * n_slices, 9))
    fig.suptitle(f"{scan_id}  Dice={dice:.4f}", fontsize=13, fontweight="bold")
    for col, idx in enumerate(idxs):
        s, g, p = ct[idx,:,:,0], gt[idx,:,:,0], pred[idx,:,:,0]
        axes[0,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[0,col].set_title(f"CT z={idx}", fontsize=8); axes[0,col].axis("off")
        axes[1,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[1,col].imshow(g, cmap="Reds",  alpha=0.45)
        axes[1,col].set_title("GT", fontsize=8); axes[1,col].axis("off")
        axes[2,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[2,col].imshow(p, cmap="Blues", alpha=0.45)
        axes[2,col].set_title("Pred", fontsize=8); axes[2,col].axis("off")
    plt.tight_layout()
    plt.savefig(str(OUT_DIR / f"{scan_id}_pred.png"), dpi=150, bbox_inches="tight")
    plt.show()

for res in [max(results, key=lambda r: r["dice"]), min(results, key=lambda r: r["dice"])]:
    p = next(x for x in val_pairs if x["scan_id"] == res["scan_id"])
    ct, gt, pred, dice = predict_volume(best_model, p["image"], p["label"])
    visualise(ct, gt, pred, res["scan_id"], dice)
# Out:
# Total patch 48: 100%|██████████| 24/24 [00:09<00:00,  2.59it/s]
# Total patch 32: 100%|██████████| 16/16 [00:06<00:00,  2.56it/s]

# %%
stats = {
    "model":         "UNet_resnet18",
    "backend":       keras.config.backend(),
    "mean_dice":     round(float(np.mean(dices)), 4),
    "std_dice":      round(float(np.std(dices)),  4),
    "n_train":       len(train_pairs),
    "n_val":         len(val_pairs),
    "crop_shape":    list(CROP_SHAPE),
    "hu_window":     [HU_MIN, HU_MAX],
    "epochs_trained": len(history.history["loss"]),
    "best_val_dice": round(float(max(history.history.get("val_binary_dice_metric", [0]))), 4),
    "total_params":  model.count_params(),
    "weight_decay":  WEIGHT_DECAY,
    "num_samples":   NUM_SAMPLES,
    "per_scan":      results,
}
with open(OUT_DIR / "eval_stats.json", "w") as f:
    json.dump(stats, f, indent=2)
print(json.dumps({k: v for k, v in stats.items() if k != "per_scan"}, indent=2))
# Out:
# {
#   "model": "UNet_resnet18",
#   "backend": "torch",
#   "mean_dice": 0.8227,
#   "std_dice": 0.0785,
#   "n_train": 39,
#   "n_val": 8,
#   "crop_shape": [
#     128,
#     128,
#     128
#   ],
#   "hu_window": [
#     -175,
#     400
#   ],
#   "epochs_trained": 200,
#   "best_val_dice": 0.0,
#   "total_params": 42622289,
#   "weight_decay": 0.0005,
#   "num_samples": 1
# }
