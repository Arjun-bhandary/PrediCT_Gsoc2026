# %%
# !pip install git+https://github.com/innat/medic-ai.git -q
# !pip install scikit-learn nibabel -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for medicai (pyproject.toml) ... done

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import json
import math
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split

import keras
import torch

from medicai.models import UNet,AttentionUNet,TransUNet
from medicai.losses import BinaryDiceCELoss
from medicai.metrics import BinaryDiceMetric
from medicai.transforms import (
    Compose,
    ScaleIntensityRange,
    CropForeground,
    RandCropByPosNegLabel,
    RandFlip,
    RandRotate90,
    RandShiftIntensity,
)

print(f"Backend : {keras.config.backend()}")
print(f"Keras   : {keras.version()}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
    print(f"VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# 2026-03-24 15:27:14.907134: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774366035.099882      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774366035.153963      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774366035.635764      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774366035.635814      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774366035.635818      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774366035.635820      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Backend : torch
# Keras   : 3.10.0
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
CT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/gsoc-coca-segment/data_totalseg/inputs")
GT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/coca-gt/kaggle/working/gsoc-coca-gt")
OUT_DIR = Path("/kaggle/working/heart_seg_output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
CROP_SHAPE    = (128, 128, 128)
HU_MIN        = -175
HU_MAX        = 400
BATCH_SIZE    = 2
NUM_SAMPLES   = 1
EPOCHS        = 400
WARMUP_EPOCHS = 10
LEARNING_RATE = 3e-4
MIN_LR        = 1e-6
WEIGHT_DECAY  = 5e-4
VAL_SPLIT     = 0.15
SEED          = 50

# %%
import medicai
print(medicai.models.list_models())
# Out:
#                      Model Registry Catalog
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Segmentor        ┃ Backbone Family ┃ Variants                 ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ • attention_unet │ convnext        │ • convnext_base          │
# │ • deeplabv3plus  │                 │ • convnext_large         │
# │ • unet           │                 │ • convnext_small         │
# │ • unet_plus_plus │                 │ • convnext_tiny          │
# │ • upernet        │                 │ • convnext_v2_atto       │
# │                  │                 │ • convnext_v2_base       │
# │                  │                 │ • convnext_v2_femto      │
# │                  │                 │ • convnext_v2_huge       │
# │                  │                 │ • convnext_v2_large      │
# │                  │                 │ • convnext_v2_nano       │
# │                  │                 │ • convnext_v2_pico       │
# │                  │                 │ • convnext_v2_small      │
# │                  │                 │ • convnext_v2_tiny       │
# │                  │                 │ • convnext_xlarge        │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ densenet        │ • densenet121            │
# │ • deeplabv3plus  │                 │ • densenet169            │
# │ • trans_unet     │                 │ • densenet201            │
# │ • unet           │                 │ • densenet264            │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ efficientnet    │ • efficientnet_b0        │
# │ • deeplabv3plus  │                 │ • efficientnet_b1        │
# │ • trans_unet     │                 │ • efficientnet_b2        │
# │ • unet           │                 │ • efficientnet_b3        │
# │ • unet_plus_plus │                 │ • efficientnet_b4        │
# │ • upernet        │                 │ • efficientnet_b5        │
# │                  │                 │ • efficientnet_b6        │
# │                  │                 │ • efficientnet_b7        │
# │                  │                 │ • efficientnet_b8        │
# │                  │                 │ • efficientnet_l2        │
# │                  │                 │ • efficientnet_v2_b0     │
# │                  │                 │ • efficientnet_v2_b1     │
# │                  │                 │ • efficientnet_v2_b2     │
# │                  │                 │ • efficientnet_v2_b3     │
# │                  │                 │ • efficientnet_v2_l      │
# │                  │                 │ • efficientnet_v2_m      │
# │                  │                 │ • efficientnet_v2_s      │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • segformer      │ mit             │ • mit_b0                 │
# │ • upernet        │                 │ • mit_b1                 │
# │                  │                 │ • mit_b2                 │
# │                  │                 │ • mit_b3                 │
# │                  │                 │ • mit_b4                 │
# │                  │                 │ • mit_b5                 │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ resnet          │ • resnet101              │
# │ • deeplabv3plus  │                 │ • resnet101_v2           │
# │ • trans_unet     │                 │ • resnet152              │
# │ • unet           │                 │ • resnet152_v2           │
# │ • unet_plus_plus │                 │ • resnet18               │
# │ • upernet        │                 │ • resnet200_vd           │
# │                  │                 │ • resnet34               │
# │                  │                 │ • resnet50               │
# │                  │                 │ • resnet50_v2            │
# │                  │                 │ • resnet50_vd            │
# │                  │                 │ • resnext101             │
# │                  │                 │ • resnext50              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ senet           │ • seresnet101            │
# │ • deeplabv3plus  │                 │ • seresnet101_v2         │
# │ • trans_unet     │                 │ • seresnet152            │
# │ • unet           │                 │ • seresnet152_v2         │
# │ • unet_plus_plus │                 │ • seresnet18             │
# │ • upernet        │                 │ • seresnet200_vd         │
# │                  │                 │ • seresnet34             │
# │                  │                 │ • seresnet50             │
# │                  │                 │ • seresnet50_v2          │
# │                  │                 │ • seresnet50_vd          │
# │                  │                 │ • seresnext101           │
# │                  │                 │ • seresnext50            │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • swin_unetr     │ swin            │ • swin_base              │
# │ • upernet        │                 │ • swin_base_v2           │
# │                  │                 │ • swin_small             │
# │                  │                 │ • swin_small_v2          │
# │                  │                 │ • swin_tiny              │
# │                  │                 │ • swin_tiny_v2           │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr_plusplus │ unetr_plusplus  │ • unetr_plusplus_encoder │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr          │ vit             │ • vit_base               │
# │                  │                 │ • vit_huge               │
# │                  │                 │ • vit_large              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ xception        │ • xception               │
# │ • trans_unet     │                 │                          │
# │ • unet           │                 │                          │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# └──────────────────┴─────────────────┴──────────────────────────┘

# %%
def discover_pairs(ct_dir, gt_dir):
    pairs = []
    for ct_path in sorted(list(ct_dir.glob("*_img.nii.gz")) + list(ct_dir.glob("*_img.nii"))):
        scan_id = ct_path.name.replace("_img.nii.gz", "").replace("_img.nii", "")
        for ext in (".nii.gz", ".nii"):
            gt_path = gt_dir / scan_id / f"{scan_id}_binary{ext}"
            if gt_path.exists():
                pairs.append({"scan_id": scan_id, "image": str(ct_path), "label": str(gt_path)})
                break
    return pairs

pairs = discover_pairs(CT_DIR, GT_DIR)
print(f"Found {len(pairs)} pairs")

train_pairs, val_pairs = train_test_split(pairs, test_size=VAL_SPLIT, random_state=SEED)
print(f"Train={len(train_pairs)}  Val={len(val_pairs)}")
# Out:
# Found 47 pairs
# Train=39  Val=8

# %%
def load_pair(image_path, label_path):
    image_nii = nib.load(image_path)
    label_nii = nib.load(label_path)
    image  = image_nii.get_fdata().astype(np.float32)
    label  = label_nii.get_fdata().astype(np.float32)
    affine = np.array(image_nii.affine, dtype=np.float32)
    image  = np.transpose(image, (2, 1, 0))
    label  = np.transpose(label, (2, 1, 0))
    affine[:, :3] = affine[:, [2, 1, 0]]
    label = (label > 0.5).astype(np.float32)
    image = image[..., np.newaxis]
    label = label[..., np.newaxis]
    return {"image": image, "label": label}, {"affine": affine}

_d, _ = load_pair(pairs[0]["image"], pairs[0]["label"])
print(f"image: {_d['image'].shape}   label: {_d['label'].shape}")
print(f"Label fraction: {_d['label'].mean():.4f}")
# Out:
# image: (219, 309, 309, 1)   label: (219, 309, 309, 1)
# Label fraction: 0.1100

# %%
train_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=2, neg=1, num_samples=NUM_SAMPLES,
        image_reference_key="image", image_threshold=0,
    ),
    RandFlip(keys=["image", "label"], spatial_axis=[0], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[1], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[2], prob=0.5),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(0, 1)),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(1, 2)),
    RandShiftIntensity(keys=["image"], offsets=0.2, prob=0.8),
])

val_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=1, neg=0, num_samples=1,
        image_reference_key="image", image_threshold=0,
    ),
])

print("Transforms ready")
# Out:
# Transforms ready

# %%
class HeartSegDataset(keras.utils.PyDataset):
    def __init__(self, pairs, transform, batch_size, num_samples=1, shuffle=False, **kw):
        super().__init__(**kw)
        self.pairs      = pairs
        self.transform  = transform
        self.batch_size = batch_size
        self.num_samples = num_samples
        self.shuffle    = shuffle
        self._build_index()

    def _build_index(self):
        self._index = [(vi, ci) for vi in range(len(self.pairs))
                                for ci in range(self.num_samples)]
        if self.shuffle:
            np.random.shuffle(self._index)

    def __len__(self):
        return math.ceil(len(self._index) / self.batch_size)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self._index)

    def __getitem__(self, idx):
        batch = self._index[idx * self.batch_size : (idx + 1) * self.batch_size]
        images, labels = [], []
        for vi, ci in batch:
            p = self.pairs[vi]
            data, meta = load_pair(p["image"], p["label"])
            out = self.transform(data, meta)
            img, lbl = out["image"], out["label"]
            if isinstance(img, list):
                ci = min(ci, len(img) - 1)
                img, lbl = img[ci], lbl[ci]
            if hasattr(img, "numpy"): img = img.numpy()
            if hasattr(lbl, "numpy"): lbl = lbl.numpy()
            images.append(img)
            labels.append(lbl)
        return np.stack(images), np.stack(labels)


train_ds = HeartSegDataset(
    train_pairs, train_transform,
    batch_size=BATCH_SIZE, num_samples=NUM_SAMPLES, shuffle=True,
)
val_ds = HeartSegDataset(
    val_pairs, val_transform,
    batch_size=1, num_samples=1, shuffle=False,
)

_x, _y = train_ds[0]
print(f"Batch: {_x.shape}  [{_x.min():.2f}, {_x.max():.2f}]")
print(f"Label: {_y.shape}  heart voxels={int(_y.sum())}")
print(f"Steps/epoch: {len(train_ds)} train, {len(val_ds)} val")
# Out:
# I0000 00:00:1774366054.769947      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Batch: (2, 128, 128, 128, 1)  [0.07, 1.17]
# Label: (2, 128, 128, 128, 1)  heart voxels=1525982
# Steps/epoch: 20 train, 8 val

# %%
model = AttentionUNet(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='densenet121',
    classifier_activation=None,
)

print(f"Parameters: {model.count_params():,}")
model.summary(line_length=100)
# Out:
# Parameters: 31,933,813
# Model: "AttentionUNet3D"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_spec (InputLayer)     │ (None, 128, 128, 128,   │              0 │ -                       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_dense_conv (Conv3D)    │ (None, 64, 64, 64, 64)  │         21,952 │ input_spec[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_dense_bn               │ (None, 64, 64, 64, 64)  │            256 │ stem_dense_conv[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_dense_relu             │ (None, 64, 64, 64, 64)  │              0 │ stem_dense_bn[0][0]     │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ max_pooling3d               │ (None, 32, 32, 32, 64)  │              0 │ stem_dense_relu[0][0]   │
# │ (MaxPooling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_bn1           │ (None, 32, 32, 32, 64)  │            256 │ max_pooling3d[0][0]     │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_relu1         │ (None, 32, 32, 32, 64)  │              0 │ block0_layer0_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_conv1x1       │ (None, 32, 32, 32, 128) │          8,192 │ block0_layer0_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer0_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer0_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer0_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer0_concat        │ (None, 32, 32, 32, 96)  │              0 │ max_pooling3d[0][0],    │
# │ (Concatenate)               │                         │                │ block0_layer0_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_bn1           │ (None, 32, 32, 32, 96)  │            384 │ block0_layer0_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_relu1         │ (None, 32, 32, 32, 96)  │              0 │ block0_layer1_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_conv1x1       │ (None, 32, 32, 32, 128) │         12,288 │ block0_layer1_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer1_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer1_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer1_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer1_concat        │ (None, 32, 32, 32, 128) │              0 │ block0_layer0_concat[0… │
# │ (Concatenate)               │                         │                │ block0_layer1_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_bn1           │ (None, 32, 32, 32, 128) │            512 │ block0_layer1_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_relu1         │ (None, 32, 32, 32, 128) │              0 │ block0_layer2_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_conv1x1       │ (None, 32, 32, 32, 128) │         16,384 │ block0_layer2_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer2_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer2_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer2_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer2_concat        │ (None, 32, 32, 32, 160) │              0 │ block0_layer1_concat[0… │
# │ (Concatenate)               │                         │                │ block0_layer2_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_bn1           │ (None, 32, 32, 32, 160) │            640 │ block0_layer2_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_relu1         │ (None, 32, 32, 32, 160) │              0 │ block0_layer3_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_conv1x1       │ (None, 32, 32, 32, 128) │         20,480 │ block0_layer3_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer3_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer3_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer3_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer3_concat        │ (None, 32, 32, 32, 192) │              0 │ block0_layer2_concat[0… │
# │ (Concatenate)               │                         │                │ block0_layer3_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_bn1           │ (None, 32, 32, 32, 192) │            768 │ block0_layer3_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_relu1         │ (None, 32, 32, 32, 192) │              0 │ block0_layer4_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_conv1x1       │ (None, 32, 32, 32, 128) │         24,576 │ block0_layer4_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer4_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer4_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer4_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer4_concat        │ (None, 32, 32, 32, 224) │              0 │ block0_layer3_concat[0… │
# │ (Concatenate)               │                         │                │ block0_layer4_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_bn1           │ (None, 32, 32, 32, 224) │            896 │ block0_layer4_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_relu1         │ (None, 32, 32, 32, 224) │              0 │ block0_layer5_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_conv1x1       │ (None, 32, 32, 32, 128) │         28,672 │ block0_layer5_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_bn2           │ (None, 32, 32, 32, 128) │            512 │ block0_layer5_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_relu2         │ (None, 32, 32, 32, 128) │              0 │ block0_layer5_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_conv3x3       │ (None, 32, 32, 32, 32)  │        110,592 │ block0_layer5_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_layer5_concat        │ (None, 32, 32, 32, 256) │              0 │ block0_layer4_concat[0… │
# │ (Concatenate)               │                         │                │ block0_layer5_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_trans_bn             │ (None, 32, 32, 32, 256) │          1,024 │ block0_layer5_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_trans_relu           │ (None, 32, 32, 32, 256) │              0 │ block0_trans_bn[0][0]   │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_trans_conv1x1        │ (None, 32, 32, 32, 128) │         32,768 │ block0_trans_relu[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block0_trans_pool           │ (None, 16, 16, 16, 128) │              0 │ block0_trans_conv1x1[0… │
# │ (AveragePooling3D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_bn1           │ (None, 16, 16, 16, 128) │            512 │ block0_trans_pool[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_relu1         │ (None, 16, 16, 16, 128) │              0 │ block1_layer0_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_conv1x1       │ (None, 16, 16, 16, 128) │         16,384 │ block1_layer0_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer0_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer0_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer0_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer0_concat        │ (None, 16, 16, 16, 160) │              0 │ block0_trans_pool[0][0… │
# │ (Concatenate)               │                         │                │ block1_layer0_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_bn1           │ (None, 16, 16, 16, 160) │            640 │ block1_layer0_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_relu1         │ (None, 16, 16, 16, 160) │              0 │ block1_layer1_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_conv1x1       │ (None, 16, 16, 16, 128) │         20,480 │ block1_layer1_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer1_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer1_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer1_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer1_concat        │ (None, 16, 16, 16, 192) │              0 │ block1_layer0_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer1_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_bn1           │ (None, 16, 16, 16, 192) │            768 │ block1_layer1_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_relu1         │ (None, 16, 16, 16, 192) │              0 │ block1_layer2_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_conv1x1       │ (None, 16, 16, 16, 128) │         24,576 │ block1_layer2_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer2_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer2_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer2_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer2_concat        │ (None, 16, 16, 16, 224) │              0 │ block1_layer1_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer2_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_bn1           │ (None, 16, 16, 16, 224) │            896 │ block1_layer2_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_relu1         │ (None, 16, 16, 16, 224) │              0 │ block1_layer3_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_conv1x1       │ (None, 16, 16, 16, 128) │         28,672 │ block1_layer3_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer3_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer3_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer3_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer3_concat        │ (None, 16, 16, 16, 256) │              0 │ block1_layer2_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer3_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_bn1           │ (None, 16, 16, 16, 256) │          1,024 │ block1_layer3_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_relu1         │ (None, 16, 16, 16, 256) │              0 │ block1_layer4_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_conv1x1       │ (None, 16, 16, 16, 128) │         32,768 │ block1_layer4_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer4_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer4_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer4_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer4_concat        │ (None, 16, 16, 16, 288) │              0 │ block1_layer3_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer4_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_bn1           │ (None, 16, 16, 16, 288) │          1,152 │ block1_layer4_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_relu1         │ (None, 16, 16, 16, 288) │              0 │ block1_layer5_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_conv1x1       │ (None, 16, 16, 16, 128) │         36,864 │ block1_layer5_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer5_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer5_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer5_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer5_concat        │ (None, 16, 16, 16, 320) │              0 │ block1_layer4_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer5_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_bn1           │ (None, 16, 16, 16, 320) │          1,280 │ block1_layer5_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_relu1         │ (None, 16, 16, 16, 320) │              0 │ block1_layer6_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_conv1x1       │ (None, 16, 16, 16, 128) │         40,960 │ block1_layer6_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer6_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer6_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer6_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer6_concat        │ (None, 16, 16, 16, 352) │              0 │ block1_layer5_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer6_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_bn1           │ (None, 16, 16, 16, 352) │          1,408 │ block1_layer6_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_relu1         │ (None, 16, 16, 16, 352) │              0 │ block1_layer7_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_conv1x1       │ (None, 16, 16, 16, 128) │         45,056 │ block1_layer7_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer7_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer7_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer7_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer7_concat        │ (None, 16, 16, 16, 384) │              0 │ block1_layer6_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer7_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_bn1           │ (None, 16, 16, 16, 384) │          1,536 │ block1_layer7_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_relu1         │ (None, 16, 16, 16, 384) │              0 │ block1_layer8_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_conv1x1       │ (None, 16, 16, 16, 128) │         49,152 │ block1_layer8_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer8_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer8_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer8_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer8_concat        │ (None, 16, 16, 16, 416) │              0 │ block1_layer7_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer8_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_bn1           │ (None, 16, 16, 16, 416) │          1,664 │ block1_layer8_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_relu1         │ (None, 16, 16, 16, 416) │              0 │ block1_layer9_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_conv1x1       │ (None, 16, 16, 16, 128) │         53,248 │ block1_layer9_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_bn2           │ (None, 16, 16, 16, 128) │            512 │ block1_layer9_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_relu2         │ (None, 16, 16, 16, 128) │              0 │ block1_layer9_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_conv3x3       │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer9_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer9_concat        │ (None, 16, 16, 16, 448) │              0 │ block1_layer8_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer9_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_bn1          │ (None, 16, 16, 16, 448) │          1,792 │ block1_layer9_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_relu1        │ (None, 16, 16, 16, 448) │              0 │ block1_layer10_bn1[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_conv1x1      │ (None, 16, 16, 16, 128) │         57,344 │ block1_layer10_relu1[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_bn2          │ (None, 16, 16, 16, 128) │            512 │ block1_layer10_conv1x1… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_relu2        │ (None, 16, 16, 16, 128) │              0 │ block1_layer10_bn2[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_conv3x3      │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer10_relu2[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer10_concat       │ (None, 16, 16, 16, 480) │              0 │ block1_layer9_concat[0… │
# │ (Concatenate)               │                         │                │ block1_layer10_conv3x3… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_bn1          │ (None, 16, 16, 16, 480) │          1,920 │ block1_layer10_concat[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_relu1        │ (None, 16, 16, 16, 480) │              0 │ block1_layer11_bn1[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_conv1x1      │ (None, 16, 16, 16, 128) │         61,440 │ block1_layer11_relu1[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_bn2          │ (None, 16, 16, 16, 128) │            512 │ block1_layer11_conv1x1… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_relu2        │ (None, 16, 16, 16, 128) │              0 │ block1_layer11_bn2[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_conv3x3      │ (None, 16, 16, 16, 32)  │        110,592 │ block1_layer11_relu2[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_layer11_concat       │ (None, 16, 16, 16, 512) │              0 │ block1_layer10_concat[… │
# │ (Concatenate)               │                         │                │ block1_layer11_conv3x3… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_trans_bn             │ (None, 16, 16, 16, 512) │          2,048 │ block1_layer11_concat[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_trans_relu           │ (None, 16, 16, 16, 512) │              0 │ block1_trans_bn[0][0]   │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_trans_conv1x1        │ (None, 16, 16, 16, 256) │        131,072 │ block1_trans_relu[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1_trans_pool           │ (None, 8, 8, 8, 256)    │              0 │ block1_trans_conv1x1[0… │
# │ (AveragePooling3D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_bn1           │ (None, 8, 8, 8, 256)    │          1,024 │ block1_trans_pool[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_relu1         │ (None, 8, 8, 8, 256)    │              0 │ block2_layer0_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_conv1x1       │ (None, 8, 8, 8, 128)    │         32,768 │ block2_layer0_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_bn2           │ (None, 8, 8, 8, 128)    │            512 │ block2_layer0_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_relu2         │ (None, 8, 8, 8, 128)    │              0 │ block2_layer0_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_conv3x3       │ (None, 8, 8, 8, 32)     │        110,592 │ block2_layer0_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer0_concat        │ (None, 8, 8, 8, 288)    │              0 │ block1_trans_pool[0][0… │
# │ (Concatenate)               │                         │                │ block2_layer0_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_bn1           │ (None, 8, 8, 8, 288)    │          1,152 │ block2_layer0_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_relu1         │ (None, 8, 8, 8, 288)    │              0 │ block2_layer1_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_conv1x1       │ (None, 8, 8, 8, 128)    │         36,864 │ block2_layer1_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_bn2           │ (None, 8, 8, 8, 128)    │            512 │ block2_layer1_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_relu2         │ (None, 8, 8, 8, 128)    │              0 │ block2_layer1_bn2[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_conv3x3       │ (None, 8, 8, 8, 32)     │        110,592 │ block2_layer1_relu2[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer1_concat        │ (None, 8, 8, 8, 320)    │              0 │ block2_layer0_concat[0… │
# │ (Concatenate)               │                         │                │ block2_layer1_conv3x3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer2_bn1           │ (None, 8, 8, 8, 320)    │          1,280 │ block2_layer1_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer2_relu1         │ (None, 8, 8, 8, 320)    │              0 │ block2_layer2_bn1[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer2_conv1x1       │ (None, 8, 8, 8, 128)    │         40,960 │ block2_layer2_relu1[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer2_bn2           │ (None, 8, 8, 8, 128)    │            512 │ block2_layer2_conv1x1[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2_layer2_relu2         │ (None, 8, 8, 8, 128)    │              0 │ block2_layer2_bn2[0][0] │
# ...
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_bn1          │ (None, 4, 4, 4, 992)    │          3,968 │ block3_layer14_concat[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_relu1        │ (None, 4, 4, 4, 992)    │              0 │ block3_layer15_bn1[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_conv1x1      │ (None, 4, 4, 4, 128)    │        126,976 │ block3_layer15_relu1[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_bn2          │ (None, 4, 4, 4, 128)    │            512 │ block3_layer15_conv1x1… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_relu2        │ (None, 4, 4, 4, 128)    │              0 │ block3_layer15_bn2[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_conv3x3      │ (None, 4, 4, 4, 32)     │        110,592 │ block3_layer15_relu2[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3_layer15_concat       │ (None, 4, 4, 4, 1024)   │              0 │ block3_layer14_concat[… │
# │ (Concatenate)               │                         │                │ block3_layer15_conv3x3… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_upsampling_… │ (None, 8, 8, 8, 1024)   │              0 │ block3_layer15_concat[… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_attention_g… │ (None, 8, 8, 8, 1024)   │        525,057 │ block2_layer23_concat[… │
# │ (AttentionGate)             │                         │                │ block3_layer15_concat[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_concat       │ (None, 8, 8, 8, 2048)   │              0 │ decoder_stage5_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage5_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_conv… │ (None, 8, 8, 8, 256)    │     14,155,776 │ decoder_stage5_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_conv… │ (None, 8, 8, 8, 256)    │      1,769,472 │ decoder_stage5_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_upsampling_… │ (None, 16, 16, 16, 256) │              0 │ decoder_stage5_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_attention_g… │ (None, 16, 16, 16, 512) │         98,689 │ block1_layer11_concat[… │
# │ (AttentionGate)             │                         │                │ decoder_stage5_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_concat       │ (None, 16, 16, 16, 768) │              0 │ decoder_stage4_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage4_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_conv… │ (None, 16, 16, 16, 128) │      2,654,208 │ decoder_stage4_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_conv… │ (None, 16, 16, 16, 128) │        442,368 │ decoder_stage4_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_upsampling_… │ (None, 32, 32, 32, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_attention_g… │ (None, 32, 32, 32, 256) │         24,769 │ block0_layer5_concat[0… │
# │ (AttentionGate)             │                         │                │ decoder_stage4_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_concat       │ (None, 32, 32, 32, 384) │              0 │ decoder_stage3_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage3_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_conv… │ (None, 32, 32, 32, 64)  │        663,552 │ decoder_stage3_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_conv… │ (None, 32, 32, 32, 64)  │        110,592 │ decoder_stage3_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_upsampling_… │ (None, 64, 64, 64, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_attention_g… │ (None, 64, 64, 64, 64)  │          4,193 │ stem_dense_relu[0][0],  │
# │ (AttentionGate)             │                         │                │ decoder_stage3_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_concat       │ (None, 64, 64, 64, 128) │              0 │ decoder_stage2_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage2_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_conv… │ (None, 64, 64, 64, 32)  │        110,592 │ decoder_stage2_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_conv… │ (None, 64, 64, 64, 32)  │         27,648 │ decoder_stage2_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_upsampling_… │ (None, 128, 128, 128,   │              0 │ decoder_stage2_conv_2_… │
# │ (UpSampling3D)              │ 32)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_conv… │ (None, 128, 128, 128,   │         13,824 │ decoder_stage1_upsampl… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_1_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_1_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_conv… │ (None, 128, 128, 128,   │          6,912 │ decoder_stage1_conv_1_… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_2_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_2_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3d_12 (Conv3D)          │ (None, 128, 128, 128,   │             17 │ decoder_stage1_conv_2_… │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ predictions (Activation)    │ (None, 128, 128, 128,   │              0 │ conv3d_12[0][0]         │
# │                             │ 1)                      │                │                         │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 31,933,813 (121.82 MB)
#  Trainable params: 31,850,229 (121.50 MB)
#  Non-trainable params: 83,584 (326.50 KB)

# %%
def warmup_cosine_lr(epoch, current_lr):
    if epoch < WARMUP_EPOCHS:
        return MIN_LR + (LEARNING_RATE - MIN_LR) * (epoch / WARMUP_EPOCHS)
    progress = (epoch - WARMUP_EPOCHS) / max(EPOCHS - WARMUP_EPOCHS, 1)
    return MIN_LR + 0.5 * (LEARNING_RATE - MIN_LR) * (1 + math.cos(math.pi * progress))

for e in [0, 10, 50, 100, 199]:
    print(f"Epoch {e:>3d}  LR = {warmup_cosine_lr(e, None):.2e}")
# Out:
# Epoch   0  LR = 1.00e-06
# Epoch  10  LR = 3.00e-04
# Epoch  50  LR = 2.92e-04
# Epoch 100  LR = 2.62e-04
# Epoch 199  LR = 1.58e-04

# %%
model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=MIN_LR,
        weight_decay=WEIGHT_DECAY,
    ),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

callbacks = [
    keras.callbacks.LearningRateScheduler(warmup_cosine_lr, verbose=0),
    keras.callbacks.ModelCheckpoint(
        filepath=str(OUT_DIR / "best_model.keras"),
        monitor="val_binary_dice_metric", mode="max",
        save_best_only=True, verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_binary_dice_metric", mode="max",
        patience=50, restore_best_weights=True, verbose=1,
    ),
    keras.callbacks.CSVLogger(str(OUT_DIR / "training_log.csv")),
]

print("Compiled")
# Out:
# Compiled

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

print(f"\nBest val Dice: {max(history.history.get('val_binary_dice_metric', [0])):.4f}")
# Out:
# Epoch 1/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 106s 5s/step - binary_dice_score: 0.3787 - loss: 1.4327 - val_binary_dice_score: 1.4445e-13 - val_loss: 1.2502 - learning_rate: 1.0000e-06
# Epoch 2/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.5231 - loss: 1.2724 - val_binary_dice_score: 0.7371 - val_loss: 1.2121 - learning_rate: 3.0900e-05
# Epoch 3/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7013 - loss: 0.9765 - val_binary_dice_score: 0.6008 - val_loss: 1.2107 - learning_rate: 6.0800e-05
# Epoch 4/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7868 - loss: 0.7940 - val_binary_dice_score: 0.6440 - val_loss: 1.3415 - learning_rate: 9.0700e-05
# Epoch 5/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7795 - loss: 0.7753 - val_binary_dice_score: 0.5872 - val_loss: 1.4961 - learning_rate: 1.2060e-04
# Epoch 6/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7692 - loss: 0.7865 - val_binary_dice_score: 0.6629 - val_loss: 1.7583 - learning_rate: 1.5050e-04
# Epoch 7/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7730 - loss: 0.7944 - val_binary_dice_score: 0.5876 - val_loss: 1.5555 - learning_rate: 1.8040e-04
# Epoch 8/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7332 - loss: 0.9055 - val_binary_dice_score: 0.5611 - val_loss: 3.5096 - learning_rate: 2.1030e-04
# Epoch 9/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8086 - loss: 0.7036 - val_binary_dice_score: 0.5456 - val_loss: 5.7497 - learning_rate: 2.4020e-04
# Epoch 10/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8157 - loss: 0.6737 - val_binary_dice_score: 0.5936 - val_loss: 5.2467 - learning_rate: 2.7010e-04
# Epoch 11/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7985 - loss: 0.7049 - val_binary_dice_score: 0.4042 - val_loss: 1.7257 - learning_rate: 3.0000e-04
# Epoch 12/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7758 - loss: 0.7961 - val_binary_dice_score: 0.7389 - val_loss: 1.0250 - learning_rate: 3.0000e-04
# Epoch 13/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7253 - loss: 0.8787 - val_binary_dice_score: 0.7113 - val_loss: 1.6362 - learning_rate: 2.9998e-04
# Epoch 14/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7416 - loss: 0.8171 - val_binary_dice_score: 0.5750 - val_loss: 2.7004 - learning_rate: 2.9996e-04
# Epoch 15/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.7184 - loss: 0.8758 - val_binary_dice_score: 0.7133 - val_loss: 1.0560 - learning_rate: 2.9992e-04
# Epoch 16/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.7898 - loss: 0.7531 - val_binary_dice_score: 0.7202 - val_loss: 0.9914 - learning_rate: 2.9988e-04
# Epoch 17/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.7917 - loss: 0.6977 - val_binary_dice_score: 0.6666 - val_loss: 1.0131 - learning_rate: 2.9983e-04
# Epoch 18/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7934 - loss: 0.7225 - val_binary_dice_score: 0.4179 - val_loss: 1.5999 - learning_rate: 2.9976e-04
# Epoch 19/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7846 - loss: 0.7407 - val_binary_dice_score: 0.0777 - val_loss: 1.7783 - learning_rate: 2.9969e-04
# Epoch 20/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8328 - loss: 0.6162 - val_binary_dice_score: 0.5041 - val_loss: 1.1346 - learning_rate: 2.9961e-04
# Epoch 21/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8542 - loss: 0.5477 - val_binary_dice_score: 0.4672 - val_loss: 1.1577 - learning_rate: 2.9952e-04
# Epoch 22/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8033 - loss: 0.6524 - val_binary_dice_score: 0.1583 - val_loss: 1.8060 - learning_rate: 2.9941e-04
# Epoch 23/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7764 - loss: 0.7143 - val_binary_dice_score: 1.3856e-13 - val_loss: 2.1242 - learning_rate: 2.9930e-04
# Epoch 24/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8056 - loss: 0.7828 - val_binary_dice_score: 0.0179 - val_loss: 1.9597 - learning_rate: 2.9918e-04
# Epoch 25/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8170 - loss: 0.6408 - val_binary_dice_score: 0.0119 - val_loss: 1.9554 - learning_rate: 2.9905e-04
# Epoch 26/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7723 - loss: 0.6834 - val_binary_dice_score: 1.2617e-13 - val_loss: 2.3974 - learning_rate: 2.9891e-04
# Epoch 27/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.7885 - loss: 0.6688 - val_binary_dice_score: 1.3386e-13 - val_loss: 3.0576 - learning_rate: 2.9876e-04
# Epoch 28/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8042 - loss: 0.7309 - val_binary_dice_score: 1.3034e-13 - val_loss: 2.2082 - learning_rate: 2.9860e-04
# Epoch 29/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8205 - loss: 0.6223 - val_binary_dice_score: 0.0076 - val_loss: 1.8222 - learning_rate: 2.9843e-04
# Epoch 30/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7963 - loss: 0.7076 - val_binary_dice_score: 5.5448e-04 - val_loss: 1.8984 - learning_rate: 2.9825e-04
# Epoch 31/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7978 - loss: 0.6965 - val_binary_dice_score: 9.0837e-05 - val_loss: 2.3071 - learning_rate: 2.9806e-04
# Epoch 32/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7971 - loss: 0.7010 - val_binary_dice_score: 0.1017 - val_loss: 1.5225 - learning_rate: 2.9787e-04
# Epoch 33/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8177 - loss: 0.6395 - val_binary_dice_score: 0.6464 - val_loss: 0.8665 - learning_rate: 2.9766e-04
# Epoch 34/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8411 - loss: 0.5508 - val_binary_dice_score: 9.8927e-04 - val_loss: 2.0540 - learning_rate: 2.9744e-04
# Epoch 35/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8413 - loss: 0.6071 - val_binary_dice_score: 0.4542 - val_loss: 0.9132 - learning_rate: 2.9721e-04
# Epoch 36/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7733 - loss: 0.7309 - val_binary_dice_score: 0.8418 - val_loss: 0.6487 - learning_rate: 2.9698e-04
# Epoch 37/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7766 - loss: 0.6860 - val_binary_dice_score: 0.0092 - val_loss: 1.8685 - learning_rate: 2.9673e-04
# Epoch 38/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8671 - loss: 0.4980 - val_binary_dice_score: 0.8373 - val_loss: 0.7072 - learning_rate: 2.9648e-04
# Epoch 39/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7535 - loss: 0.7392 - val_binary_dice_score: 0.4631 - val_loss: 0.9530 - learning_rate: 2.9621e-04
# Epoch 40/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7920 - loss: 0.6481 - val_binary_dice_score: 0.0498 - val_loss: 1.1916 - learning_rate: 2.9594e-04
# Epoch 41/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8298 - loss: 0.6122 - val_binary_dice_score: 2.6523e-04 - val_loss: 1.8907 - learning_rate: 2.9566e-04
# Epoch 42/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7897 - loss: 0.6446 - val_binary_dice_score: 0.5135 - val_loss: 0.8432 - learning_rate: 2.9536e-04
# Epoch 43/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8493 - loss: 0.5717 - val_binary_dice_score: 1.3714e-04 - val_loss: 2.2814 - learning_rate: 2.9506e-04
# Epoch 44/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8581 - loss: 0.5101 - val_binary_dice_score: 1.2596e-13 - val_loss: 2.4533 - learning_rate: 2.9475e-04
# Epoch 45/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8202 - loss: 0.7049 - val_binary_dice_score: 1.4404e-13 - val_loss: 2.6192 - learning_rate: 2.9443e-04
# Epoch 46/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7863 - loss: 0.6669 - val_binary_dice_score: 1.3169e-13 - val_loss: 2.4659 - learning_rate: 2.9410e-04
# Epoch 47/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8136 - loss: 0.6219 - val_binary_dice_score: 0.7700 - val_loss: 0.6660 - learning_rate: 2.9376e-04
# Epoch 48/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8025 - loss: 0.6602 - val_binary_dice_score: 0.7673 - val_loss: 1.1390 - learning_rate: 2.9341e-04
# Epoch 49/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7485 - loss: 0.7784 - val_binary_dice_score: 2.0242e-05 - val_loss: 3.3025 - learning_rate: 2.9305e-04
# Epoch 50/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8084 - loss: 0.6268 - val_binary_dice_score: 1.3438e-13 - val_loss: 3.5100 - learning_rate: 2.9268e-04
# Epoch 51/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7932 - loss: 0.6935 - val_binary_dice_score: 1.3881e-13 - val_loss: 3.9495 - learning_rate: 2.9231e-04
# Epoch 52/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8537 - loss: 0.5191 - val_binary_dice_score: 7.9867e-05 - val_loss: 2.6922 - learning_rate: 2.9192e-04
# Epoch 53/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8208 - loss: 0.5861 - val_binary_dice_score: 1.6012e-13 - val_loss: 2.7340 - learning_rate: 2.9153e-04
# Epoch 54/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8718 - loss: 0.4612 - val_binary_dice_score: 1.3659e-13 - val_loss: 3.0805 - learning_rate: 2.9112e-04
# Epoch 55/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8714 - loss: 0.4669 - val_binary_dice_score: 1.3701e-13 - val_loss: 2.4624 - learning_rate: 2.9071e-04
# Epoch 56/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8382 - loss: 0.5920 - val_binary_dice_score: 1.5415e-13 - val_loss: 2.4054 - learning_rate: 2.9028e-04
# Epoch 57/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7988 - loss: 0.6975 - val_binary_dice_score: 4.0321e-05 - val_loss: 2.4621 - learning_rate: 2.8985e-04
# Epoch 58/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8523 - loss: 0.6082 - val_binary_dice_score: 0.0039 - val_loss: 1.7811 - learning_rate: 2.8941e-04
# Epoch 59/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8742 - loss: 0.4774 - val_binary_dice_score: 1.2681e-13 - val_loss: 3.1568 - learning_rate: 2.8896e-04
# Epoch 60/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7812 - loss: 0.6895 - val_binary_dice_score: 1.4598e-13 - val_loss: 2.1791 - learning_rate: 2.8850e-04
# Epoch 61/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8321 - loss: 0.6199 - val_binary_dice_score: 1.3798e-13 - val_loss: 2.7179 - learning_rate: 2.8804e-04
# Epoch 62/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8452 - loss: 0.5257 - val_binary_dice_score: 7.4421e-05 - val_loss: 2.1221 - learning_rate: 2.8756e-04
# Epoch 63/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8440 - loss: 0.5348 - val_binary_dice_score: 0.8635 - val_loss: 0.6562 - learning_rate: 2.8708e-04
# Epoch 64/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8373 - loss: 0.5619 - val_binary_dice_score: 0.5721 - val_loss: 1.1007 - learning_rate: 2.8658e-04
# Epoch 65/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8621 - loss: 0.5247 - val_binary_dice_score: 0.9079 - val_loss: 0.4529 - learning_rate: 2.8608e-04
# Epoch 66/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.7717 - loss: 0.6927 - val_binary_dice_score: 1.6712e-13 - val_loss: 2.4098 - learning_rate: 2.8557e-04
# Epoch 67/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8405 - loss: 0.5388 - val_binary_dice_score: 1.2647e-13 - val_loss: 2.6162 - learning_rate: 2.8505e-04
# Epoch 68/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8526 - loss: 0.5390 - val_binary_dice_score: 1.2673e-13 - val_loss: 2.6699 - learning_rate: 2.8452e-04
# Epoch 69/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8559 - loss: 0.5251 - val_binary_dice_score: 1.2720e-13 - val_loss: 2.7350 - learning_rate: 2.8398e-04
# Epoch 70/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.7772 - loss: 0.7177 - val_binary_dice_score: 1.2710e-13 - val_loss: 2.9953 - learning_rate: 2.8343e-04
# Epoch 71/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8342 - loss: 0.5768 - val_binary_dice_score: 1.3429e-13 - val_loss: 2.9159 - learning_rate: 2.8288e-04
# Epoch 72/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8187 - loss: 0.6093 - val_binary_dice_score: 8.5383e-05 - val_loss: 2.4150 - learning_rate: 2.8231e-04
# Epoch 73/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8453 - loss: 0.5326 - val_binary_dice_score: 1.2453e-13 - val_loss: 2.4636 - learning_rate: 2.8174e-04
# Epoch 74/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8204 - loss: 0.5965 - val_binary_dice_score: 1.4128e-13 - val_loss: 2.9366 - learning_rate: 2.8116e-04
# Epoch 75/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8890 - loss: 0.4143 - val_binary_dice_score: 1.3667e-13 - val_loss: 2.5235 - learning_rate: 2.8057e-04
# Epoch 76/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8567 - loss: 0.4844 - val_binary_dice_score: 1.6112e-13 - val_loss: 3.0161 - learning_rate: 2.7997e-04
# Epoch 77/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8196 - loss: 0.6467 - val_binary_dice_score: 1.1296e-13 - val_loss: 4.2589 - learning_rate: 2.7936e-04
# Epoch 78/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8789 - loss: 0.5068 - val_binary_dice_score: 1.1620e-13 - val_loss: 3.7711 - learning_rate: 2.7875e-04
# Epoch 79/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7791 - loss: 0.8014 - val_binary_dice_score: 9.3411e-06 - val_loss: 2.6846 - learning_rate: 2.7813e-04
# Epoch 80/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8779 - loss: 0.4463 - val_binary_dice_score: 8.6164e-07 - val_loss: 2.8672 - learning_rate: 2.7750e-04
# Epoch 81/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7814 - loss: 0.6840 - val_binary_dice_score: 1.3747e-13 - val_loss: 2.6108 - learning_rate: 2.7686e-04
# Epoch 82/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8491 - loss: 0.5118 - val_binary_dice_score: 1.7746e-05 - val_loss: 2.4531 - learning_rate: 2.7621e-04
# Epoch 83/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8483 - loss: 0.4758 - val_binary_dice_score: 1.3041e-13 - val_loss: 2.3820 - learning_rate: 2.7555e-04
# Epoch 84/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.8515 - loss: 0.5191 - val_binary_dice_score: 0.0260 - val_loss: 1.7750 - learning_rate: 2.7489e-04
# Epoch 85/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8535 - loss: 0.5409 - val_binary_dice_score: 0.7094 - val_loss: 0.7722 - learning_rate: 2.7422e-04
# Epoch 86/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7643 - loss: 0.7373 - val_binary_dice_score: 0.4874 - val_loss: 0.8275 - learning_rate: 2.7354e-04
# Epoch 87/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8237 - loss: 0.5277 - val_binary_dice_score: 0.7454 - val_loss: 0.7005 - learning_rate: 2.7285e-04
# Epoch 88/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8199 - loss: 0.5956 - val_binary_dice_score: 0.8232 - val_loss: 0.6960 - learning_rate: 2.7215e-04
# Epoch 89/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8180 - loss: 0.6301 - val_binary_dice_score: 1.5926e-13 - val_loss: 2.1199 - learning_rate: 2.7145e-04
# Epoch 90/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8951 - loss: 0.4512 - val_binary_dice_score: 1.2620e-13 - val_loss: 2.5175 - learning_rate: 2.7074e-04
# Epoch 91/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7964 - loss: 0.6495 - val_binary_dice_score: 1.2386e-13 - val_loss: 3.2865 - learning_rate: 2.7002e-04
# Epoch 92/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8545 - loss: 0.5138 - val_binary_dice_score: 1.4786e-13 - val_loss: 2.9925 - learning_rate: 2.6929e-04
# Epoch 93/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8714 - loss: 0.4494 - val_binary_dice_score: 1.3743e-13 - val_loss: 2.8551 - learning_rate: 2.6855e-04
# Epoch 94/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8042 - loss: 0.6158 - val_binary_dice_score: 1.1957e-13 - val_loss: 2.9193 - learning_rate: 2.6781e-04
# Epoch 95/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8025 - loss: 0.6490 - val_binary_dice_score: 0.7356 - val_loss: 0.6448 - learning_rate: 2.6706e-04
# Epoch 96/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.8485 - loss: 0.5452 - val_binary_dice_score: 1.4323e-13 - val_loss: 3.1187 - learning_rate: 2.6630e-04
# Epoch 97/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8302 - loss: 0.5660 - val_binary_dice_score: 1.2892e-13 - val_loss: 3.1197 - learning_rate: 2.6554e-04
# Epoch 98/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8314 - loss: 0.5405 - val_binary_dice_score: 1.1626e-13 - val_loss: 3.2586 - learning_rate: 2.6477e-04
# Epoch 99/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8520 - loss: 0.4969 - val_binary_dice_score: 1.3900e-13 - val_loss: 3.0547 - learning_rate: 2.6398e-04
# Epoch 100/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8539 - loss: 0.5131 - val_binary_dice_score: 1.2457e-13 - val_loss: 3.7210 - learning_rate: 2.6320e-04
# Epoch 101/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8623 - loss: 0.4717 - val_binary_dice_score: 1.4132e-13 - val_loss: 2.9665 - learning_rate: 2.6240e-04
# Epoch 102/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8178 - loss: 0.5778 - val_binary_dice_score: 1.2276e-13 - val_loss: 3.1318 - learning_rate: 2.6160e-04
# Epoch 103/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8677 - loss: 0.4650 - val_binary_dice_score: 1.3022e-13 - val_loss: 3.0646 - learning_rate: 2.6079e-04
# Epoch 104/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8677 - loss: 0.4798 - val_binary_dice_score: 1.3042e-13 - val_loss: 3.1803 - learning_rate: 2.5997e-04
# Epoch 105/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8315 - loss: 0.5612 - val_binary_dice_score: 0.8084 - val_loss: 0.5591 - learning_rate: 2.5915e-04
# Epoch 106/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.8190 - loss: 0.6503 - val_binary_dice_score: 1.5460e-13 - val_loss: 4.4661 - learning_rate: 2.5832e-04
# Epoch 107/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8021 - loss: 0.7017 - val_binary_dice_score: 1.3549e-13 - val_loss: 5.6769 - learning_rate: 2.5748e-04
# Epoch 108/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8577 - loss: 0.5434 - val_binary_dice_score: 1.5084e-13 - val_loss: 3.2505 - learning_rate: 2.5664e-04
# Epoch 109/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8383 - loss: 0.5742 - val_binary_dice_score: 1.3938e-13 - val_loss: 2.7683 - learning_rate: 2.5579e-04
# Epoch 110/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8179 - loss: 0.5683 - val_binary_dice_score: 1.4609e-13 - val_loss: 2.0934 - learning_rate: 2.5493e-04
# Epoch 111/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8049 - loss: 0.5975 - val_binary_dice_score: 1.3872e-13 - val_loss: 2.4681 - learning_rate: 2.5406e-04
# Epoch 112/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8967 - loss: 0.4096 - val_binary_dice_score: 1.5833e-13 - val_loss: 2.4437 - learning_rate: 2.5319e-04
# Epoch 113/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8583 - loss: 0.4701 - val_binary_dice_score: 4.6545e-04 - val_loss: 2.5658 - learning_rate: 2.5231e-04
# Epoch 114/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8385 - loss: 0.5342 - val_binary_dice_score: 3.1973e-05 - val_loss: 2.4920 - learning_rate: 2.5143e-04
# Epoch 115/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8278 - loss: 0.5993 - val_binary_dice_score: 1.2045e-13 - val_loss: 2.9767 - learning_rate: 2.5054e-04
# Epoch 116/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8335 - loss: 0.5582 - val_binary_dice_score: 2.9312e-05 - val_loss: 2.7857 - learning_rate: 2.4964e-04
# Epoch 117/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8455 - loss: 0.4941 - val_binary_dice_score: 0.0742 - val_loss: 1.4105 - learning_rate: 2.4873e-04
# Epoch 118/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8586 - loss: 0.4789 - val_binary_dice_score: 0.0524 - val_loss: 1.7166 - learning_rate: 2.4782e-04
# Epoch 119/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8483 - loss: 0.4958 - val_binary_dice_score: 0.9003 - val_loss: 0.3985 - learning_rate: 2.4690e-04
# Epoch 120/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8624 - loss: 0.4710 - val_binary_dice_score: 0.7929 - val_loss: 0.5386 - learning_rate: 2.4598e-04
# Epoch 121/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8316 - loss: 0.5829 - val_binary_dice_score: 0.0078 - val_loss: 1.9692 - learning_rate: 2.4505e-04
# Epoch 122/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8618 - loss: 0.5115 - val_binary_dice_score: 0.6200 - val_loss: 0.9334 - learning_rate: 2.4411e-04
# Epoch 123/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8328 - loss: 0.5209 - val_binary_dice_score: 1.3830e-13 - val_loss: 2.9827 - learning_rate: 2.4317e-04
# Epoch 124/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8590 - loss: 0.4997 - val_binary_dice_score: 0.1046 - val_loss: 1.2278 - learning_rate: 2.4222e-04
# Epoch 125/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8601 - loss: 0.5782 - val_binary_dice_score: 1.5429e-13 - val_loss: 2.8270 - learning_rate: 2.4127e-04
# Epoch 126/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7930 - loss: 0.6296 - val_binary_dice_score: 0.3781 - val_loss: 1.1736 - learning_rate: 2.4031e-04
# Epoch 127/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7642 - loss: 0.7916 - val_binary_dice_score: 0.0751 - val_loss: 1.3994 - learning_rate: 2.3935e-04
# Epoch 128/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8542 - loss: 0.5219 - val_binary_dice_score: 1.3246e-13 - val_loss: 1.9485 - learning_rate: 2.3837e-04
# Epoch 129/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.9244 - loss: 0.3411 - val_binary_dice_score: 0.8550 - val_loss: 0.5527 - learning_rate: 2.3740e-04
# Epoch 130/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7917 - loss: 0.6832 - val_binary_dice_score: 1.2582e-13 - val_loss: 3.1854 - learning_rate: 2.3641e-04
# Epoch 131/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8660 - loss: 0.4851 - val_binary_dice_score: 1.2991e-13 - val_loss: 2.7085 - learning_rate: 2.3543e-04
# Epoch 132/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8504 - loss: 0.4854 - val_binary_dice_score: 2.5368e-05 - val_loss: 2.8911 - learning_rate: 2.3443e-04
# Epoch 133/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8685 - loss: 0.4134 - val_binary_dice_score: 1.2870e-13 - val_loss: 2.5437 - learning_rate: 2.3343e-04
# Epoch 134/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8719 - loss: 0.4403 - val_binary_dice_score: 1.5989e-13 - val_loss: 2.6727 - learning_rate: 2.3243e-04
# Epoch 135/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8574 - loss: 0.4806 - val_binary_dice_score: 0.0016 - val_loss: 2.0417 - learning_rate: 2.3142e-04
# Epoch 136/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8847 - loss: 0.4065 - val_binary_dice_score: 1.2881e-13 - val_loss: 2.7338 - learning_rate: 2.3040e-04
# Epoch 137/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.8623 - loss: 0.4544 - val_binary_dice_score: 0.8837 - val_loss: 0.3869 - learning_rate: 2.2938e-04
# Epoch 138/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8725 - loss: 0.4484 - val_binary_dice_score: 0.8656 - val_loss: 0.5454 - learning_rate: 2.2836e-04
# Epoch 139/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8561 - loss: 0.5616 - val_binary_dice_score: 0.1133 - val_loss: 1.4218 - learning_rate: 2.2733e-04
# Epoch 140/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8627 - loss: 0.4788 - val_binary_dice_score: 0.9193 - val_loss: 0.3496 - learning_rate: 2.2629e-04
# Epoch 141/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8690 - loss: 0.4436 - val_binary_dice_score: 0.0074 - val_loss: 2.4568 - learning_rate: 2.2525e-04
# Epoch 142/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7985 - loss: 0.7278 - val_binary_dice_score: 0.5613 - val_loss: 1.1076 - learning_rate: 2.2420e-04
# Epoch 143/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8284 - loss: 0.6028 - val_binary_dice_score: 0.0942 - val_loss: 1.9022 - learning_rate: 2.2315e-04
# Epoch 144/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8642 - loss: 0.4585 - val_binary_dice_score: 1.2903e-13 - val_loss: 2.9693 - learning_rate: 2.2210e-04
# Epoch 145/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8288 - loss: 0.5741 - val_binary_dice_score: 0.3429 - val_loss: 1.4846 - learning_rate: 2.2104e-04
# Epoch 146/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.7955 - loss: 0.6056 - val_binary_dice_score: 0.6625 - val_loss: 1.2743 - learning_rate: 2.1998e-04
# Epoch 147/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8625 - loss: 0.4294 - val_binary_dice_score: 0.9138 - val_loss: 0.3061 - learning_rate: 2.1891e-04
# Epoch 148/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.7913 - loss: 0.6512 - val_binary_dice_score: 0.8591 - val_loss: 0.5367 - learning_rate: 2.1783e-04
# Epoch 149/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9056 - loss: 0.3493 - val_binary_dice_score: 1.1665e-13 - val_loss: 3.7993 - learning_rate: 2.1676e-04
# Epoch 150/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8572 - loss: 0.4820 - val_binary_dice_score: 0.0043 - val_loss: 2.8059 - learning_rate: 2.1568e-04
# Epoch 151/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8441 - loss: 0.5377 - val_binary_dice_score: 1.6367e-13 - val_loss: 2.9146 - learning_rate: 2.1459e-04
# Epoch 152/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8625 - loss: 0.4597 - val_binary_dice_score: 1.6814e-06 - val_loss: 2.9523 - learning_rate: 2.1350e-04
# Epoch 153/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8806 - loss: 0.4055 - val_binary_dice_score: 0.0630 - val_loss: 2.1740 - learning_rate: 2.1241e-04
# Epoch 154/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8583 - loss: 0.4288 - val_binary_dice_score: 0.8889 - val_loss: 0.3741 - learning_rate: 2.1131e-04
# Epoch 155/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8599 - loss: 0.5061 - val_binary_dice_score: 0.8070 - val_loss: 0.6220 - learning_rate: 2.1021e-04
# Epoch 156/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8876 - loss: 0.4133 - val_binary_dice_score: 0.0142 - val_loss: 2.1328 - learning_rate: 2.0910e-04
# Epoch 157/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8696 - loss: 0.4308 - val_binary_dice_score: 0.1400 - val_loss: 1.6710 - learning_rate: 2.0799e-04
# Epoch 158/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8705 - loss: 0.4395 - val_binary_dice_score: 0.0168 - val_loss: 1.9471 - learning_rate: 2.0688e-04
# Epoch 159/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8786 - loss: 0.4805 - val_binary_dice_score: 0.5595 - val_loss: 1.2793 - learning_rate: 2.0576e-04
# Epoch 160/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8462 - loss: 0.5222 - val_binary_dice_score: 1.2827e-13 - val_loss: 3.1864 - learning_rate: 2.0464e-04
# Epoch 161/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8407 - loss: 0.5387 - val_binary_dice_score: 4.0831e-05 - val_loss: 2.5763 - learning_rate: 2.0351e-04
# Epoch 162/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8682 - loss: 0.4328 - val_binary_dice_score: 0.8662 - val_loss: 0.6431 - learning_rate: 2.0239e-04
# Epoch 163/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8583 - loss: 0.5077 - val_binary_dice_score: 0.9050 - val_loss: 0.3870 - learning_rate: 2.0125e-04
# Epoch 164/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.8935 - loss: 0.4284 - val_binary_dice_score: 0.8350 - val_loss: 0.5587 - learning_rate: 2.0012e-04
# Epoch 165/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.8758 - loss: 0.4849 - val_binary_dice_score: 1.3793e-13 - val_loss: 3.1114 - learning_rate: 1.9898e-04
# Epoch 166/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.8414 - loss: 0.6078 - val_binary_dice_score: 0.8337 - val_loss: 0.5595 - learning_rate: 1.9784e-04
# Epoch 167/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9026 - loss: 0.3357 - val_binary_dice_score: 1.3805e-13 - val_loss: 2.6982 - learning_rate: 1.9670e-04
# Epoch 168/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8804 - loss: 0.4071 - val_binary_dice_score: 1.0934e-13 - val_loss: 3.4750 - learning_rate: 1.9555e-04
# Epoch 169/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8333 - loss: 0.5583 - val_binary_dice_score: 0.0035 - val_loss: 2.4966 - learning_rate: 1.9440e-04
# Epoch 170/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8525 - loss: 0.4699 - val_binary_dice_score: 4.5116e-06 - val_loss: 2.7327 - learning_rate: 1.9325e-04
# Epoch 171/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9077 - loss: 0.3950 - val_binary_dice_score: 0.5164 - val_loss: 0.9924 - learning_rate: 1.9209e-04
# Epoch 172/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8689 - loss: 0.4415 - val_binary_dice_score: 0.0040 - val_loss: 1.7617 - learning_rate: 1.9094e-04
# Epoch 173/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8671 - loss: 0.4548 - val_binary_dice_score: 0.1408 - val_loss: 1.4871 - learning_rate: 1.8977e-04
# Epoch 174/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8421 - loss: 0.5263 - val_binary_dice_score: 9.8364e-05 - val_loss: 2.8755 - learning_rate: 1.8861e-04
# Epoch 175/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8831 - loss: 0.4351 - val_binary_dice_score: 3.8617e-05 - val_loss: 3.1730 - learning_rate: 1.8745e-04
# Epoch 176/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.7931 - loss: 0.6297 - val_binary_dice_score: 1.3663e-13 - val_loss: 2.9025 - learning_rate: 1.8628e-04
# Epoch 177/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8909 - loss: 0.4034 - val_binary_dice_score: 0.0308 - val_loss: 1.7652 - learning_rate: 1.8511e-04
# Epoch 178/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9035 - loss: 0.3612 - val_binary_dice_score: 0.2976 - val_loss: 1.0831 - learning_rate: 1.8393e-04
# Epoch 179/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8507 - loss: 0.4815 - val_binary_dice_score: 0.8575 - val_loss: 0.5048 - learning_rate: 1.8276e-04
# Epoch 180/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8768 - loss: 0.4380 - val_binary_dice_score: 0.9012 - val_loss: 0.3724 - learning_rate: 1.8158e-04
# Epoch 181/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8680 - loss: 0.4555 - val_binary_dice_score: 0.3129 - val_loss: 1.4152 - learning_rate: 1.8040e-04
# Epoch 182/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8914 - loss: 0.4337 - val_binary_dice_score: 0.0072 - val_loss: 2.8525 - learning_rate: 1.7922e-04
# Epoch 183/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8268 - loss: 0.5433 - val_binary_dice_score: 1.5912e-13 - val_loss: 2.7728 - learning_rate: 1.7804e-04
# Epoch 184/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - binary_dice_score: 0.8796 - loss: 0.5335 - val_binary_dice_score: 8.3540e-04 - val_loss: 2.6118 - learning_rate: 1.7686e-04
# Epoch 185/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8594 - loss: 0.4824 - val_binary_dice_score: 1.2772e-04 - val_loss: 2.3849 - learning_rate: 1.7567e-04
# Epoch 186/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8636 - loss: 0.4491 - val_binary_dice_score: 0.5135 - val_loss: 1.3110 - learning_rate: 1.7448e-04
# Epoch 187/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8951 - loss: 0.4104 - val_binary_dice_score: 0.8572 - val_loss: 0.4582 - learning_rate: 1.7329e-04
# Epoch 188/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8552 - loss: 0.4607 - val_binary_dice_score: 0.0012 - val_loss: 2.3578 - learning_rate: 1.7210e-04
# Epoch 189/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - binary_dice_score: 0.8785 - loss: 0.3996 - val_binary_dice_score: 0.0482 - val_loss: 2.0529 - learning_rate: 1.7091e-04
# Epoch 190/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.7978 - loss: 0.6118 - val_binary_dice_score: 0.8189 - val_loss: 0.5664 - learning_rate: 1.6972e-04
# Epoch 191/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8813 - loss: 0.4695 - val_binary_dice_score: 0.2729 - val_loss: 1.7072 - learning_rate: 1.6852e-04
# Epoch 192/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.9115 - loss: 0.3576 - val_binary_dice_score: 0.8805 - val_loss: 0.4541 - learning_rate: 1.6732e-04
# Epoch 193/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8551 - loss: 0.4525 - val_binary_dice_score: 1.5363e-13 - val_loss: 3.2393 - learning_rate: 1.6613e-04
# Epoch 194/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8240 - loss: 0.6151 - val_binary_dice_score: 0.0109 - val_loss: 2.1330 - learning_rate: 1.6493e-04
# Epoch 195/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8674 - loss: 0.4504 - val_binary_dice_score: 0.3168 - val_loss: 1.6014 - learning_rate: 1.6373e-04
# Epoch 196/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8930 - loss: 0.3850 - val_binary_dice_score: 1.3295e-13 - val_loss: 3.0691 - learning_rate: 1.6253e-04
# Epoch 197/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8861 - loss: 0.4644 - val_binary_dice_score: 0.9064 - val_loss: 0.3627 - learning_rate: 1.6133e-04
# Epoch 198/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8941 - loss: 0.3701 - val_binary_dice_score: 0.9030 - val_loss: 0.3652 - learning_rate: 1.6013e-04
# Epoch 199/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8621 - loss: 0.4552 - val_binary_dice_score: 0.9087 - val_loss: 0.3202 - learning_rate: 1.5893e-04
# Epoch 200/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - binary_dice_score: 0.8875 - loss: 0.3965 - val_binary_dice_score: 0.5692 - val_loss: 1.1788 - learning_rate: 1.5772e-04
# Epoch 201/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8427 - loss: 0.4790 - val_binary_dice_score: 3.5072e-06 - val_loss: 2.7822 - learning_rate: 1.5652e-04
# Epoch 202/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8878 - loss: 0.4243 - val_binary_dice_score: 0.9347 - val_loss: 0.2789 - learning_rate: 1.5532e-04
# Epoch 203/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8695 - loss: 0.4220 - val_binary_dice_score: 0.9125 - val_loss: 0.3836 - learning_rate: 1.5411e-04
# Epoch 204/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.8445 - loss: 0.5286 - val_binary_dice_score: 0.8767 - val_loss: 0.3870 - learning_rate: 1.5291e-04
# Epoch 205/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9169 - loss: 0.3206 - val_binary_dice_score: 0.6852 - val_loss: 1.1352 - learning_rate: 1.5170e-04
# Epoch 206/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8590 - loss: 0.4485 - val_binary_dice_score: 0.0076 - val_loss: 2.3996 - learning_rate: 1.5050e-04
# Epoch 207/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9038 - loss: 0.3647 - val_binary_dice_score: 0.8472 - val_loss: 0.5705 - learning_rate: 1.4930e-04
# Epoch 208/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.8657 - loss: 0.4322 - val_binary_dice_score: 0.8312 - val_loss: 0.5719 - learning_rate: 1.4809e-04
# Epoch 209/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.8833 - loss: 0.4170 - val_binary_dice_score: 0.4949 - val_loss: 1.5254 - learning_rate: 1.4689e-04
# Epoch 210/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.8844 - loss: 0.4057 - val_binary_dice_score: 0.8888 - val_loss: 0.3928 - learning_rate: 1.4568e-04
# Epoch 211/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.7784 - loss: 0.6510 - val_binary_dice_score: 0.9142 - val_loss: 0.3184 - learning_rate: 1.4448e-04
# Epoch 212/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8893 - loss: 0.3668 - val_binary_dice_score: 1.2387e-13 - val_loss: 3.6251 - learning_rate: 1.4328e-04
# Epoch 213/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8957 - loss: 0.3687 - val_binary_dice_score: 0.4615 - val_loss: 1.4151 - learning_rate: 1.4207e-04
# Epoch 214/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.8618 - loss: 0.4266 - val_binary_dice_score: 1.2737e-13 - val_loss: 2.9209 - learning_rate: 1.4087e-04
# Epoch 215/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8713 - loss: 0.4127 - val_binary_dice_score: 0.8910 - val_loss: 0.3746 - learning_rate: 1.3967e-04
# Epoch 216/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8813 - loss: 0.3929 - val_binary_dice_score: 0.3847 - val_loss: 1.5667 - learning_rate: 1.3847e-04
# Epoch 217/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8719 - loss: 0.4089 - val_binary_dice_score: 0.8703 - val_loss: 0.5878 - learning_rate: 1.3727e-04
# Epoch 218/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9088 - loss: 0.3364 - val_binary_dice_score: 1.6177e-13 - val_loss: 2.9070 - learning_rate: 1.3607e-04
# Epoch 219/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8821 - loss: 0.4076 - val_binary_dice_score: 1.2500e-13 - val_loss: 3.4509 - learning_rate: 1.3487e-04
# Epoch 220/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8905 - loss: 0.3773 - val_binary_dice_score: 0.8894 - val_loss: 0.3664 - learning_rate: 1.3368e-04
# Epoch 221/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8636 - loss: 0.4284 - val_binary_dice_score: 0.9318 - val_loss: 0.2770 - learning_rate: 1.3248e-04
# Epoch 222/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9007 - loss: 0.3996 - val_binary_dice_score: 0.9117 - val_loss: 0.3503 - learning_rate: 1.3128e-04
# Epoch 223/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8654 - loss: 0.4552 - val_binary_dice_score: 0.9147 - val_loss: 0.3212 - learning_rate: 1.3009e-04
# Epoch 224/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8600 - loss: 0.4663 - val_binary_dice_score: 0.9265 - val_loss: 0.3422 - learning_rate: 1.2890e-04
# Epoch 225/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8939 - loss: 0.3776 - val_binary_dice_score: 0.8924 - val_loss: 0.3763 - learning_rate: 1.2771e-04
# Epoch 226/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8846 - loss: 0.3496 - val_binary_dice_score: 0.9025 - val_loss: 0.3742 - learning_rate: 1.2652e-04
# Epoch 227/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8864 - loss: 0.3845 - val_binary_dice_score: 0.9041 - val_loss: 0.3392 - learning_rate: 1.2533e-04
# Epoch 228/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8891 - loss: 0.4119 - val_binary_dice_score: 0.9171 - val_loss: 0.2931 - learning_rate: 1.2414e-04
# Epoch 229/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.7992 - loss: 0.6808 - val_binary_dice_score: 0.9025 - val_loss: 0.4262 - learning_rate: 1.2296e-04
# Epoch 230/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8813 - loss: 0.3606 - val_binary_dice_score: 8.6850e-04 - val_loss: 3.0783 - learning_rate: 1.2178e-04
# Epoch 231/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.8440 - loss: 0.4827 - val_binary_dice_score: 0.6444 - val_loss: 1.2254 - learning_rate: 1.2060e-04
# Epoch 232/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.9212 - loss: 0.3242 - val_binary_dice_score: 0.8042 - val_loss: 0.6505 - learning_rate: 1.1942e-04
# Epoch 233/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.8957 - loss: 0.3779 - val_binary_dice_score: 0.9431 - val_loss: 0.2457 - learning_rate: 1.1824e-04
# Epoch 234/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.8838 - loss: 0.4001 - val_binary_dice_score: 0.8066 - val_loss: 0.7663 - learning_rate: 1.1707e-04
# Epoch 235/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8761 - loss: 0.4824 - val_binary_dice_score: 0.9349 - val_loss: 0.2537 - learning_rate: 1.1589e-04
# Epoch 236/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8756 - loss: 0.4490 - val_binary_dice_score: 0.9226 - val_loss: 0.2979 - learning_rate: 1.1472e-04
# Epoch 237/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8748 - loss: 0.4476 - val_binary_dice_score: 0.9027 - val_loss: 0.3985 - learning_rate: 1.1355e-04
# Epoch 238/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8931 - loss: 0.3746 - val_binary_dice_score: 0.0699 - val_loss: 2.2735 - learning_rate: 1.1239e-04
# Epoch 239/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8828 - loss: 0.4314 - val_binary_dice_score: 0.0440 - val_loss: 2.6056 - learning_rate: 1.1123e-04
# Epoch 240/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8794 - loss: 0.4187 - val_binary_dice_score: 0.5571 - val_loss: 1.5791 - learning_rate: 1.1006e-04
# Epoch 241/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.9253 - loss: 0.2842 - val_binary_dice_score: 0.9160 - val_loss: 0.3158 - learning_rate: 1.0891e-04
# Epoch 242/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8865 - loss: 0.3920 - val_binary_dice_score: 0.0940 - val_loss: 2.2528 - learning_rate: 1.0775e-04
# Epoch 243/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.9152 - loss: 0.3256 - val_binary_dice_score: 0.8873 - val_loss: 0.3720 - learning_rate: 1.0660e-04
# Epoch 244/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8358 - loss: 0.5862 - val_binary_dice_score: 0.9191 - val_loss: 0.2799 - learning_rate: 1.0545e-04
# Epoch 245/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.9082 - loss: 0.3237 - val_binary_dice_score: 0.9281 - val_loss: 0.2694 - learning_rate: 1.0430e-04
# Epoch 246/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.9007 - loss: 0.3398 - val_binary_dice_score: 0.4518 - val_loss: 1.7534 - learning_rate: 1.0316e-04
# Epoch 247/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.9252 - loss: 0.2684 - val_binary_dice_score: 0.7916 - val_loss: 0.7317 - learning_rate: 1.0202e-04
# Epoch 248/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.9167 - loss: 0.3074 - val_binary_dice_score: 0.9284 - val_loss: 0.2811 - learning_rate: 1.0088e-04
# Epoch 249/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8870 - loss: 0.3837 - val_binary_dice_score: 0.8487 - val_loss: 0.5032 - learning_rate: 9.9745e-05
# Epoch 250/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.8787 - loss: 0.4291 - val_binary_dice_score: 0.5345 - val_loss: 1.6528 - learning_rate: 9.8614e-05
# Epoch 251/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.9014 - loss: 0.3648 - val_binary_dice_score: 0.7945 - val_loss: 0.6532 - learning_rate: 9.7487e-05
# Epoch 252/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8839 - loss: 0.3699 - val_binary_dice_score: 0.2335 - val_loss: 2.2084 - learning_rate: 9.6362e-05
# Epoch 253/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8769 - loss: 0.4120 - val_binary_dice_score: 0.6213 - val_loss: 1.3261 - learning_rate: 9.5242e-05
# Epoch 254/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8821 - loss: 0.4160 - val_binary_dice_score: 0.8213 - val_loss: 0.5864 - learning_rate: 9.4124e-05
# Epoch 255/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8703 - loss: 0.4650 - val_binary_dice_score: 0.0751 - val_loss: 2.5010 - learning_rate: 9.3011e-05
# Epoch 256/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8953 - loss: 0.3481 - val_binary_dice_score: 0.7374 - val_loss: 0.8726 - learning_rate: 9.1901e-05
# Epoch 257/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8636 - loss: 0.4328 - val_binary_dice_score: 0.2642 - val_loss: 2.2804 - learning_rate: 9.0795e-05
# Epoch 258/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9051 - loss: 0.3369 - val_binary_dice_score: 0.8158 - val_loss: 0.6306 - learning_rate: 8.9693e-05
# Epoch 259/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8855 - loss: 0.3661 - val_binary_dice_score: 0.8871 - val_loss: 0.3956 - learning_rate: 8.8595e-05
# Epoch 260/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9016 - loss: 0.3391 - val_binary_dice_score: 0.8748 - val_loss: 0.4408 - learning_rate: 8.7501e-05
# Epoch 261/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8887 - loss: 0.4063 - val_binary_dice_score: 0.7211 - val_loss: 0.8407 - learning_rate: 8.6410e-05
# Epoch 262/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8289 - loss: 0.4897 - val_binary_dice_score: 0.4776 - val_loss: 1.5291 - learning_rate: 8.5325e-05
# Epoch 263/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9120 - loss: 0.3455 - val_binary_dice_score: 0.1936 - val_loss: 2.3649 - learning_rate: 8.4243e-05
# Epoch 264/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.9313 - loss: 0.2674 - val_binary_dice_score: 0.3480 - val_loss: 1.9782 - learning_rate: 8.3165e-05
# Epoch 265/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8370 - loss: 0.5128 - val_binary_dice_score: 0.9178 - val_loss: 0.3110 - learning_rate: 8.2092e-05
# Epoch 266/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8997 - loss: 0.3297 - val_binary_dice_score: 0.6325 - val_loss: 1.4426 - learning_rate: 8.1024e-05
# Epoch 267/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - binary_dice_score: 0.8982 - loss: 0.3608 - val_binary_dice_score: 6.3083e-05 - val_loss: 2.9015 - learning_rate: 7.9960e-05
# Epoch 268/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8889 - loss: 0.4011 - val_binary_dice_score: 0.9209 - val_loss: 0.2858 - learning_rate: 7.8900e-05
# Epoch 269/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8694 - loss: 0.4717 - val_binary_dice_score: 0.8503 - val_loss: 0.4785 - learning_rate: 7.7845e-05
# Epoch 270/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8857 - loss: 0.3485 - val_binary_dice_score: 0.8031 - val_loss: 0.5760 - learning_rate: 7.6795e-05
# Epoch 271/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8963 - loss: 0.3716 - val_binary_dice_score: 0.8281 - val_loss: 0.5393 - learning_rate: 7.5750e-05
# Epoch 272/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.8714 - loss: 0.4533 - val_binary_dice_score: 0.4754 - val_loss: 1.9194 - learning_rate: 7.4710e-05
# Epoch 273/400
# ...
# Epoch 310/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9049 - loss: 0.3196 - val_binary_dice_score: 0.8629 - val_loss: 0.5186 - learning_rate: 3.9400e-05
# Epoch 311/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9193 - loss: 0.2834 - val_binary_dice_score: 0.8076 - val_loss: 0.6941 - learning_rate: 3.8598e-05
# Epoch 312/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9134 - loss: 0.3405 - val_binary_dice_score: 0.9030 - val_loss: 0.3503 - learning_rate: 3.7803e-05
# Epoch 313/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9278 - loss: 0.2885 - val_binary_dice_score: 0.9221 - val_loss: 0.3018 - learning_rate: 3.7015e-05
# Epoch 314/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9259 - loss: 0.3204 - val_binary_dice_score: 0.9073 - val_loss: 0.3757 - learning_rate: 3.6235e-05
# Epoch 315/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.8881 - loss: 0.3950 - val_binary_dice_score: 0.9181 - val_loss: 0.2770 - learning_rate: 3.5462e-05
# Epoch 316/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8226 - loss: 0.4920 - val_binary_dice_score: 0.9339 - val_loss: 0.2756 - learning_rate: 3.4697e-05
# Epoch 317/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9142 - loss: 0.3186 - val_binary_dice_score: 0.9302 - val_loss: 0.2626 - learning_rate: 3.3939e-05
# Epoch 318/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.8991 - loss: 0.3279 - val_binary_dice_score: 0.9234 - val_loss: 0.2463 - learning_rate: 3.3188e-05
# Epoch 319/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8181 - loss: 0.6329 - val_binary_dice_score: 0.8927 - val_loss: 0.3868 - learning_rate: 3.2446e-05
# Epoch 320/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9010 - loss: 0.3447 - val_binary_dice_score: 0.9376 - val_loss: 0.2630 - learning_rate: 3.1711e-05
# Epoch 321/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.9153 - loss: 0.2804 - val_binary_dice_score: 0.9394 - val_loss: 0.2445 - learning_rate: 3.0983e-05
# Epoch 322/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9056 - loss: 0.3389 - val_binary_dice_score: 0.9382 - val_loss: 0.2307 - learning_rate: 3.0264e-05
# Epoch 323/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9116 - loss: 0.3593 - val_binary_dice_score: 0.9171 - val_loss: 0.3040 - learning_rate: 2.9552e-05
# Epoch 324/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9174 - loss: 0.3036 - val_binary_dice_score: 0.9178 - val_loss: 0.2990 - learning_rate: 2.8848e-05
# Epoch 325/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9049 - loss: 0.3518 - val_binary_dice_score: 0.9358 - val_loss: 0.2580 - learning_rate: 2.8152e-05
# Epoch 326/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9146 - loss: 0.3182 - val_binary_dice_score: 0.9416 - val_loss: 0.2403 - learning_rate: 2.7464e-05
# Epoch 327/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9033 - loss: 0.3060 - val_binary_dice_score: 0.9247 - val_loss: 0.3083 - learning_rate: 2.6784e-05
# Epoch 328/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8850 - loss: 0.3672 - val_binary_dice_score: 0.9370 - val_loss: 0.2409 - learning_rate: 2.6112e-05
# Epoch 329/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9229 - loss: 0.2592 - val_binary_dice_score: 0.9025 - val_loss: 0.3725 - learning_rate: 2.5448e-05
# Epoch 330/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9031 - loss: 0.3382 - val_binary_dice_score: 0.9182 - val_loss: 0.2944 - learning_rate: 2.4792e-05
# Epoch 331/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8996 - loss: 0.3365 - val_binary_dice_score: 0.8939 - val_loss: 0.4072 - learning_rate: 2.4144e-05
# Epoch 332/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9149 - loss: 0.3629 - val_binary_dice_score: 0.9418 - val_loss: 0.2266 - learning_rate: 2.3505e-05
# Epoch 333/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8090 - loss: 0.6310 - val_binary_dice_score: 0.9154 - val_loss: 0.3244 - learning_rate: 2.2873e-05
# Epoch 334/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8964 - loss: 0.3933 - val_binary_dice_score: 0.9252 - val_loss: 0.2591 - learning_rate: 2.2250e-05
# Epoch 335/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9172 - loss: 0.2938 - val_binary_dice_score: 0.9291 - val_loss: 0.2677 - learning_rate: 2.1636e-05
# Epoch 336/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.8765 - loss: 0.4244 - val_binary_dice_score: 0.9375 - val_loss: 0.2672 - learning_rate: 2.1029e-05
# Epoch 337/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9130 - loss: 0.3062 - val_binary_dice_score: 0.9188 - val_loss: 0.2915 - learning_rate: 2.0431e-05
# Epoch 338/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9328 - loss: 0.2861 - val_binary_dice_score: 0.9352 - val_loss: 0.2590 - learning_rate: 1.9842e-05
# Epoch 339/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9258 - loss: 0.2599 - val_binary_dice_score: 0.9454 - val_loss: 0.2236 - learning_rate: 1.9261e-05
# Epoch 340/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8820 - loss: 0.3551 - val_binary_dice_score: 0.9206 - val_loss: 0.2995 - learning_rate: 1.8688e-05
# Epoch 341/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9024 - loss: 0.2991 - val_binary_dice_score: 0.9409 - val_loss: 0.2280 - learning_rate: 1.8124e-05
# Epoch 342/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9178 - loss: 0.3128 - val_binary_dice_score: 0.9190 - val_loss: 0.3076 - learning_rate: 1.7569e-05
# Epoch 343/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8856 - loss: 0.4080 - val_binary_dice_score: 0.9021 - val_loss: 0.3507 - learning_rate: 1.7022e-05
# Epoch 344/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - binary_dice_score: 0.8764 - loss: 0.4317 - val_binary_dice_score: 0.9422 - val_loss: 0.2463 - learning_rate: 1.6484e-05
# Epoch 345/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9123 - loss: 0.3149 - val_binary_dice_score: 0.9149 - val_loss: 0.3060 - learning_rate: 1.5955e-05
# Epoch 346/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9077 - loss: 0.3433 - val_binary_dice_score: 0.9413 - val_loss: 0.2136 - learning_rate: 1.5434e-05
# Epoch 347/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9078 - loss: 0.3306 - val_binary_dice_score: 0.9494 - val_loss: 0.2119 - learning_rate: 1.4922e-05
# Epoch 348/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9317 - loss: 0.2436 - val_binary_dice_score: 0.9147 - val_loss: 0.3412 - learning_rate: 1.4419e-05
# Epoch 349/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8963 - loss: 0.3774 - val_binary_dice_score: 0.9274 - val_loss: 0.2934 - learning_rate: 1.3925e-05
# Epoch 350/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8956 - loss: 0.3463 - val_binary_dice_score: 0.9173 - val_loss: 0.2773 - learning_rate: 1.3440e-05
# Epoch 351/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.9364 - loss: 0.2429 - val_binary_dice_score: 0.9316 - val_loss: 0.2700 - learning_rate: 1.2963e-05
# Epoch 352/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.9297 - loss: 0.2350 - val_binary_dice_score: 0.9290 - val_loss: 0.2576 - learning_rate: 1.2496e-05
# Epoch 353/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9195 - loss: 0.2964 - val_binary_dice_score: 0.8939 - val_loss: 0.3268 - learning_rate: 1.2037e-05
# Epoch 354/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9146 - loss: 0.3148 - val_binary_dice_score: 0.9361 - val_loss: 0.2518 - learning_rate: 1.1587e-05
# Epoch 355/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9102 - loss: 0.3691 - val_binary_dice_score: 0.9303 - val_loss: 0.2678 - learning_rate: 1.1147e-05
# Epoch 356/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9109 - loss: 0.2891 - val_binary_dice_score: 0.9408 - val_loss: 0.2236 - learning_rate: 1.0715e-05
# Epoch 357/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9388 - loss: 0.2478 - val_binary_dice_score: 0.9386 - val_loss: 0.2381 - learning_rate: 1.0293e-05
# Epoch 358/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9394 - loss: 0.2445 - val_binary_dice_score: 0.9400 - val_loss: 0.2367 - learning_rate: 9.8792e-06
# Epoch 359/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9000 - loss: 0.3638 - val_binary_dice_score: 0.9120 - val_loss: 0.3284 - learning_rate: 9.4749e-06
# Epoch 360/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9196 - loss: 0.2680 - val_binary_dice_score: 0.8814 - val_loss: 0.3538 - learning_rate: 9.0798e-06
# Epoch 361/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9184 - loss: 0.2908 - val_binary_dice_score: 0.9154 - val_loss: 0.2879 - learning_rate: 8.6938e-06
# Epoch 362/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - binary_dice_score: 0.9136 - loss: 0.3225 - val_binary_dice_score: 0.9014 - val_loss: 0.3582 - learning_rate: 8.3171e-06
# Epoch 363/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8939 - loss: 0.4047 - val_binary_dice_score: 0.9449 - val_loss: 0.2356 - learning_rate: 7.9495e-06
# Epoch 364/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8884 - loss: 0.4136 - val_binary_dice_score: 0.9315 - val_loss: 0.2680 - learning_rate: 7.5913e-06
# Epoch 365/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9088 - loss: 0.3430 - val_binary_dice_score: 0.9061 - val_loss: 0.3524 - learning_rate: 7.2422e-06
# Epoch 366/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9164 - loss: 0.3215 - val_binary_dice_score: 0.9385 - val_loss: 0.2507 - learning_rate: 6.9025e-06
# Epoch 367/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - binary_dice_score: 0.9199 - loss: 0.3188 - val_binary_dice_score: 0.9266 - val_loss: 0.2542 - learning_rate: 6.5722e-06
# Epoch 368/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9303 - loss: 0.2837 - val_binary_dice_score: 0.9525 - val_loss: 0.1965 - learning_rate: 6.2511e-06
# Epoch 369/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9130 - loss: 0.3488 - val_binary_dice_score: 0.9218 - val_loss: 0.2520 - learning_rate: 5.9394e-06
# Epoch 370/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9284 - loss: 0.2727 - val_binary_dice_score: 0.9106 - val_loss: 0.3366 - learning_rate: 5.6371e-06
# Epoch 371/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9157 - loss: 0.3358 - val_binary_dice_score: 0.9408 - val_loss: 0.2531 - learning_rate: 5.3442e-06
# Epoch 372/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8465 - loss: 0.5528 - val_binary_dice_score: 0.9153 - val_loss: 0.3058 - learning_rate: 5.0607e-06
# Epoch 373/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9020 - loss: 0.4289 - val_binary_dice_score: 0.9275 - val_loss: 0.2811 - learning_rate: 4.7867e-06
# Epoch 374/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9174 - loss: 0.2931 - val_binary_dice_score: 0.8881 - val_loss: 0.4566 - learning_rate: 4.5221e-06
# Epoch 375/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9076 - loss: 0.2928 - val_binary_dice_score: 0.9092 - val_loss: 0.3415 - learning_rate: 4.2669e-06
# Epoch 376/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9072 - loss: 0.2981 - val_binary_dice_score: 0.9399 - val_loss: 0.2706 - learning_rate: 4.0213e-06
# Epoch 377/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9145 - loss: 0.3047 - val_binary_dice_score: 0.9208 - val_loss: 0.2926 - learning_rate: 3.7852e-06
# Epoch 378/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8896 - loss: 0.3903 - val_binary_dice_score: 0.9003 - val_loss: 0.3914 - learning_rate: 3.5586e-06
# Epoch 379/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9218 - loss: 0.3113 - val_binary_dice_score: 0.9074 - val_loss: 0.3307 - learning_rate: 3.3415e-06
# Epoch 380/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8868 - loss: 0.5603 - val_binary_dice_score: 0.9276 - val_loss: 0.2683 - learning_rate: 3.1340e-06
# Epoch 381/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9051 - loss: 0.3540 - val_binary_dice_score: 0.9363 - val_loss: 0.2298 - learning_rate: 2.9360e-06
# Epoch 382/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9005 - loss: 0.3381 - val_binary_dice_score: 0.9048 - val_loss: 0.3387 - learning_rate: 2.7476e-06
# Epoch 383/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9349 - loss: 0.2521 - val_binary_dice_score: 0.9141 - val_loss: 0.2850 - learning_rate: 2.5688e-06
# Epoch 384/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.9241 - loss: 0.2734 - val_binary_dice_score: 0.9385 - val_loss: 0.2261 - learning_rate: 2.3996e-06
# Epoch 385/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9056 - loss: 0.3194 - val_binary_dice_score: 0.9191 - val_loss: 0.2629 - learning_rate: 2.2400e-06
# Epoch 386/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9156 - loss: 0.3009 - val_binary_dice_score: 0.9477 - val_loss: 0.1998 - learning_rate: 2.0900e-06
# Epoch 387/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9119 - loss: 0.3237 - val_binary_dice_score: 0.9256 - val_loss: 0.2735 - learning_rate: 1.9497e-06
# Epoch 388/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9298 - loss: 0.2648 - val_binary_dice_score: 0.9400 - val_loss: 0.2312 - learning_rate: 1.8190e-06
# Epoch 389/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9165 - loss: 0.2917 - val_binary_dice_score: 0.9375 - val_loss: 0.2271 - learning_rate: 1.6979e-06
# Epoch 390/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9078 - loss: 0.3470 - val_binary_dice_score: 0.8976 - val_loss: 0.3703 - learning_rate: 1.5865e-06
# Epoch 391/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - binary_dice_score: 0.8933 - loss: 0.3590 - val_binary_dice_score: 0.8937 - val_loss: 0.3645 - learning_rate: 1.4848e-06
# Epoch 392/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 75s 4s/step - binary_dice_score: 0.9220 - loss: 0.2839 - val_binary_dice_score: 0.9380 - val_loss: 0.2456 - learning_rate: 1.3927e-06
# Epoch 393/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - binary_dice_score: 0.9154 - loss: 0.2905 - val_binary_dice_score: 0.9239 - val_loss: 0.2889 - learning_rate: 1.3103e-06
# Epoch 394/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9122 - loss: 0.2924 - val_binary_dice_score: 0.9494 - val_loss: 0.2022 - learning_rate: 1.2376e-06
# Epoch 395/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - binary_dice_score: 0.9265 - loss: 0.2785 - val_binary_dice_score: 0.9438 - val_loss: 0.2214 - learning_rate: 1.1746e-06
# Epoch 396/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - binary_dice_score: 0.9135 - loss: 0.2968 - val_binary_dice_score: 0.9560 - val_loss: 0.1778 - learning_rate: 1.1212e-06
# Epoch 397/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8764 - loss: 0.4173 - val_binary_dice_score: 0.8767 - val_loss: 0.4188 - learning_rate: 1.0776e-06
# Epoch 398/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - binary_dice_score: 0.9398 - loss: 0.2216 - val_binary_dice_score: 0.8985 - val_loss: 0.3399 - learning_rate: 1.0437e-06
# Epoch 399/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8955 - loss: 0.3681 - val_binary_dice_score: 0.9044 - val_loss: 0.3539 - learning_rate: 1.0194e-06
# Epoch 400/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - binary_dice_score: 0.8905 - loss: 0.3988 - val_binary_dice_score: 0.9051 - val_loss: 0.3266 - learning_rate: 1.0049e-06
#
# Best val Dice: 0.0000

# %%
metric_key = [k for k in history.history.keys() if "dice" in k and "val" not in k][0]
val_metric_key = [k for k in history.history.keys() if "dice" in k and "val" in k][0]

fig, axes = plt.subplots(1, 3, figsize=(18, 4))

axes[0].plot(history.history["loss"],     label="Train", alpha=0.8)
axes[0].plot(history.history["val_loss"], label="Val", alpha=0.8)
axes[0].set_title("Loss"); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history[metric_key],     label="Train", alpha=0.8)
axes[1].plot(history.history[val_metric_key], label="Val", alpha=0.8)
axes[1].axhline(y=0.90, color='red', linestyle='--', alpha=0.5, label='Target')
axes[1].set_title("Dice"); axes[1].set_ylim(0, 1)
axes[1].legend(); axes[1].grid(alpha=0.3)

n = len(history.history["loss"])
axes[2].plot([warmup_cosine_lr(e, None) for e in range(n)])
axes[2].set_title("LR"); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(str(OUT_DIR / "training_curves.png"), dpi=150)
plt.show()

final_train = history.history[metric_key][-1]
final_val   = history.history[val_metric_key][-1]
print(f"Train Dice: {final_train:.4f}  Val Dice: {final_val:.4f}  Gap: {final_train - final_val:.4f}")
# Out:
# Train Dice: 0.8838  Val Dice: 0.9051  Gap: -0.0213

# %%
from medicai.utils.inference import SlidingWindowInference

def predict_volume(model, image_path, label_path):
    data, meta = load_pair(image_path, label_path)
    pre = Compose([
        ScaleIntensityRange(
            keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForeground(keys=("image", "label"), source_key="image"),
    ])
    out = pre(data, meta)
    ct = out["image"]
    gt = out["label"]
    if hasattr(ct, "numpy"): ct = ct.numpy()
    if hasattr(gt, "numpy"): gt = gt.numpy()

    swi = SlidingWindowInference(
        model=model, num_classes=1, roi_size=CROP_SHAPE,
        sw_batch_size=2, overlap=0.5, mode='gaussian',
    )
    pred     = np.array(swi(ct[np.newaxis]))[0]
    pred_bin = (1.0 / (1.0 + np.exp(-pred)) > 0.5).astype(np.float32)
    inter    = (pred_bin * gt).sum()
    dice     = float(2.0 * inter / (pred_bin.sum() + gt.sum() + 1e-6))
    return ct, gt, pred_bin, dice

# %%
best_model = AttentionUNet(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='densenet121',
    classifier_activation=None,
)

best_model.load_weights(
    str(OUT_DIR / "best_model.keras"),
)

best_model.compile(
  optimizer=keras.optimizers.AdamW(
    learning_rate=MIN_LR,
    weight_decay=WEIGHT_DECAY
  ),
  loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
  metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)
results = []
for p in val_pairs:
    _, _, _, dice = predict_volume(best_model, p["image"], p["label"])
    results.append({"scan_id": p["scan_id"], "dice": dice})
    print(f"  {p['scan_id']}  Dice={dice:.4f}")

dices = [r["dice"] for r in results]
print(f"\nMean={np.mean(dices):.4f}  Std={np.std(dices):.4f}  Min={np.min(dices):.4f}  Max={np.max(dices):.4f}")
# Out:
# Total patch 48: 100%|██████████| 24/24 [00:11<00:00,  2.12it/s]
#   be9fa3df918a  Dice=0.9298
# Total patch 48: 100%|██████████| 24/24 [00:11<00:00,  2.09it/s]
#   092c97ecec4b  Dice=0.9162
# Total patch 75: 100%|██████████| 38/38 [00:18<00:00,  2.10it/s]
#   ed66d74f6692  Dice=0.8925
# Total patch 48: 100%|██████████| 24/24 [00:11<00:00,  2.10it/s]
#   d86566fdb41c  Dice=0.9210
# Total patch 27: 100%|██████████| 14/14 [00:06<00:00,  2.09it/s]
#   2eb903f4f204  Dice=0.9285
# Total patch 32: 100%|██████████| 16/16 [00:07<00:00,  2.08it/s]
#   4d9723eef946  Dice=0.8881
# Total patch 75: 100%|██████████| 38/38 [00:17<00:00,  2.12it/s]
#   43ca4b1f6495  Dice=0.9331
# Total patch 32: 100%|██████████| 16/16 [00:07<00:00,  2.10it/s]
#   8781c0349102  Dice=0.7481
#
# Mean=0.8947  Std=0.0576  Min=0.7481  Max=0.9331

# %%
def visualise(ct, gt, pred, scan_id, dice, n_slices=6):
    D = ct.shape[0]
    idxs = np.linspace(D // 4, 3 * D // 4, n_slices, dtype=int)
    fig, axes = plt.subplots(3, n_slices, figsize=(3 * n_slices, 9))
    fig.suptitle(f"{scan_id}  Dice={dice:.4f}", fontsize=13, fontweight="bold")
    for col, idx in enumerate(idxs):
        s, g, p = ct[idx,:,:,0], gt[idx,:,:,0], pred[idx,:,:,0]
        axes[0,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[0,col].set_title(f"CT z={idx}", fontsize=8); axes[0,col].axis("off")
        axes[1,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[1,col].imshow(g, cmap="Reds",  alpha=0.45)
        axes[1,col].set_title("GT", fontsize=8); axes[1,col].axis("off")
        axes[2,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[2,col].imshow(p, cmap="Blues", alpha=0.45)
        axes[2,col].set_title("Pred", fontsize=8); axes[2,col].axis("off")
    plt.tight_layout()
    plt.savefig(str(OUT_DIR / f"{scan_id}_pred.png"), dpi=150, bbox_inches="tight")
    plt.show()

for res in [max(results, key=lambda r: r["dice"]), min(results, key=lambda r: r["dice"])]:
    p = next(x for x in val_pairs if x["scan_id"] == res["scan_id"])
    ct, gt, pred, dice = predict_volume(best_model, p["image"], p["label"])
    visualise(ct, gt, pred, res["scan_id"], dice)
# Out:
# Total patch 75: 100%|██████████| 38/38 [00:18<00:00,  2.10it/s]
# Total patch 32: 100%|██████████| 16/16 [00:07<00:00,  2.08it/s]

# %%
stats = {
    "model":         "UNet_resnet18",
    "backend":       keras.config.backend(),
    "mean_dice":     round(float(np.mean(dices)), 4),
    "std_dice":      round(float(np.std(dices)),  4),
    "n_train":       len(train_pairs),
    "n_val":         len(val_pairs),
    "crop_shape":    list(CROP_SHAPE),
    "hu_window":     [HU_MIN, HU_MAX],
    "epochs_trained": len(history.history["loss"]),
    "best_val_dice": round(float(max(history.history.get("val_binary_dice_metric", [0]))), 4),
    "total_params":  model.count_params(),
    "weight_decay":  WEIGHT_DECAY,
    "num_samples":   NUM_SAMPLES,
    "per_scan":      results,
}
with open(OUT_DIR / "eval_stats.json", "w") as f:
    json.dump(stats, f, indent=2)
print(json.dumps({k: v for k, v in stats.items() if k != "per_scan"}, indent=2))
# Out:
# {
#   "model": "UNet_resnet18",
#   "backend": "torch",
#   "mean_dice": 0.8947,
#   "std_dice": 0.0576,
#   "n_train": 39,
#   "n_val": 8,
#   "crop_shape": [
#     128,
#     128,
#     128
#   ],
#   "hu_window": [
#     -175,
#     400
#   ],
#   "epochs_trained": 400,
#   "best_val_dice": 0.0,
#   "total_params": 31933813,
#   "weight_decay": 0.0005,
#   "num_samples": 1
# }
