# %%
# !pip install git+https://github.com/innat/medic-ai.git -q
# !pip install scikit-learn nibabel -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for medicai (pyproject.toml) ... done

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import json
import math
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split

import keras
import torch

from medicai.models import UNet,AttentionUNet,TransUNet,SwinUNETR,SegFormer
from medicai.losses import BinaryDiceCELoss
from medicai.metrics import BinaryDiceMetric
from medicai.transforms import (
    Compose,
    ScaleIntensityRange,
    CropForeground,
    RandCropByPosNegLabel,
    RandFlip,
    RandRotate90,
    RandShiftIntensity,
)

print(f"Backend : {keras.config.backend()}")
print(f"Keras   : {keras.version()}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
    print(f"VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# 2026-03-24 15:45:44.769007: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774367144.987633      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774367145.052585      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774367145.538099      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774367145.538148      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774367145.538150      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774367145.538153      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Backend : torch
# Keras   : 3.10.0
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
CT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/gsoc-coca-segment/data_totalseg/inputs")
GT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/coca-gt/kaggle/working/gsoc-coca-gt")
OUT_DIR = Path("/kaggle/working/heart_seg_output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
CROP_SHAPE    = (160, 160, 160)
HU_MIN        = -175
HU_MAX        = 400
BATCH_SIZE    = 2
NUM_SAMPLES   = 1
EPOCHS        = 400
WARMUP_EPOCHS = 10
LEARNING_RATE = 3e-4
MIN_LR        = 1e-6
WEIGHT_DECAY  = 5e-4
VAL_SPLIT     = 0.15
SEED          = 50

# %%
import medicai
print(medicai.models.list_models())
# Out:
#                      Model Registry Catalog
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Segmentor        ┃ Backbone Family ┃ Variants                 ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ • attention_unet │ convnext        │ • convnext_base          │
# │ • deeplabv3plus  │                 │ • convnext_large         │
# │ • unet           │                 │ • convnext_small         │
# │ • unet_plus_plus │                 │ • convnext_tiny          │
# │ • upernet        │                 │ • convnext_v2_atto       │
# │                  │                 │ • convnext_v2_base       │
# │                  │                 │ • convnext_v2_femto      │
# │                  │                 │ • convnext_v2_huge       │
# │                  │                 │ • convnext_v2_large      │
# │                  │                 │ • convnext_v2_nano       │
# │                  │                 │ • convnext_v2_pico       │
# │                  │                 │ • convnext_v2_small      │
# │                  │                 │ • convnext_v2_tiny       │
# │                  │                 │ • convnext_xlarge        │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ densenet        │ • densenet121            │
# │ • deeplabv3plus  │                 │ • densenet169            │
# │ • trans_unet     │                 │ • densenet201            │
# │ • unet           │                 │ • densenet264            │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ efficientnet    │ • efficientnet_b0        │
# │ • deeplabv3plus  │                 │ • efficientnet_b1        │
# │ • trans_unet     │                 │ • efficientnet_b2        │
# │ • unet           │                 │ • efficientnet_b3        │
# │ • unet_plus_plus │                 │ • efficientnet_b4        │
# │ • upernet        │                 │ • efficientnet_b5        │
# │                  │                 │ • efficientnet_b6        │
# │                  │                 │ • efficientnet_b7        │
# │                  │                 │ • efficientnet_b8        │
# │                  │                 │ • efficientnet_l2        │
# │                  │                 │ • efficientnet_v2_b0     │
# │                  │                 │ • efficientnet_v2_b1     │
# │                  │                 │ • efficientnet_v2_b2     │
# │                  │                 │ • efficientnet_v2_b3     │
# │                  │                 │ • efficientnet_v2_l      │
# │                  │                 │ • efficientnet_v2_m      │
# │                  │                 │ • efficientnet_v2_s      │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • segformer      │ mit             │ • mit_b0                 │
# │ • upernet        │                 │ • mit_b1                 │
# │                  │                 │ • mit_b2                 │
# │                  │                 │ • mit_b3                 │
# │                  │                 │ • mit_b4                 │
# │                  │                 │ • mit_b5                 │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ resnet          │ • resnet101              │
# │ • deeplabv3plus  │                 │ • resnet101_v2           │
# │ • trans_unet     │                 │ • resnet152              │
# │ • unet           │                 │ • resnet152_v2           │
# │ • unet_plus_plus │                 │ • resnet18               │
# │ • upernet        │                 │ • resnet200_vd           │
# │                  │                 │ • resnet34               │
# │                  │                 │ • resnet50               │
# │                  │                 │ • resnet50_v2            │
# │                  │                 │ • resnet50_vd            │
# │                  │                 │ • resnext101             │
# │                  │                 │ • resnext50              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ senet           │ • seresnet101            │
# │ • deeplabv3plus  │                 │ • seresnet101_v2         │
# │ • trans_unet     │                 │ • seresnet152            │
# │ • unet           │                 │ • seresnet152_v2         │
# │ • unet_plus_plus │                 │ • seresnet18             │
# │ • upernet        │                 │ • seresnet200_vd         │
# │                  │                 │ • seresnet34             │
# │                  │                 │ • seresnet50             │
# │                  │                 │ • seresnet50_v2          │
# │                  │                 │ • seresnet50_vd          │
# │                  │                 │ • seresnext101           │
# │                  │                 │ • seresnext50            │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • swin_unetr     │ swin            │ • swin_base              │
# │ • upernet        │                 │ • swin_base_v2           │
# │                  │                 │ • swin_small             │
# │                  │                 │ • swin_small_v2          │
# │                  │                 │ • swin_tiny              │
# │                  │                 │ • swin_tiny_v2           │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr_plusplus │ unetr_plusplus  │ • unetr_plusplus_encoder │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr          │ vit             │ • vit_base               │
# │                  │                 │ • vit_huge               │
# │                  │                 │ • vit_large              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ xception        │ • xception               │
# │ • trans_unet     │                 │                          │
# │ • unet           │                 │                          │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# └──────────────────┴─────────────────┴──────────────────────────┘

# %%
def discover_pairs(ct_dir, gt_dir):
    pairs = []
    for ct_path in sorted(list(ct_dir.glob("*_img.nii.gz")) + list(ct_dir.glob("*_img.nii"))):
        scan_id = ct_path.name.replace("_img.nii.gz", "").replace("_img.nii", "")
        for ext in (".nii.gz", ".nii"):
            gt_path = gt_dir / scan_id / f"{scan_id}_binary{ext}"
            if gt_path.exists():
                pairs.append({"scan_id": scan_id, "image": str(ct_path), "label": str(gt_path)})
                break
    return pairs

pairs = discover_pairs(CT_DIR, GT_DIR)
print(f"Found {len(pairs)} pairs")

train_pairs, val_pairs = train_test_split(pairs, test_size=VAL_SPLIT, random_state=SEED)
print(f"Train={len(train_pairs)}  Val={len(val_pairs)}")
# Out:
# Found 47 pairs
# Train=39  Val=8

# %%
def load_pair(image_path, label_path):
    image_nii = nib.load(image_path)
    label_nii = nib.load(label_path)
    image  = image_nii.get_fdata().astype(np.float32)
    label  = label_nii.get_fdata().astype(np.float32)
    affine = np.array(image_nii.affine, dtype=np.float32)
    image  = np.transpose(image, (2, 1, 0))
    label  = np.transpose(label, (2, 1, 0))
    affine[:, :3] = affine[:, [2, 1, 0]]
    label = (label > 0.5).astype(np.float32)
    image = image[..., np.newaxis]
    label = label[..., np.newaxis]
    return {"image": image, "label": label}, {"affine": affine}

_d, _ = load_pair(pairs[0]["image"], pairs[0]["label"])
print(f"image: {_d['image'].shape}   label: {_d['label'].shape}")
print(f"Label fraction: {_d['label'].mean():.4f}")
# Out:
# image: (219, 309, 309, 1)   label: (219, 309, 309, 1)
# Label fraction: 0.1100

# %%
train_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=2, neg=1, num_samples=NUM_SAMPLES,
        image_reference_key="image", image_threshold=0,
    ),
    RandFlip(keys=["image", "label"], spatial_axis=[0], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[1], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[2], prob=0.5),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(0, 1)),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(1, 2)),
    RandShiftIntensity(keys=["image"], offsets=0.2, prob=0.8),
])

val_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=1, neg=0, num_samples=1,
        image_reference_key="image", image_threshold=0,
    ),
])

print("Transforms ready")
# Out:
# Transforms ready

# %%
class HeartSegDataset(keras.utils.PyDataset):
    def __init__(self, pairs, transform, batch_size, num_samples=1, shuffle=False, **kw):
        super().__init__(**kw)
        self.pairs      = pairs
        self.transform  = transform
        self.batch_size = batch_size
        self.num_samples = num_samples
        self.shuffle    = shuffle
        self._build_index()

    def _build_index(self):
        self._index = [(vi, ci) for vi in range(len(self.pairs))
                                for ci in range(self.num_samples)]
        if self.shuffle:
            np.random.shuffle(self._index)

    def __len__(self):
        return math.ceil(len(self._index) / self.batch_size)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self._index)

    def __getitem__(self, idx):
        batch = self._index[idx * self.batch_size : (idx + 1) * self.batch_size]
        images, labels = [], []
        for vi, ci in batch:
            p = self.pairs[vi]
            data, meta = load_pair(p["image"], p["label"])
            out = self.transform(data, meta)
            img, lbl = out["image"], out["label"]
            if isinstance(img, list):
                ci = min(ci, len(img) - 1)
                img, lbl = img[ci], lbl[ci]
            if hasattr(img, "numpy"): img = img.numpy()
            if hasattr(lbl, "numpy"): lbl = lbl.numpy()
            images.append(img)
            labels.append(lbl)
        return np.stack(images), np.stack(labels)


train_ds = HeartSegDataset(
    train_pairs, train_transform,
    batch_size=BATCH_SIZE, num_samples=NUM_SAMPLES, shuffle=True,
)
val_ds = HeartSegDataset(
    val_pairs, val_transform,
    batch_size=1, num_samples=1, shuffle=False,
)

_x, _y = train_ds[0]
print(f"Batch: {_x.shape}  [{_x.min():.2f}, {_x.max():.2f}]")
print(f"Label: {_y.shape}  heart voxels={int(_y.sum())}")
print(f"Steps/epoch: {len(train_ds)} train, {len(val_ds)} val")
# Out:
# I0000 00:00:1774367164.320697      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Batch: (2, 160, 160, 160, 1)  [-0.17, 1.04]
# Label: (2, 160, 160, 160, 1)  heart voxels=2760929
# Steps/epoch: 20 train, 8 val

# %%
model = SegFormer(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='mit_b1',
    classifier_activation=None,
)

print(f"Parameters: {model.count_params():,}")
model.summary(line_length=100)
# Out:
# Parameters: 16,623,425
# Model: "SegFormer3D"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mixvit_input (InputLayer)   │ (None, 160, 160, 160,   │              0 │ -                       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ overlap_patch_and_embed_0   │ (None, 64000, 64)       │         22,144 │ mixvit_input[0][0]      │
# │ (OverlappingPatchingAndEmb… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_0_0    │ (None, 64000, 64)       │        320,512 │ overlap_patch_and_embe… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_0_1    │ (None, 64000, 64)       │        320,512 │ hierarchical_encoder_0… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_7       │ (None, 64000, 64)       │            128 │ hierarchical_encoder_0… │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape (Reshape)           │ (None, 40, 40, 40, 64)  │              0 │ layer_normalization_7[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ overlap_patch_and_embed_1   │ (None, 8000, 128)       │        221,568 │ reshape[0][0]           │
# │ (OverlappingPatchingAndEmb… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_1_0    │ (None, 8000, 128)       │        346,112 │ overlap_patch_and_embe… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_1_1    │ (None, 8000, 128)       │        346,112 │ hierarchical_encoder_1… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_15      │ (None, 8000, 128)       │            256 │ hierarchical_encoder_1… │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_1 (Reshape)         │ (None, 20, 20, 20, 128) │              0 │ layer_normalization_15… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ overlap_patch_and_embed_2   │ (None, 1000, 320)       │      1,106,880 │ reshape_1[0][0]         │
# │ (OverlappingPatchingAndEmb… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_2_0    │ (None, 1000, 320)       │      1,273,920 │ overlap_patch_and_embe… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_2_1    │ (None, 1000, 320)       │      1,273,920 │ hierarchical_encoder_2… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_21      │ (None, 1000, 320)       │            640 │ hierarchical_encoder_2… │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_2 (Reshape)         │ (None, 10, 10, 10, 320) │              0 │ layer_normalization_21… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ overlap_patch_and_embed_3   │ (None, 125, 512)        │      4,425,216 │ reshape_2[0][0]         │
# │ (OverlappingPatchingAndEmb… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_3_0    │ (None, 125, 512)        │      3,217,920 │ overlap_patch_and_embe… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ hierarchical_encoder_3_1    │ (None, 125, 512)        │      3,217,920 │ hierarchical_encoder_3… │
# │ (HierarchicalTransformerEn… │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_27      │ (None, 125, 512)        │          1,024 │ hierarchical_encoder_3… │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_3 (Reshape)         │ (None, 5, 5, 5, 512)    │              0 │ layer_normalization_27… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_8 (Reshape)         │ (None, 8000, 128)       │              0 │ reshape_1[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_6 (Reshape)         │ (None, 1000, 320)       │              0 │ reshape_2[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_4 (Reshape)         │ (None, 125, 512)        │              0 │ reshape_3[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_10 (Reshape)        │ (None, 64000, 64)       │              0 │ reshape[0][0]           │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense_50 (Dense)            │ (None, 8000, 256)       │         33,024 │ reshape_8[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense_49 (Dense)            │ (None, 1000, 256)       │         82,176 │ reshape_6[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense_48 (Dense)            │ (None, 125, 256)        │        131,328 │ reshape_4[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense_51 (Dense)            │ (None, 64000, 256)      │         16,640 │ reshape_10[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_30      │ (None, 8000, 256)       │            512 │ dense_50[0][0]          │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_29      │ (None, 1000, 256)       │            512 │ dense_49[0][0]          │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_28      │ (None, 125, 256)        │            512 │ dense_48[0][0]          │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ layer_normalization_31      │ (None, 64000, 256)      │            512 │ dense_51[0][0]          │
# │ (LayerNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_9 (Reshape)         │ (None, 20, 20, 20, 256) │              0 │ layer_normalization_30… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_7 (Reshape)         │ (None, 10, 10, 10, 256) │              0 │ layer_normalization_29… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_5 (Reshape)         │ (None, 5, 5, 5, 256)    │              0 │ layer_normalization_28… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ reshape_11 (Reshape)        │ (None, 40, 40, 40, 256) │              0 │ layer_normalization_31… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ resize_op3 (ResizingND)     │ (None, 40, 40, 40, 256) │              0 │ reshape_9[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ resize_op2 (ResizingND)     │ (None, 40, 40, 40, 256) │              0 │ reshape_7[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ resize_op1 (ResizingND)     │ (None, 40, 40, 40, 256) │              0 │ reshape_5[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ concatenate (Concatenate)   │ (None, 40, 40, 40,      │              0 │ reshape_11[0][0],       │
# │                             │ 1024)                   │                │ resize_op3[0][0],       │
# │                             │                         │                │ resize_op2[0][0],       │
# │                             │                         │                │ resize_op1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ linear_fuse_conv_conv_3D    │ (None, 40, 40, 40, 256) │        262,144 │ concatenate[0][0]       │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ linear_fuse_conv_norm_3D    │ (None, 40, 40, 40, 256) │          1,024 │ linear_fuse_conv_conv_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ linear_fuse_conv_activation │ (None, 40, 40, 40, 256) │              0 │ linear_fuse_conv_norm_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dropout_32 (Dropout)        │ (None, 40, 40, 40, 256) │              0 │ linear_fuse_conv_activ… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3d_16 (Conv3D)          │ (None, 40, 40, 40, 1)   │            257 │ dropout_32[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ resize_op4 (ResizingND)     │ (None, 160, 160, 160,   │              0 │ conv3d_16[0][0]         │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ predictions (Activation)    │ (None, 160, 160, 160,   │              0 │ resize_op4[0][0]        │
# │                             │ 1)                      │                │                         │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 16,623,425 (63.41 MB)
#  Trainable params: 16,606,529 (63.35 MB)
#  Non-trainable params: 16,896 (66.00 KB)

# %%
def warmup_cosine_lr(epoch, current_lr):
    if epoch < WARMUP_EPOCHS:
        return MIN_LR + (LEARNING_RATE - MIN_LR) * (epoch / WARMUP_EPOCHS)
    progress = (epoch - WARMUP_EPOCHS) / max(EPOCHS - WARMUP_EPOCHS, 1)
    return MIN_LR + 0.5 * (LEARNING_RATE - MIN_LR) * (1 + math.cos(math.pi * progress))

for e in [0, 10, 50, 100, 199]:
    print(f"Epoch {e:>3d}  LR = {warmup_cosine_lr(e, None):.2e}")
# Out:
# Epoch   0  LR = 1.00e-06
# Epoch  10  LR = 3.00e-04
# Epoch  50  LR = 2.92e-04
# Epoch 100  LR = 2.62e-04
# Epoch 199  LR = 1.58e-04

# %%
model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=MIN_LR,
        weight_decay=WEIGHT_DECAY,
    ),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

callbacks = [
    keras.callbacks.LearningRateScheduler(warmup_cosine_lr, verbose=0),
    keras.callbacks.ModelCheckpoint(
        filepath=str(OUT_DIR / "best_model.keras"),
        monitor="val_binary_dice_metric", mode="max",
        save_best_only=True, verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_binary_dice_metric", mode="max",
        patience=50, restore_best_weights=True, verbose=1,
    ),
    keras.callbacks.CSVLogger(str(OUT_DIR / "training_log.csv")),
]

print("Compiled")
# Out:
# Compiled

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

print(f"\nBest val Dice: {max(history.history.get('val_binary_dice_metric', [0])):.4f}")
# Out:
# Epoch 1/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 111s 6s/step - binary_dice_score: 0.4002 - loss: 1.3175 - val_binary_dice_score: 0.6914 - val_loss: 1.1625 - learning_rate: 1.0000e-06
# Epoch 2/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.5942 - loss: 1.1056 - val_binary_dice_score: 0.5688 - val_loss: 1.2489 - learning_rate: 3.0900e-05
# Epoch 3/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.5952 - loss: 1.0826 - val_binary_dice_score: 0.5655 - val_loss: 1.1042 - learning_rate: 6.0800e-05
# Epoch 4/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.6571 - loss: 0.9562 - val_binary_dice_score: 8.4994e-14 - val_loss: 1.6318 - learning_rate: 9.0700e-05
# Epoch 5/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7343 - loss: 0.7994 - val_binary_dice_score: 8.7864e-14 - val_loss: 2.0680 - learning_rate: 1.2060e-04
# Epoch 6/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.6933 - loss: 0.8742 - val_binary_dice_score: 2.6579e-04 - val_loss: 1.2083 - learning_rate: 1.5050e-04
# Epoch 7/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7439 - loss: 0.8023 - val_binary_dice_score: 0.5865 - val_loss: 1.1930 - learning_rate: 1.8040e-04
# Epoch 8/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7495 - loss: 0.7179 - val_binary_dice_score: 8.6292e-14 - val_loss: 2.0361 - learning_rate: 2.1030e-04
# Epoch 9/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7699 - loss: 0.6728 - val_binary_dice_score: 0.0072 - val_loss: 1.0822 - learning_rate: 2.4020e-04
# Epoch 10/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.6999 - loss: 0.7736 - val_binary_dice_score: 8.1711e-14 - val_loss: 2.2980 - learning_rate: 2.7010e-04
# Epoch 11/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.6959 - loss: 0.8292 - val_binary_dice_score: 8.0626e-14 - val_loss: 3.6384 - learning_rate: 3.0000e-04
# Epoch 12/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7175 - loss: 0.7619 - val_binary_dice_score: 8.9898e-14 - val_loss: 1.5873 - learning_rate: 3.0000e-04
# Epoch 13/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7727 - loss: 0.6535 - val_binary_dice_score: 7.0716e-07 - val_loss: 1.7765 - learning_rate: 2.9998e-04
# Epoch 14/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.7929 - loss: 0.5850 - val_binary_dice_score: 9.0959e-14 - val_loss: 1.3672 - learning_rate: 2.9996e-04
# Epoch 15/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7196 - loss: 0.7377 - val_binary_dice_score: 0.7742 - val_loss: 0.8240 - learning_rate: 2.9992e-04
# Epoch 16/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7212 - loss: 0.7612 - val_binary_dice_score: 8.8329e-14 - val_loss: 1.5034 - learning_rate: 2.9988e-04
# Epoch 17/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8064 - loss: 0.5623 - val_binary_dice_score: 0.7007 - val_loss: 1.1861 - learning_rate: 2.9983e-04
# Epoch 18/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.7754 - loss: 0.6630 - val_binary_dice_score: 0.6204 - val_loss: 1.3084 - learning_rate: 2.9976e-04
# Epoch 19/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8000 - loss: 0.7019 - val_binary_dice_score: 0.5319 - val_loss: 0.8894 - learning_rate: 2.9969e-04
# Epoch 20/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8298 - loss: 0.5169 - val_binary_dice_score: 0.1528 - val_loss: 1.0881 - learning_rate: 2.9961e-04
# Epoch 21/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8068 - loss: 0.5803 - val_binary_dice_score: 0.7955 - val_loss: 0.6641 - learning_rate: 2.9952e-04
# Epoch 22/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8371 - loss: 0.4911 - val_binary_dice_score: 0.8250 - val_loss: 0.5617 - learning_rate: 2.9941e-04
# Epoch 23/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8401 - loss: 0.4867 - val_binary_dice_score: 0.0266 - val_loss: 1.5223 - learning_rate: 2.9930e-04
# Epoch 24/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8103 - loss: 0.5557 - val_binary_dice_score: 7.6379e-14 - val_loss: 2.0538 - learning_rate: 2.9918e-04
# Epoch 25/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7535 - loss: 0.6420 - val_binary_dice_score: 0.3303 - val_loss: 0.9938 - learning_rate: 2.9905e-04
# Epoch 26/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7901 - loss: 0.5677 - val_binary_dice_score: 0.7388 - val_loss: 0.8247 - learning_rate: 2.9891e-04
# Epoch 27/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8122 - loss: 0.5319 - val_binary_dice_score: 0.2814 - val_loss: 1.4694 - learning_rate: 2.9876e-04
# Epoch 28/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8190 - loss: 0.5276 - val_binary_dice_score: 0.8404 - val_loss: 0.5036 - learning_rate: 2.9860e-04
# Epoch 29/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8311 - loss: 0.5074 - val_binary_dice_score: 0.0923 - val_loss: 1.3289 - learning_rate: 2.9843e-04
# Epoch 30/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8541 - loss: 0.4367 - val_binary_dice_score: 0.8220 - val_loss: 0.6033 - learning_rate: 2.9825e-04
# Epoch 31/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8227 - loss: 0.5349 - val_binary_dice_score: 0.7833 - val_loss: 0.6030 - learning_rate: 2.9806e-04
# Epoch 32/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8651 - loss: 0.4477 - val_binary_dice_score: 0.0106 - val_loss: 1.8894 - learning_rate: 2.9787e-04
# Epoch 33/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8475 - loss: 0.4705 - val_binary_dice_score: 0.3305 - val_loss: 0.8935 - learning_rate: 2.9766e-04
# Epoch 34/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8358 - loss: 0.5006 - val_binary_dice_score: 8.6269e-04 - val_loss: 2.2363 - learning_rate: 2.9744e-04
# Epoch 35/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7767 - loss: 0.6393 - val_binary_dice_score: 0.8485 - val_loss: 0.5036 - learning_rate: 2.9721e-04
# Epoch 36/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8124 - loss: 0.5333 - val_binary_dice_score: 0.8474 - val_loss: 0.4610 - learning_rate: 2.9698e-04
# Epoch 37/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8292 - loss: 0.4939 - val_binary_dice_score: 0.8264 - val_loss: 0.5489 - learning_rate: 2.9673e-04
# Epoch 38/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8055 - loss: 0.5626 - val_binary_dice_score: 0.0479 - val_loss: 1.6472 - learning_rate: 2.9648e-04
# Epoch 39/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8800 - loss: 0.3531 - val_binary_dice_score: 0.7462 - val_loss: 0.7957 - learning_rate: 2.9621e-04
# Epoch 40/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8148 - loss: 0.5222 - val_binary_dice_score: 0.8299 - val_loss: 0.5301 - learning_rate: 2.9594e-04
# Epoch 41/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8431 - loss: 0.4626 - val_binary_dice_score: 0.6970 - val_loss: 0.7608 - learning_rate: 2.9566e-04
# Epoch 42/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8533 - loss: 0.4029 - val_binary_dice_score: 0.8028 - val_loss: 0.6090 - learning_rate: 2.9536e-04
# Epoch 43/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8506 - loss: 0.4593 - val_binary_dice_score: 0.8420 - val_loss: 0.4866 - learning_rate: 2.9506e-04
# Epoch 44/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8304 - loss: 0.5199 - val_binary_dice_score: 0.8438 - val_loss: 0.4833 - learning_rate: 2.9475e-04
# Epoch 45/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8483 - loss: 0.4444 - val_binary_dice_score: 0.7584 - val_loss: 0.6711 - learning_rate: 2.9443e-04
# Epoch 46/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8377 - loss: 0.4522 - val_binary_dice_score: 0.1284 - val_loss: 1.2930 - learning_rate: 2.9410e-04
# Epoch 47/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8597 - loss: 0.3966 - val_binary_dice_score: 0.7209 - val_loss: 0.7971 - learning_rate: 2.9376e-04
# Epoch 48/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8329 - loss: 0.4746 - val_binary_dice_score: 0.1668 - val_loss: 1.2707 - learning_rate: 2.9341e-04
# Epoch 49/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8357 - loss: 0.4578 - val_binary_dice_score: 0.7432 - val_loss: 0.8330 - learning_rate: 2.9305e-04
# Epoch 50/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8186 - loss: 0.5521 - val_binary_dice_score: 0.8133 - val_loss: 0.6645 - learning_rate: 2.9268e-04
# Epoch 51/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8577 - loss: 0.4696 - val_binary_dice_score: 0.7933 - val_loss: 0.6787 - learning_rate: 2.9231e-04
# Epoch 52/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8349 - loss: 0.4814 - val_binary_dice_score: 0.8337 - val_loss: 0.6300 - learning_rate: 2.9192e-04
# Epoch 53/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8521 - loss: 0.4325 - val_binary_dice_score: 0.6650 - val_loss: 1.1255 - learning_rate: 2.9153e-04
# Epoch 54/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8287 - loss: 0.4868 - val_binary_dice_score: 0.8910 - val_loss: 0.4057 - learning_rate: 2.9112e-04
# Epoch 55/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8609 - loss: 0.4208 - val_binary_dice_score: 0.7277 - val_loss: 0.6859 - learning_rate: 2.9071e-04
# Epoch 56/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8624 - loss: 0.4083 - val_binary_dice_score: 0.7060 - val_loss: 0.7940 - learning_rate: 2.9028e-04
# Epoch 57/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8425 - loss: 0.4726 - val_binary_dice_score: 0.7423 - val_loss: 0.7827 - learning_rate: 2.8985e-04
# Epoch 58/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8503 - loss: 0.4630 - val_binary_dice_score: 0.5507 - val_loss: 0.9399 - learning_rate: 2.8941e-04
# Epoch 59/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.7193 - loss: 0.8477 - val_binary_dice_score: 0.7223 - val_loss: 0.8463 - learning_rate: 2.8896e-04
# Epoch 60/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8060 - loss: 0.5671 - val_binary_dice_score: 0.5219 - val_loss: 0.8999 - learning_rate: 2.8850e-04
# Epoch 61/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8148 - loss: 0.5579 - val_binary_dice_score: 8.3188e-14 - val_loss: 2.6388 - learning_rate: 2.8804e-04
# Epoch 62/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8275 - loss: 0.5498 - val_binary_dice_score: 0.0380 - val_loss: 1.7999 - learning_rate: 2.8756e-04
# Epoch 63/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7806 - loss: 0.6601 - val_binary_dice_score: 8.3498e-14 - val_loss: 2.6982 - learning_rate: 2.8708e-04
# Epoch 64/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8009 - loss: 0.6010 - val_binary_dice_score: 8.2467e-14 - val_loss: 2.8389 - learning_rate: 2.8658e-04
# Epoch 65/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.7829 - loss: 0.5630 - val_binary_dice_score: 8.7602e-14 - val_loss: 1.9326 - learning_rate: 2.8608e-04
# Epoch 66/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8382 - loss: 0.4788 - val_binary_dice_score: 9.1672e-14 - val_loss: 2.1033 - learning_rate: 2.8557e-04
# Epoch 67/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8124 - loss: 0.5402 - val_binary_dice_score: 0.7986 - val_loss: 0.6358 - learning_rate: 2.8505e-04
# Epoch 68/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8127 - loss: 0.5317 - val_binary_dice_score: 0.7676 - val_loss: 0.6796 - learning_rate: 2.8452e-04
# Epoch 69/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8643 - loss: 0.3954 - val_binary_dice_score: 0.8075 - val_loss: 0.5791 - learning_rate: 2.8398e-04
# Epoch 70/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8704 - loss: 0.3803 - val_binary_dice_score: 0.7632 - val_loss: 0.7473 - learning_rate: 2.8343e-04
# Epoch 71/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8625 - loss: 0.4235 - val_binary_dice_score: 0.8678 - val_loss: 0.4421 - learning_rate: 2.8288e-04
# Epoch 72/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8136 - loss: 0.4902 - val_binary_dice_score: 0.5282 - val_loss: 0.9250 - learning_rate: 2.8231e-04
# Epoch 73/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8666 - loss: 0.4018 - val_binary_dice_score: 8.6817e-14 - val_loss: 2.6540 - learning_rate: 2.8174e-04
# Epoch 74/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8414 - loss: 0.4493 - val_binary_dice_score: 0.8758 - val_loss: 0.4016 - learning_rate: 2.8116e-04
# Epoch 75/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8499 - loss: 0.4800 - val_binary_dice_score: 0.8363 - val_loss: 0.5554 - learning_rate: 2.8057e-04
# Epoch 76/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8612 - loss: 0.3988 - val_binary_dice_score: 0.8645 - val_loss: 0.4943 - learning_rate: 2.7997e-04
# Epoch 77/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8537 - loss: 0.4482 - val_binary_dice_score: 0.8775 - val_loss: 0.4030 - learning_rate: 2.7936e-04
# Epoch 78/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8814 - loss: 0.3686 - val_binary_dice_score: 0.8939 - val_loss: 0.3569 - learning_rate: 2.7875e-04
# Epoch 79/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8342 - loss: 0.4601 - val_binary_dice_score: 0.8565 - val_loss: 0.3925 - learning_rate: 2.7813e-04
# Epoch 80/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8753 - loss: 0.3617 - val_binary_dice_score: 0.8622 - val_loss: 0.4964 - learning_rate: 2.7750e-04
# Epoch 81/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8462 - loss: 0.4614 - val_binary_dice_score: 0.6887 - val_loss: 0.9848 - learning_rate: 2.7686e-04
# Epoch 82/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8259 - loss: 0.5274 - val_binary_dice_score: 0.0847 - val_loss: 1.6124 - learning_rate: 2.7621e-04
# Epoch 83/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8654 - loss: 0.4163 - val_binary_dice_score: 0.8206 - val_loss: 0.6497 - learning_rate: 2.7555e-04
# Epoch 84/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8692 - loss: 0.3980 - val_binary_dice_score: 0.5912 - val_loss: 0.8813 - learning_rate: 2.7489e-04
# Epoch 85/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8771 - loss: 0.3558 - val_binary_dice_score: 0.7035 - val_loss: 0.8548 - learning_rate: 2.7422e-04
# Epoch 86/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8329 - loss: 0.4790 - val_binary_dice_score: 0.3458 - val_loss: 1.1094 - learning_rate: 2.7354e-04
# Epoch 87/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8542 - loss: 0.4515 - val_binary_dice_score: 0.8350 - val_loss: 0.5425 - learning_rate: 2.7285e-04
# Epoch 88/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8782 - loss: 0.3774 - val_binary_dice_score: 0.6396 - val_loss: 1.4299 - learning_rate: 2.7215e-04
# Epoch 89/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8519 - loss: 0.4249 - val_binary_dice_score: 0.8405 - val_loss: 0.5449 - learning_rate: 2.7145e-04
# Epoch 90/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8773 - loss: 0.3986 - val_binary_dice_score: 0.7747 - val_loss: 0.7577 - learning_rate: 2.7074e-04
# Epoch 91/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8694 - loss: 0.3743 - val_binary_dice_score: 0.8693 - val_loss: 0.4029 - learning_rate: 2.7002e-04
# Epoch 92/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.9090 - loss: 0.2866 - val_binary_dice_score: 0.8798 - val_loss: 0.3448 - learning_rate: 2.6929e-04
# Epoch 93/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8931 - loss: 0.3339 - val_binary_dice_score: 0.8978 - val_loss: 0.3597 - learning_rate: 2.6855e-04
# Epoch 94/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8820 - loss: 0.3775 - val_binary_dice_score: 0.8574 - val_loss: 0.4529 - learning_rate: 2.6781e-04
# Epoch 95/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8899 - loss: 0.3288 - val_binary_dice_score: 0.6117 - val_loss: 1.5402 - learning_rate: 2.6706e-04
# Epoch 96/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8614 - loss: 0.4138 - val_binary_dice_score: 0.0039 - val_loss: 1.8773 - learning_rate: 2.6630e-04
# Epoch 97/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8095 - loss: 0.5574 - val_binary_dice_score: 0.1315 - val_loss: 1.5662 - learning_rate: 2.6554e-04
# Epoch 98/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8525 - loss: 0.4405 - val_binary_dice_score: 0.2142 - val_loss: 1.1666 - learning_rate: 2.6477e-04
# Epoch 99/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8751 - loss: 0.3725 - val_binary_dice_score: 0.4808 - val_loss: 0.9512 - learning_rate: 2.6398e-04
# Epoch 100/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8426 - loss: 0.5001 - val_binary_dice_score: 0.8279 - val_loss: 0.4838 - learning_rate: 2.6320e-04
# Epoch 101/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8966 - loss: 0.3522 - val_binary_dice_score: 0.8693 - val_loss: 0.3758 - learning_rate: 2.6240e-04
# Epoch 102/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8860 - loss: 0.3275 - val_binary_dice_score: 0.8549 - val_loss: 0.5090 - learning_rate: 2.6160e-04
# Epoch 103/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8855 - loss: 0.3499 - val_binary_dice_score: 0.0591 - val_loss: 1.5837 - learning_rate: 2.6079e-04
# Epoch 104/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8493 - loss: 0.4491 - val_binary_dice_score: 0.8305 - val_loss: 0.5569 - learning_rate: 2.5997e-04
# Epoch 105/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8838 - loss: 0.3576 - val_binary_dice_score: 0.2679 - val_loss: 1.2612 - learning_rate: 2.5915e-04
# Epoch 106/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8920 - loss: 0.4045 - val_binary_dice_score: 0.8767 - val_loss: 0.3781 - learning_rate: 2.5832e-04
# Epoch 107/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8842 - loss: 0.3447 - val_binary_dice_score: 0.8697 - val_loss: 0.4407 - learning_rate: 2.5748e-04
# Epoch 108/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8755 - loss: 0.3841 - val_binary_dice_score: 0.9092 - val_loss: 0.3251 - learning_rate: 2.5664e-04
# Epoch 109/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9014 - loss: 0.2983 - val_binary_dice_score: 0.8760 - val_loss: 0.3926 - learning_rate: 2.5579e-04
# Epoch 110/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8632 - loss: 0.3902 - val_binary_dice_score: 0.3585 - val_loss: 1.0117 - learning_rate: 2.5493e-04
# Epoch 111/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8463 - loss: 0.5017 - val_binary_dice_score: 0.7473 - val_loss: 0.7030 - learning_rate: 2.5406e-04
# Epoch 112/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8793 - loss: 0.3854 - val_binary_dice_score: 0.8235 - val_loss: 0.5235 - learning_rate: 2.5319e-04
# Epoch 113/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8464 - loss: 0.4303 - val_binary_dice_score: 0.8326 - val_loss: 0.5300 - learning_rate: 2.5231e-04
# Epoch 114/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8617 - loss: 0.4172 - val_binary_dice_score: 0.8270 - val_loss: 0.5838 - learning_rate: 2.5143e-04
# Epoch 115/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8979 - loss: 0.4313 - val_binary_dice_score: 0.9054 - val_loss: 0.2983 - learning_rate: 2.5054e-04
# Epoch 116/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9010 - loss: 0.3144 - val_binary_dice_score: 0.7780 - val_loss: 1.1036 - learning_rate: 2.4964e-04
# Epoch 117/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9023 - loss: 0.3314 - val_binary_dice_score: 0.8205 - val_loss: 0.6199 - learning_rate: 2.4873e-04
# Epoch 118/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8760 - loss: 0.3908 - val_binary_dice_score: 0.6723 - val_loss: 1.2559 - learning_rate: 2.4782e-04
# Epoch 119/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9132 - loss: 0.2845 - val_binary_dice_score: 0.9160 - val_loss: 0.2825 - learning_rate: 2.4690e-04
# Epoch 120/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8693 - loss: 0.3893 - val_binary_dice_score: 0.6154 - val_loss: 1.3692 - learning_rate: 2.4598e-04
# Epoch 121/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8848 - loss: 0.3391 - val_binary_dice_score: 0.8825 - val_loss: 0.3259 - learning_rate: 2.4505e-04
# Epoch 122/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8686 - loss: 0.3844 - val_binary_dice_score: 0.8945 - val_loss: 0.3423 - learning_rate: 2.4411e-04
# Epoch 123/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8730 - loss: 0.3681 - val_binary_dice_score: 0.9001 - val_loss: 0.3253 - learning_rate: 2.4317e-04
# Epoch 124/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8614 - loss: 0.4348 - val_binary_dice_score: 0.8924 - val_loss: 0.3786 - learning_rate: 2.4222e-04
# Epoch 125/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8951 - loss: 0.3346 - val_binary_dice_score: 0.1425 - val_loss: 1.1391 - learning_rate: 2.4127e-04
# Epoch 126/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8777 - loss: 0.3625 - val_binary_dice_score: 0.8407 - val_loss: 0.4965 - learning_rate: 2.4031e-04
# Epoch 127/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8924 - loss: 0.3182 - val_binary_dice_score: 0.7167 - val_loss: 0.6819 - learning_rate: 2.3935e-04
# Epoch 128/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8792 - loss: 0.3642 - val_binary_dice_score: 0.8872 - val_loss: 0.3554 - learning_rate: 2.3837e-04
# Epoch 129/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8857 - loss: 0.3950 - val_binary_dice_score: 0.8361 - val_loss: 0.4660 - learning_rate: 2.3740e-04
# Epoch 130/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8907 - loss: 0.3521 - val_binary_dice_score: 0.9078 - val_loss: 0.2787 - learning_rate: 2.3641e-04
# Epoch 131/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9008 - loss: 0.2888 - val_binary_dice_score: 0.9104 - val_loss: 0.3229 - learning_rate: 2.3543e-04
# Epoch 132/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8946 - loss: 0.3266 - val_binary_dice_score: 0.8815 - val_loss: 0.3530 - learning_rate: 2.3443e-04
# Epoch 133/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8876 - loss: 0.3530 - val_binary_dice_score: 0.1081 - val_loss: 1.8735 - learning_rate: 2.3343e-04
# Epoch 134/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8855 - loss: 0.3527 - val_binary_dice_score: 0.7899 - val_loss: 0.8316 - learning_rate: 2.3243e-04
# Epoch 135/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8856 - loss: 0.3358 - val_binary_dice_score: 0.8688 - val_loss: 0.4470 - learning_rate: 2.3142e-04
# Epoch 136/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8686 - loss: 0.3942 - val_binary_dice_score: 0.8269 - val_loss: 0.5248 - learning_rate: 2.3040e-04
# Epoch 137/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8803 - loss: 0.3549 - val_binary_dice_score: 0.8387 - val_loss: 0.5314 - learning_rate: 2.2938e-04
# Epoch 138/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8727 - loss: 0.4011 - val_binary_dice_score: 0.8995 - val_loss: 0.3274 - learning_rate: 2.2836e-04
# Epoch 139/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8699 - loss: 0.4351 - val_binary_dice_score: 0.8264 - val_loss: 0.5270 - learning_rate: 2.2733e-04
# Epoch 140/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8959 - loss: 0.3449 - val_binary_dice_score: 0.8845 - val_loss: 0.3641 - learning_rate: 2.2629e-04
# Epoch 141/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8963 - loss: 0.3180 - val_binary_dice_score: 0.9288 - val_loss: 0.2468 - learning_rate: 2.2525e-04
# Epoch 142/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9107 - loss: 0.2939 - val_binary_dice_score: 0.8695 - val_loss: 0.4129 - learning_rate: 2.2420e-04
# Epoch 143/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8964 - loss: 0.3120 - val_binary_dice_score: 0.7974 - val_loss: 0.6801 - learning_rate: 2.2315e-04
# Epoch 144/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8713 - loss: 0.3849 - val_binary_dice_score: 0.8301 - val_loss: 0.5507 - learning_rate: 2.2210e-04
# Epoch 145/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8747 - loss: 0.3747 - val_binary_dice_score: 0.8700 - val_loss: 0.3832 - learning_rate: 2.2104e-04
# Epoch 146/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9098 - loss: 0.2946 - val_binary_dice_score: 0.9159 - val_loss: 0.2576 - learning_rate: 2.1998e-04
# Epoch 147/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8824 - loss: 0.3485 - val_binary_dice_score: 0.9036 - val_loss: 0.3108 - learning_rate: 2.1891e-04
# Epoch 148/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8466 - loss: 0.4480 - val_binary_dice_score: 0.8776 - val_loss: 0.4452 - learning_rate: 2.1783e-04
# Epoch 149/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8702 - loss: 0.3859 - val_binary_dice_score: 0.8964 - val_loss: 0.3599 - learning_rate: 2.1676e-04
# Epoch 150/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8861 - loss: 0.3324 - val_binary_dice_score: 0.8931 - val_loss: 0.3192 - learning_rate: 2.1568e-04
# Epoch 151/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8696 - loss: 0.4666 - val_binary_dice_score: 0.9111 - val_loss: 0.2661 - learning_rate: 2.1459e-04
# Epoch 152/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9130 - loss: 0.3119 - val_binary_dice_score: 0.9295 - val_loss: 0.2327 - learning_rate: 2.1350e-04
# Epoch 153/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9132 - loss: 0.2783 - val_binary_dice_score: 0.9272 - val_loss: 0.2403 - learning_rate: 2.1241e-04
# Epoch 154/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9081 - loss: 0.2673 - val_binary_dice_score: 0.7483 - val_loss: 0.7994 - learning_rate: 2.1131e-04
# Epoch 155/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9007 - loss: 0.2959 - val_binary_dice_score: 0.8989 - val_loss: 0.3149 - learning_rate: 2.1021e-04
# Epoch 156/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.9108 - loss: 0.2774 - val_binary_dice_score: 0.6974 - val_loss: 0.7673 - learning_rate: 2.0910e-04
# Epoch 157/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8897 - loss: 0.3440 - val_binary_dice_score: 0.8302 - val_loss: 0.5172 - learning_rate: 2.0799e-04
# Epoch 158/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.9161 - loss: 0.2491 - val_binary_dice_score: 0.9060 - val_loss: 0.3149 - learning_rate: 2.0688e-04
# Epoch 159/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.9008 - loss: 0.3332 - val_binary_dice_score: 0.8867 - val_loss: 0.3705 - learning_rate: 2.0576e-04
# Epoch 160/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8901 - loss: 0.3161 - val_binary_dice_score: 0.9026 - val_loss: 0.2845 - learning_rate: 2.0464e-04
# Epoch 161/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9104 - loss: 0.3153 - val_binary_dice_score: 0.8252 - val_loss: 0.5541 - learning_rate: 2.0351e-04
# Epoch 162/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9009 - loss: 0.3164 - val_binary_dice_score: 0.6562 - val_loss: 1.0554 - learning_rate: 2.0239e-04
# Epoch 163/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.9027 - loss: 0.2951 - val_binary_dice_score: 0.8735 - val_loss: 0.3627 - learning_rate: 2.0125e-04
# Epoch 164/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9115 - loss: 0.2619 - val_binary_dice_score: 0.8613 - val_loss: 0.4270 - learning_rate: 2.0012e-04
# Epoch 165/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9171 - loss: 0.2588 - val_binary_dice_score: 0.9251 - val_loss: 0.2364 - learning_rate: 1.9898e-04
# Epoch 166/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8944 - loss: 0.3104 - val_binary_dice_score: 0.9039 - val_loss: 0.3332 - learning_rate: 1.9784e-04
# Epoch 167/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9036 - loss: 0.2892 - val_binary_dice_score: 0.0065 - val_loss: 3.1754 - learning_rate: 1.9670e-04
# Epoch 168/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8734 - loss: 0.3840 - val_binary_dice_score: 0.8736 - val_loss: 0.3957 - learning_rate: 1.9555e-04
# Epoch 169/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8655 - loss: 0.3928 - val_binary_dice_score: 0.8618 - val_loss: 0.4936 - learning_rate: 1.9440e-04
# Epoch 170/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8693 - loss: 0.3945 - val_binary_dice_score: 0.9126 - val_loss: 0.2765 - learning_rate: 1.9325e-04
# Epoch 171/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9099 - loss: 0.2773 - val_binary_dice_score: 0.9072 - val_loss: 0.3065 - learning_rate: 1.9209e-04
# Epoch 172/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8839 - loss: 0.3629 - val_binary_dice_score: 0.6148 - val_loss: 0.8150 - learning_rate: 1.9094e-04
# Epoch 173/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - binary_dice_score: 0.8722 - loss: 0.3693 - val_binary_dice_score: 0.9022 - val_loss: 0.3096 - learning_rate: 1.8977e-04
# Epoch 174/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9011 - loss: 0.3079 - val_binary_dice_score: 0.8810 - val_loss: 0.3753 - learning_rate: 1.8861e-04
# Epoch 175/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9177 - loss: 0.2610 - val_binary_dice_score: 0.7928 - val_loss: 0.5696 - learning_rate: 1.8745e-04
# Epoch 176/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8840 - loss: 0.3440 - val_binary_dice_score: 0.9010 - val_loss: 0.3370 - learning_rate: 1.8628e-04
# Epoch 177/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9149 - loss: 0.2747 - val_binary_dice_score: 0.9097 - val_loss: 0.3045 - learning_rate: 1.8511e-04
# Epoch 178/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8993 - loss: 0.3041 - val_binary_dice_score: 0.8942 - val_loss: 0.3367 - learning_rate: 1.8393e-04
# Epoch 179/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8756 - loss: 0.3785 - val_binary_dice_score: 0.8755 - val_loss: 0.3753 - learning_rate: 1.8276e-04
# Epoch 180/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8879 - loss: 0.3383 - val_binary_dice_score: 0.9204 - val_loss: 0.2502 - learning_rate: 1.8158e-04
# Epoch 181/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9125 - loss: 0.2768 - val_binary_dice_score: 0.9015 - val_loss: 0.2928 - learning_rate: 1.8040e-04
# Epoch 182/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9034 - loss: 0.2784 - val_binary_dice_score: 0.8689 - val_loss: 0.4443 - learning_rate: 1.7922e-04
# Epoch 183/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8248 - loss: 0.5366 - val_binary_dice_score: 0.9108 - val_loss: 0.2974 - learning_rate: 1.7804e-04
# Epoch 184/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8957 - loss: 0.3323 - val_binary_dice_score: 0.8933 - val_loss: 0.3563 - learning_rate: 1.7686e-04
# Epoch 185/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9065 - loss: 0.2713 - val_binary_dice_score: 0.9035 - val_loss: 0.3097 - learning_rate: 1.7567e-04
# Epoch 186/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8974 - loss: 0.3076 - val_binary_dice_score: 0.9151 - val_loss: 0.2654 - learning_rate: 1.7448e-04
# Epoch 187/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8703 - loss: 0.3723 - val_binary_dice_score: 0.9105 - val_loss: 0.2882 - learning_rate: 1.7329e-04
# Epoch 188/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9077 - loss: 0.2723 - val_binary_dice_score: 0.9328 - val_loss: 0.2172 - learning_rate: 1.7210e-04
# Epoch 189/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9205 - loss: 0.2487 - val_binary_dice_score: 0.9245 - val_loss: 0.2337 - learning_rate: 1.7091e-04
# Epoch 190/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9142 - loss: 0.2758 - val_binary_dice_score: 0.9345 - val_loss: 0.2208 - learning_rate: 1.6972e-04
# Epoch 191/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9121 - loss: 0.2629 - val_binary_dice_score: 0.8928 - val_loss: 0.3622 - learning_rate: 1.6852e-04
# Epoch 192/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9163 - loss: 0.2906 - val_binary_dice_score: 0.6953 - val_loss: 0.7082 - learning_rate: 1.6732e-04
# Epoch 193/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9123 - loss: 0.2625 - val_binary_dice_score: 0.9056 - val_loss: 0.3074 - learning_rate: 1.6613e-04
# Epoch 194/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8986 - loss: 0.2899 - val_binary_dice_score: 0.9272 - val_loss: 0.2382 - learning_rate: 1.6493e-04
# Epoch 195/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8922 - loss: 0.3180 - val_binary_dice_score: 0.5214 - val_loss: 1.2616 - learning_rate: 1.6373e-04
# Epoch 196/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8521 - loss: 0.4439 - val_binary_dice_score: 0.9006 - val_loss: 0.3361 - learning_rate: 1.6253e-04
# Epoch 197/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8753 - loss: 0.4089 - val_binary_dice_score: 0.8856 - val_loss: 0.3455 - learning_rate: 1.6133e-04
# Epoch 198/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8853 - loss: 0.3585 - val_binary_dice_score: 0.8061 - val_loss: 0.6097 - learning_rate: 1.6013e-04
# Epoch 199/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8837 - loss: 0.3414 - val_binary_dice_score: 0.8868 - val_loss: 0.3783 - learning_rate: 1.5893e-04
# Epoch 200/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8997 - loss: 0.2980 - val_binary_dice_score: 0.8676 - val_loss: 0.3810 - learning_rate: 1.5772e-04
# Epoch 201/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9190 - loss: 0.2697 - val_binary_dice_score: 0.7558 - val_loss: 1.0150 - learning_rate: 1.5652e-04
# Epoch 202/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9162 - loss: 0.2628 - val_binary_dice_score: 0.8954 - val_loss: 0.3708 - learning_rate: 1.5532e-04
# Epoch 203/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9189 - loss: 0.3453 - val_binary_dice_score: 0.9318 - val_loss: 0.2179 - learning_rate: 1.5411e-04
# Epoch 204/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 5s/step - binary_dice_score: 0.9063 - loss: 0.2907 - val_binary_dice_score: 0.9558 - val_loss: 0.1500 - learning_rate: 1.5291e-04
# Epoch 205/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9073 - loss: 0.3116 - val_binary_dice_score: 0.7112 - val_loss: 0.8461 - learning_rate: 1.5170e-04
# Epoch 206/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8373 - loss: 0.5201 - val_binary_dice_score: 0.8511 - val_loss: 0.5523 - learning_rate: 1.5050e-04
# Epoch 207/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8959 - loss: 0.3939 - val_binary_dice_score: 0.7192 - val_loss: 0.7311 - learning_rate: 1.4930e-04
# Epoch 208/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9061 - loss: 0.2964 - val_binary_dice_score: 0.7488 - val_loss: 0.8218 - learning_rate: 1.4809e-04
# Epoch 209/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8946 - loss: 0.3100 - val_binary_dice_score: 0.9125 - val_loss: 0.2869 - learning_rate: 1.4689e-04
# Epoch 210/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8737 - loss: 0.4426 - val_binary_dice_score: 0.9042 - val_loss: 0.2989 - learning_rate: 1.4568e-04
# Epoch 211/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 5s/step - binary_dice_score: 0.9262 - loss: 0.2362 - val_binary_dice_score: 0.9218 - val_loss: 0.2773 - learning_rate: 1.4448e-04
# Epoch 212/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9191 - loss: 0.2530 - val_binary_dice_score: 0.8992 - val_loss: 0.3141 - learning_rate: 1.4328e-04
# Epoch 213/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8987 - loss: 0.3237 - val_binary_dice_score: 0.8695 - val_loss: 0.4084 - learning_rate: 1.4207e-04
# Epoch 214/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9035 - loss: 0.2981 - val_binary_dice_score: 0.9299 - val_loss: 0.2219 - learning_rate: 1.4087e-04
# Epoch 215/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9130 - loss: 0.2756 - val_binary_dice_score: 0.9137 - val_loss: 0.2846 - learning_rate: 1.3967e-04
# Epoch 216/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9086 - loss: 0.2695 - val_binary_dice_score: 0.9355 - val_loss: 0.2111 - learning_rate: 1.3847e-04
# Epoch 217/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9228 - loss: 0.2414 - val_binary_dice_score: 0.9061 - val_loss: 0.3035 - learning_rate: 1.3727e-04
# Epoch 218/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9192 - loss: 0.2334 - val_binary_dice_score: 0.9264 - val_loss: 0.2388 - learning_rate: 1.3607e-04
# Epoch 219/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.8641 - loss: 0.4395 - val_binary_dice_score: 0.9360 - val_loss: 0.2013 - learning_rate: 1.3487e-04
# Epoch 220/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9213 - loss: 0.2298 - val_binary_dice_score: 0.9249 - val_loss: 0.2366 - learning_rate: 1.3368e-04
# Epoch 221/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9185 - loss: 0.2521 - val_binary_dice_score: 0.8783 - val_loss: 0.3547 - learning_rate: 1.3248e-04
# Epoch 222/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9084 - loss: 0.2887 - val_binary_dice_score: 0.9056 - val_loss: 0.2883 - learning_rate: 1.3128e-04
# Epoch 223/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9191 - loss: 0.2510 - val_binary_dice_score: 0.9042 - val_loss: 0.3072 - learning_rate: 1.3009e-04
# Epoch 224/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9070 - loss: 0.3675 - val_binary_dice_score: 0.9133 - val_loss: 0.2924 - learning_rate: 1.2890e-04
# Epoch 225/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8962 - loss: 0.2930 - val_binary_dice_score: 0.9157 - val_loss: 0.2707 - learning_rate: 1.2771e-04
# Epoch 226/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9085 - loss: 0.2805 - val_binary_dice_score: 0.9241 - val_loss: 0.2648 - learning_rate: 1.2652e-04
# Epoch 227/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 5s/step - binary_dice_score: 0.9206 - loss: 0.2341 - val_binary_dice_score: 0.9243 - val_loss: 0.2374 - learning_rate: 1.2533e-04
# Epoch 228/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9044 - loss: 0.2883 - val_binary_dice_score: 0.9091 - val_loss: 0.3223 - learning_rate: 1.2414e-04
# Epoch 229/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9258 - loss: 0.2334 - val_binary_dice_score: 0.9191 - val_loss: 0.2686 - learning_rate: 1.2296e-04
# Epoch 230/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9257 - loss: 0.2394 - val_binary_dice_score: 0.9046 - val_loss: 0.2741 - learning_rate: 1.2178e-04
# Epoch 231/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8939 - loss: 0.3176 - val_binary_dice_score: 0.9196 - val_loss: 0.2731 - learning_rate: 1.2060e-04
# Epoch 232/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 5s/step - binary_dice_score: 0.9191 - loss: 0.2428 - val_binary_dice_score: 0.8969 - val_loss: 0.3098 - learning_rate: 1.1942e-04
# Epoch 233/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9348 - loss: 0.2141 - val_binary_dice_score: 0.9057 - val_loss: 0.2736 - learning_rate: 1.1824e-04
# Epoch 234/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9259 - loss: 0.2385 - val_binary_dice_score: 0.9149 - val_loss: 0.2644 - learning_rate: 1.1707e-04
# Epoch 235/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.8888 - loss: 0.3483 - val_binary_dice_score: 0.9098 - val_loss: 0.2933 - learning_rate: 1.1589e-04
# Epoch 236/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9166 - loss: 0.2563 - val_binary_dice_score: 0.9314 - val_loss: 0.2076 - learning_rate: 1.1472e-04
# Epoch 237/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9263 - loss: 0.2303 - val_binary_dice_score: 0.9258 - val_loss: 0.2795 - learning_rate: 1.1355e-04
# Epoch 238/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9345 - loss: 0.1991 - val_binary_dice_score: 0.8803 - val_loss: 0.4597 - learning_rate: 1.1239e-04
# Epoch 239/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9114 - loss: 0.2571 - val_binary_dice_score: 0.9286 - val_loss: 0.2291 - learning_rate: 1.1123e-04
# Epoch 240/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9277 - loss: 0.2213 - val_binary_dice_score: 0.9259 - val_loss: 0.2281 - learning_rate: 1.1006e-04
# Epoch 241/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9020 - loss: 0.3164 - val_binary_dice_score: 0.8869 - val_loss: 0.3394 - learning_rate: 1.0891e-04
# Epoch 242/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.8910 - loss: 0.3141 - val_binary_dice_score: 0.9101 - val_loss: 0.2855 - learning_rate: 1.0775e-04
# Epoch 243/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9070 - loss: 0.3258 - val_binary_dice_score: 0.8855 - val_loss: 0.3691 - learning_rate: 1.0660e-04
# Epoch 244/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9359 - loss: 0.2110 - val_binary_dice_score: 0.9122 - val_loss: 0.2709 - learning_rate: 1.0545e-04
# Epoch 245/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9211 - loss: 0.3004 - val_binary_dice_score: 0.9306 - val_loss: 0.2169 - learning_rate: 1.0430e-04
# Epoch 246/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9007 - loss: 0.3063 - val_binary_dice_score: 0.9090 - val_loss: 0.3102 - learning_rate: 1.0316e-04
# Epoch 247/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9059 - loss: 0.2919 - val_binary_dice_score: 0.9270 - val_loss: 0.2287 - learning_rate: 1.0202e-04
# Epoch 248/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9099 - loss: 0.2728 - val_binary_dice_score: 0.9089 - val_loss: 0.2874 - learning_rate: 1.0088e-04
# Epoch 249/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9327 - loss: 0.2150 - val_binary_dice_score: 0.9260 - val_loss: 0.2317 - learning_rate: 9.9745e-05
# Epoch 250/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9324 - loss: 0.2083 - val_binary_dice_score: 0.9294 - val_loss: 0.2121 - learning_rate: 9.8614e-05
# Epoch 251/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9177 - loss: 0.2601 - val_binary_dice_score: 0.9247 - val_loss: 0.2397 - learning_rate: 9.7487e-05
# Epoch 252/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9140 - loss: 0.2526 - val_binary_dice_score: 0.9338 - val_loss: 0.2405 - learning_rate: 9.6362e-05
# Epoch 253/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9028 - loss: 0.2859 - val_binary_dice_score: 0.9151 - val_loss: 0.2540 - learning_rate: 9.5242e-05
# Epoch 254/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9187 - loss: 0.2564 - val_binary_dice_score: 0.9321 - val_loss: 0.2221 - learning_rate: 9.4124e-05
# Epoch 255/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9339 - loss: 0.2052 - val_binary_dice_score: 0.9422 - val_loss: 0.1927 - learning_rate: 9.3011e-05
# Epoch 256/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9332 - loss: 0.1978 - val_binary_dice_score: 0.9292 - val_loss: 0.2189 - learning_rate: 9.1901e-05
# Epoch 257/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9350 - loss: 0.1993 - val_binary_dice_score: 0.9317 - val_loss: 0.2065 - learning_rate: 9.0795e-05
# Epoch 258/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9263 - loss: 0.2117 - val_binary_dice_score: 0.9336 - val_loss: 0.2232 - learning_rate: 8.9693e-05
# Epoch 259/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9363 - loss: 0.1834 - val_binary_dice_score: 0.9429 - val_loss: 0.1830 - learning_rate: 8.8595e-05
# Epoch 260/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9189 - loss: 0.2525 - val_binary_dice_score: 0.9399 - val_loss: 0.1929 - learning_rate: 8.7501e-05
# Epoch 261/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9359 - loss: 0.2283 - val_binary_dice_score: 0.9118 - val_loss: 0.2827 - learning_rate: 8.6410e-05
# Epoch 262/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9410 - loss: 0.1808 - val_binary_dice_score: 0.9357 - val_loss: 0.2151 - learning_rate: 8.5325e-05
# Epoch 263/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9304 - loss: 0.2159 - val_binary_dice_score: 0.9219 - val_loss: 0.2608 - learning_rate: 8.4243e-05
# Epoch 264/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9312 - loss: 0.2504 - val_binary_dice_score: 0.9225 - val_loss: 0.2700 - learning_rate: 8.3165e-05
# Epoch 265/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9110 - loss: 0.2813 - val_binary_dice_score: 0.9243 - val_loss: 0.2471 - learning_rate: 8.2092e-05
# Epoch 266/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9263 - loss: 0.2307 - val_binary_dice_score: 0.9292 - val_loss: 0.2210 - learning_rate: 8.1024e-05
# Epoch 267/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9355 - loss: 0.1970 - val_binary_dice_score: 0.9243 - val_loss: 0.2542 - learning_rate: 7.9960e-05
# Epoch 268/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9308 - loss: 0.2066 - val_binary_dice_score: 0.9324 - val_loss: 0.2157 - learning_rate: 7.8900e-05
# Epoch 269/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9107 - loss: 0.2913 - val_binary_dice_score: 0.9336 - val_loss: 0.2276 - learning_rate: 7.7845e-05
# Epoch 270/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9238 - loss: 0.2499 - val_binary_dice_score: 0.9198 - val_loss: 0.2452 - learning_rate: 7.6795e-05
# Epoch 271/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9254 - loss: 0.2283 - val_binary_dice_score: 0.9155 - val_loss: 0.2812 - learning_rate: 7.5750e-05
# Epoch 272/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9195 - loss: 0.3434 - val_binary_dice_score: 0.9305 - val_loss: 0.2318 - learning_rate: 7.4710e-05
# Epoch 273/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9223 - loss: 0.2485 - val_binary_dice_score: 0.9165 - val_loss: 0.2657 - learning_rate: 7.3674e-05
# Epoch 274/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9091 - loss: 0.2820 - val_binary_dice_score: 0.9021 - val_loss: 0.2935 - learning_rate: 7.2643e-05
# Epoch 275/400
# ...
# Epoch 310/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9309 - loss: 0.2249 - val_binary_dice_score: 0.9312 - val_loss: 0.2152 - learning_rate: 3.9400e-05
# Epoch 311/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9392 - loss: 0.1988 - val_binary_dice_score: 0.9091 - val_loss: 0.3549 - learning_rate: 3.8598e-05
# Epoch 312/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - binary_dice_score: 0.9224 - loss: 0.2373 - val_binary_dice_score: 0.9321 - val_loss: 0.2108 - learning_rate: 3.7803e-05
# Epoch 313/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9272 - loss: 0.2197 - val_binary_dice_score: 0.9274 - val_loss: 0.2303 - learning_rate: 3.7015e-05
# Epoch 314/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9403 - loss: 0.1866 - val_binary_dice_score: 0.9109 - val_loss: 0.3291 - learning_rate: 3.6235e-05
# Epoch 315/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9265 - loss: 0.2383 - val_binary_dice_score: 0.9323 - val_loss: 0.2523 - learning_rate: 3.5462e-05
# Epoch 316/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9474 - loss: 0.1664 - val_binary_dice_score: 0.9263 - val_loss: 0.2390 - learning_rate: 3.4697e-05
# Epoch 317/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9375 - loss: 0.1880 - val_binary_dice_score: 0.9307 - val_loss: 0.2202 - learning_rate: 3.3939e-05
# Epoch 318/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9477 - loss: 0.1613 - val_binary_dice_score: 0.9441 - val_loss: 0.1792 - learning_rate: 3.3188e-05
# Epoch 319/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9335 - loss: 0.2198 - val_binary_dice_score: 0.9367 - val_loss: 0.2014 - learning_rate: 3.2446e-05
# Epoch 320/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9224 - loss: 0.2174 - val_binary_dice_score: 0.9355 - val_loss: 0.2027 - learning_rate: 3.1711e-05
# Epoch 321/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9051 - loss: 0.2920 - val_binary_dice_score: 0.9255 - val_loss: 0.2392 - learning_rate: 3.0983e-05
# Epoch 322/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9149 - loss: 0.2590 - val_binary_dice_score: 0.9349 - val_loss: 0.2054 - learning_rate: 3.0264e-05
# Epoch 323/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.8866 - loss: 0.3277 - val_binary_dice_score: 0.9251 - val_loss: 0.2394 - learning_rate: 2.9552e-05
# Epoch 324/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.8839 - loss: 0.3465 - val_binary_dice_score: 0.9338 - val_loss: 0.2208 - learning_rate: 2.8848e-05
# Epoch 325/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9253 - loss: 0.2359 - val_binary_dice_score: 0.9040 - val_loss: 0.3012 - learning_rate: 2.8152e-05
# Epoch 326/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9408 - loss: 0.1920 - val_binary_dice_score: 0.9255 - val_loss: 0.2404 - learning_rate: 2.7464e-05
# Epoch 327/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9351 - loss: 0.1920 - val_binary_dice_score: 0.9341 - val_loss: 0.2110 - learning_rate: 2.6784e-05
# Epoch 328/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9349 - loss: 0.2116 - val_binary_dice_score: 0.9439 - val_loss: 0.1796 - learning_rate: 2.6112e-05
# Epoch 329/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9171 - loss: 0.2622 - val_binary_dice_score: 0.9252 - val_loss: 0.2388 - learning_rate: 2.5448e-05
# Epoch 330/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9238 - loss: 0.3057 - val_binary_dice_score: 0.9270 - val_loss: 0.2401 - learning_rate: 2.4792e-05
# Epoch 331/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9405 - loss: 0.1896 - val_binary_dice_score: 0.9486 - val_loss: 0.1727 - learning_rate: 2.4144e-05
# Epoch 332/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9353 - loss: 0.1943 - val_binary_dice_score: 0.9353 - val_loss: 0.2202 - learning_rate: 2.3505e-05
# Epoch 333/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9409 - loss: 0.1897 - val_binary_dice_score: 0.9231 - val_loss: 0.2930 - learning_rate: 2.2873e-05
# Epoch 334/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9201 - loss: 0.2387 - val_binary_dice_score: 0.9346 - val_loss: 0.2114 - learning_rate: 2.2250e-05
# Epoch 335/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9339 - loss: 0.2009 - val_binary_dice_score: 0.9365 - val_loss: 0.2123 - learning_rate: 2.1636e-05
# Epoch 336/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9480 - loss: 0.1574 - val_binary_dice_score: 0.9438 - val_loss: 0.1856 - learning_rate: 2.1029e-05
# Epoch 337/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9292 - loss: 0.2129 - val_binary_dice_score: 0.9297 - val_loss: 0.2153 - learning_rate: 2.0431e-05
# Epoch 338/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9313 - loss: 0.2042 - val_binary_dice_score: 0.9309 - val_loss: 0.2208 - learning_rate: 1.9842e-05
# Epoch 339/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.8925 - loss: 0.3563 - val_binary_dice_score: 0.9137 - val_loss: 0.2993 - learning_rate: 1.9261e-05
# Epoch 340/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9356 - loss: 0.1958 - val_binary_dice_score: 0.8888 - val_loss: 0.3545 - learning_rate: 1.8688e-05
# Epoch 341/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9269 - loss: 0.3113 - val_binary_dice_score: 0.9368 - val_loss: 0.2084 - learning_rate: 1.8124e-05
# Epoch 342/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9206 - loss: 0.2370 - val_binary_dice_score: 0.9322 - val_loss: 0.2458 - learning_rate: 1.7569e-05
# Epoch 343/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9286 - loss: 0.2410 - val_binary_dice_score: 0.9369 - val_loss: 0.2132 - learning_rate: 1.7022e-05
# Epoch 344/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9222 - loss: 0.2263 - val_binary_dice_score: 0.9338 - val_loss: 0.2074 - learning_rate: 1.6484e-05
# Epoch 345/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9477 - loss: 0.1672 - val_binary_dice_score: 0.9319 - val_loss: 0.2133 - learning_rate: 1.5955e-05
# Epoch 346/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9126 - loss: 0.3067 - val_binary_dice_score: 0.9225 - val_loss: 0.2702 - learning_rate: 1.5434e-05
# Epoch 347/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9314 - loss: 0.2362 - val_binary_dice_score: 0.9221 - val_loss: 0.2501 - learning_rate: 1.4922e-05
# Epoch 348/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9353 - loss: 0.1986 - val_binary_dice_score: 0.9411 - val_loss: 0.1857 - learning_rate: 1.4419e-05
# Epoch 349/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9406 - loss: 0.1744 - val_binary_dice_score: 0.9293 - val_loss: 0.2295 - learning_rate: 1.3925e-05
# Epoch 350/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9443 - loss: 0.1705 - val_binary_dice_score: 0.9361 - val_loss: 0.2063 - learning_rate: 1.3440e-05
# Epoch 351/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9084 - loss: 0.2985 - val_binary_dice_score: 0.9317 - val_loss: 0.2218 - learning_rate: 1.2963e-05
# Epoch 352/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9455 - loss: 0.1654 - val_binary_dice_score: 0.9273 - val_loss: 0.2472 - learning_rate: 1.2496e-05
# Epoch 353/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9255 - loss: 0.2400 - val_binary_dice_score: 0.9196 - val_loss: 0.2522 - learning_rate: 1.2037e-05
# Epoch 354/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9357 - loss: 0.2147 - val_binary_dice_score: 0.9304 - val_loss: 0.2329 - learning_rate: 1.1587e-05
# Epoch 355/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9328 - loss: 0.1994 - val_binary_dice_score: 0.9269 - val_loss: 0.2536 - learning_rate: 1.1147e-05
# Epoch 356/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9334 - loss: 0.2165 - val_binary_dice_score: 0.9340 - val_loss: 0.2114 - learning_rate: 1.0715e-05
# Epoch 357/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9376 - loss: 0.1923 - val_binary_dice_score: 0.9157 - val_loss: 0.2678 - learning_rate: 1.0293e-05
# Epoch 358/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9370 - loss: 0.1870 - val_binary_dice_score: 0.9344 - val_loss: 0.2194 - learning_rate: 9.8792e-06
# Epoch 359/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9253 - loss: 0.2730 - val_binary_dice_score: 0.9500 - val_loss: 0.1684 - learning_rate: 9.4749e-06
# Epoch 360/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9443 - loss: 0.1744 - val_binary_dice_score: 0.9349 - val_loss: 0.2277 - learning_rate: 9.0798e-06
# Epoch 361/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9427 - loss: 0.1665 - val_binary_dice_score: 0.9039 - val_loss: 0.3409 - learning_rate: 8.6938e-06
# Epoch 362/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - binary_dice_score: 0.9337 - loss: 0.2003 - val_binary_dice_score: 0.9330 - val_loss: 0.2221 - learning_rate: 8.3171e-06
# Epoch 363/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9421 - loss: 0.1718 - val_binary_dice_score: 0.9310 - val_loss: 0.2212 - learning_rate: 7.9495e-06
# Epoch 364/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9395 - loss: 0.1756 - val_binary_dice_score: 0.9336 - val_loss: 0.2072 - learning_rate: 7.5913e-06
# Epoch 365/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9316 - loss: 0.2045 - val_binary_dice_score: 0.9328 - val_loss: 0.2107 - learning_rate: 7.2422e-06
# Epoch 366/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9444 - loss: 0.1656 - val_binary_dice_score: 0.9463 - val_loss: 0.1697 - learning_rate: 6.9025e-06
# Epoch 367/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9454 - loss: 0.1839 - val_binary_dice_score: 0.9393 - val_loss: 0.2120 - learning_rate: 6.5722e-06
# Epoch 368/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9261 - loss: 0.2292 - val_binary_dice_score: 0.9230 - val_loss: 0.2594 - learning_rate: 6.2511e-06
# Epoch 369/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9335 - loss: 0.2016 - val_binary_dice_score: 0.9325 - val_loss: 0.2146 - learning_rate: 5.9394e-06
# Epoch 370/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9299 - loss: 0.2143 - val_binary_dice_score: 0.9376 - val_loss: 0.2024 - learning_rate: 5.6371e-06
# Epoch 371/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9367 - loss: 0.1908 - val_binary_dice_score: 0.9235 - val_loss: 0.2336 - learning_rate: 5.3442e-06
# Epoch 372/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9350 - loss: 0.1905 - val_binary_dice_score: 0.9252 - val_loss: 0.2438 - learning_rate: 5.0607e-06
# Epoch 373/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9151 - loss: 0.2454 - val_binary_dice_score: 0.9217 - val_loss: 0.2709 - learning_rate: 4.7867e-06
# Epoch 374/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9275 - loss: 0.2234 - val_binary_dice_score: 0.9451 - val_loss: 0.1718 - learning_rate: 4.5221e-06
# Epoch 375/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9317 - loss: 0.2293 - val_binary_dice_score: 0.9136 - val_loss: 0.2805 - learning_rate: 4.2669e-06
# Epoch 376/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9290 - loss: 0.2133 - val_binary_dice_score: 0.9352 - val_loss: 0.2201 - learning_rate: 4.0213e-06
# Epoch 377/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9432 - loss: 0.2048 - val_binary_dice_score: 0.9442 - val_loss: 0.1829 - learning_rate: 3.7852e-06
# Epoch 378/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9400 - loss: 0.1788 - val_binary_dice_score: 0.9347 - val_loss: 0.2161 - learning_rate: 3.5586e-06
# Epoch 379/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9385 - loss: 0.1833 - val_binary_dice_score: 0.9050 - val_loss: 0.3391 - learning_rate: 3.3415e-06
# Epoch 380/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 5s/step - binary_dice_score: 0.9461 - loss: 0.1668 - val_binary_dice_score: 0.9427 - val_loss: 0.1870 - learning_rate: 3.1340e-06
# Epoch 381/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9459 - loss: 0.1717 - val_binary_dice_score: 0.9079 - val_loss: 0.2811 - learning_rate: 2.9360e-06
# Epoch 382/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9391 - loss: 0.1822 - val_binary_dice_score: 0.9393 - val_loss: 0.2087 - learning_rate: 2.7476e-06
# Epoch 383/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9367 - loss: 0.1839 - val_binary_dice_score: 0.9247 - val_loss: 0.2629 - learning_rate: 2.5688e-06
# Epoch 384/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9331 - loss: 0.2022 - val_binary_dice_score: 0.9275 - val_loss: 0.2415 - learning_rate: 2.3996e-06
# Epoch 385/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9257 - loss: 0.2516 - val_binary_dice_score: 0.9481 - val_loss: 0.1664 - learning_rate: 2.2400e-06
# Epoch 386/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9467 - loss: 0.1592 - val_binary_dice_score: 0.9334 - val_loss: 0.2094 - learning_rate: 2.0900e-06
# Epoch 387/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9431 - loss: 0.1767 - val_binary_dice_score: 0.9298 - val_loss: 0.2144 - learning_rate: 1.9497e-06
# Epoch 388/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9254 - loss: 0.2217 - val_binary_dice_score: 0.9354 - val_loss: 0.2155 - learning_rate: 1.8190e-06
# Epoch 389/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9221 - loss: 0.2629 - val_binary_dice_score: 0.9399 - val_loss: 0.1843 - learning_rate: 1.6979e-06
# Epoch 390/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - binary_dice_score: 0.9087 - loss: 0.3183 - val_binary_dice_score: 0.9499 - val_loss: 0.1539 - learning_rate: 1.5865e-06
# Epoch 391/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - binary_dice_score: 0.9430 - loss: 0.1813 - val_binary_dice_score: 0.9403 - val_loss: 0.1986 - learning_rate: 1.4848e-06
# Epoch 392/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9410 - loss: 0.1766 - val_binary_dice_score: 0.9384 - val_loss: 0.2114 - learning_rate: 1.3927e-06
# Epoch 393/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9405 - loss: 0.1847 - val_binary_dice_score: 0.9439 - val_loss: 0.1871 - learning_rate: 1.3103e-06
# Epoch 394/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9081 - loss: 0.3061 - val_binary_dice_score: 0.9435 - val_loss: 0.1816 - learning_rate: 1.2376e-06
# Epoch 395/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9448 - loss: 0.1667 - val_binary_dice_score: 0.9426 - val_loss: 0.1874 - learning_rate: 1.1746e-06
# Epoch 396/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9347 - loss: 0.2037 - val_binary_dice_score: 0.9401 - val_loss: 0.1913 - learning_rate: 1.1212e-06
# Epoch 397/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9459 - loss: 0.1983 - val_binary_dice_score: 0.9370 - val_loss: 0.2122 - learning_rate: 1.0776e-06
# Epoch 398/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9164 - loss: 0.2820 - val_binary_dice_score: 0.9398 - val_loss: 0.1905 - learning_rate: 1.0437e-06
# Epoch 399/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - binary_dice_score: 0.9248 - loss: 0.2259 - val_binary_dice_score: 0.9389 - val_loss: 0.2098 - learning_rate: 1.0194e-06
# Epoch 400/400
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - binary_dice_score: 0.9421 - loss: 0.1773 - val_binary_dice_score: 0.9226 - val_loss: 0.2582 - learning_rate: 1.0049e-06
#
# Best val Dice: 0.0000

# %%
metric_key = [k for k in history.history.keys() if "dice" in k and "val" not in k][0]
val_metric_key = [k for k in history.history.keys() if "dice" in k and "val" in k][0]

fig, axes = plt.subplots(1, 3, figsize=(18, 4))

axes[0].plot(history.history["loss"],     label="Train", alpha=0.8)
axes[0].plot(history.history["val_loss"], label="Val", alpha=0.8)
axes[0].set_title("Loss"); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history[metric_key],     label="Train", alpha=0.8)
axes[1].plot(history.history[val_metric_key], label="Val", alpha=0.8)
axes[1].axhline(y=0.90, color='red', linestyle='--', alpha=0.5, label='Target')
axes[1].set_title("Dice"); axes[1].set_ylim(0, 1)
axes[1].legend(); axes[1].grid(alpha=0.3)

n = len(history.history["loss"])
axes[2].plot([warmup_cosine_lr(e, None) for e in range(n)])
axes[2].set_title("LR"); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(str(OUT_DIR / "training_curves.png"), dpi=150)
plt.show()

final_train = history.history[metric_key][-1]
final_val   = history.history[val_metric_key][-1]
print(f"Train Dice: {final_train:.4f}  Val Dice: {final_val:.4f}  Gap: {final_train - final_val:.4f}")
# Out:
# Train Dice: 0.9428  Val Dice: 0.9226  Gap: 0.0201

# %%
from medicai.utils.inference import SlidingWindowInference

def predict_volume(model, image_path, label_path):
    data, meta = load_pair(image_path, label_path)
    pre = Compose([
        ScaleIntensityRange(
            keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForeground(keys=("image", "label"), source_key="image"),
    ])
    out = pre(data, meta)
    ct = out["image"]
    gt = out["label"]
    if hasattr(ct, "numpy"): ct = ct.numpy()
    if hasattr(gt, "numpy"): gt = gt.numpy()

    swi = SlidingWindowInference(
        model=model, num_classes=1, roi_size=CROP_SHAPE,
        sw_batch_size=2, overlap=0.5, mode='gaussian',
    )
    pred     = np.array(swi(ct[np.newaxis]))[0]
    pred_bin = (1.0 / (1.0 + np.exp(-pred)) > 0.5).astype(np.float32)
    inter    = (pred_bin * gt).sum()
    dice     = float(2.0 * inter / (pred_bin.sum() + gt.sum() + 1e-6))
    return ct, gt, pred_bin, dice

# %%
best_model = SegFormer(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='mit_b1',
    classifier_activation=None,
)

best_model.load_weights(
    str(OUT_DIR / "best_model.keras"),
)

best_model.compile(
  optimizer=keras.optimizers.AdamW(
    learning_rate=MIN_LR,
    weight_decay=WEIGHT_DECAY
  ),
  loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
  metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)
results = []
for p in val_pairs:
    _, _, _, dice = predict_volume(best_model, p["image"], p["label"])
    results.append({"scan_id": p["scan_id"], "dice": dice})
    print(f"  {p['scan_id']}  Dice={dice:.4f}")

dices = [r["dice"] for r in results]
print(f"\nMean={np.mean(dices):.4f}  Std={np.std(dices):.4f}  Min={np.min(dices):.4f}  Max={np.max(dices):.4f}")
# Out:
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.72it/s]
#   be9fa3df918a  Dice=0.9487
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.69it/s]
#   092c97ecec4b  Dice=0.9164
# Total patch 32: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
#   ed66d74f6692  Dice=0.9352
# Total patch 27: 100%|██████████| 14/14 [00:08<00:00,  1.69it/s]
#   d86566fdb41c  Dice=0.9256
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.72it/s]
#   2eb903f4f204  Dice=0.9447
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.71it/s]
#   4d9723eef946  Dice=0.8884
# Total patch 32: 100%|██████████| 16/16 [00:09<00:00,  1.74it/s]
#   43ca4b1f6495  Dice=0.9417
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.72it/s]
#   8781c0349102  Dice=0.9294
#
# Mean=0.9288  Std=0.0182  Min=0.8884  Max=0.9487

# %%
def visualise(ct, gt, pred, scan_id, dice, n_slices=6):
    D = ct.shape[0]
    idxs = np.linspace(D // 4, 3 * D // 4, n_slices, dtype=int)
    fig, axes = plt.subplots(3, n_slices, figsize=(3 * n_slices, 9))
    fig.suptitle(f"{scan_id}  Dice={dice:.4f}", fontsize=13, fontweight="bold")
    for col, idx in enumerate(idxs):
        s, g, p = ct[idx,:,:,0], gt[idx,:,:,0], pred[idx,:,:,0]
        axes[0,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[0,col].set_title(f"CT z={idx}", fontsize=8); axes[0,col].axis("off")
        axes[1,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[1,col].imshow(g, cmap="Reds",  alpha=0.45)
        axes[1,col].set_title("GT", fontsize=8); axes[1,col].axis("off")
        axes[2,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[2,col].imshow(p, cmap="Blues", alpha=0.45)
        axes[2,col].set_title("Pred", fontsize=8); axes[2,col].axis("off")
    plt.tight_layout()
    plt.savefig(str(OUT_DIR / f"{scan_id}_pred.png"), dpi=150, bbox_inches="tight")
    plt.show()

for res in [max(results, key=lambda r: r["dice"]), min(results, key=lambda r: r["dice"])]:
    p = next(x for x in val_pairs if x["scan_id"] == res["scan_id"])
    ct, gt, pred, dice = predict_volume(best_model, p["image"], p["label"])
    visualise(ct, gt, pred, res["scan_id"], dice)
# Out:
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.70it/s]
# Total patch 18: 100%|██████████| 9/9 [00:05<00:00,  1.75it/s]

# %%
stats = {
    "model":         "UNet_resnet18",
    "backend":       keras.config.backend(),
    "mean_dice":     round(float(np.mean(dices)), 4),
    "std_dice":      round(float(np.std(dices)),  4),
    "n_train":       len(train_pairs),
    "n_val":         len(val_pairs),
    "crop_shape":    list(CROP_SHAPE),
    "hu_window":     [HU_MIN, HU_MAX],
    "epochs_trained": len(history.history["loss"]),
    "best_val_dice": round(float(max(history.history.get("val_binary_dice_metric", [0]))), 4),
    "total_params":  model.count_params(),
    "weight_decay":  WEIGHT_DECAY,
    "num_samples":   NUM_SAMPLES,
    "per_scan":      results,
}
with open(OUT_DIR / "eval_stats.json", "w") as f:
    json.dump(stats, f, indent=2)
print(json.dumps({k: v for k, v in stats.items() if k != "per_scan"}, indent=2))
# Out:
# {
#   "model": "UNet_resnet18",
#   "backend": "torch",
#   "mean_dice": 0.9288,
#   "std_dice": 0.0182,
#   "n_train": 39,
#   "n_val": 8,
#   "crop_shape": [
#     160,
#     160,
#     160
#   ],
#   "hu_window": [
#     -175,
#     400
#   ],
#   "epochs_trained": 400,
#   "best_val_dice": 0.0,
#   "total_params": 16623425,
#   "weight_decay": 0.0005,
#   "num_samples": 1
# }
