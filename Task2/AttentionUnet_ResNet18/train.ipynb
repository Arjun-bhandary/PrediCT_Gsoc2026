# %%
# !pip install git+https://github.com/innat/medic-ai.git -q
# !pip install scikit-learn nibabel -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for medicai (pyproject.toml) ... done

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import json
import math
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split

import keras
import torch

from medicai.models import UNet,AttentionUNet
from medicai.losses import BinaryDiceCELoss
from medicai.metrics import BinaryDiceMetric
from medicai.transforms import (
    Compose,
    ScaleIntensityRange,
    CropForeground,
    RandCropByPosNegLabel,
    RandFlip,
    RandRotate90,
    RandShiftIntensity,
)

print(f"Backend : {keras.config.backend()}")
print(f"Keras   : {keras.version()}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
    print(f"VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# 2026-03-22 15:40:31.632645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774194031.810289      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774194031.864654      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774194032.275117      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774194032.275150      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774194032.275153      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774194032.275155      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Backend : torch
# Keras   : 3.10.0
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
CT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/gsoc-coca-segment/data_totalseg/inputs")
GT_DIR  = Path("/kaggle/input/datasets/arjunashokbhandary/coca-gt/kaggle/working/gsoc-coca-gt")
OUT_DIR = Path("/kaggle/working/heart_seg_output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
CROP_SHAPE    = (128, 128, 128)
HU_MIN        = -175
HU_MAX        = 400
BATCH_SIZE    = 2
NUM_SAMPLES   = 1
EPOCHS        = 200
WARMUP_EPOCHS = 10
LEARNING_RATE = 3e-4
MIN_LR        = 1e-6
WEIGHT_DECAY  = 5e-4
VAL_SPLIT     = 0.15
SEED          = 50

# %%
import medicai
print(medicai.models.list_models())
# Out:
#                      Model Registry Catalog
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Segmentor        ┃ Backbone Family ┃ Variants                 ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ • attention_unet │ convnext        │ • convnext_base          │
# │ • deeplabv3plus  │                 │ • convnext_large         │
# │ • unet           │                 │ • convnext_small         │
# │ • unet_plus_plus │                 │ • convnext_tiny          │
# │ • upernet        │                 │ • convnext_v2_atto       │
# │                  │                 │ • convnext_v2_base       │
# │                  │                 │ • convnext_v2_femto      │
# │                  │                 │ • convnext_v2_huge       │
# │                  │                 │ • convnext_v2_large      │
# │                  │                 │ • convnext_v2_nano       │
# │                  │                 │ • convnext_v2_pico       │
# │                  │                 │ • convnext_v2_small      │
# │                  │                 │ • convnext_v2_tiny       │
# │                  │                 │ • convnext_xlarge        │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ densenet        │ • densenet121            │
# │ • deeplabv3plus  │                 │ • densenet169            │
# │ • trans_unet     │                 │ • densenet201            │
# │ • unet           │                 │ • densenet264            │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ efficientnet    │ • efficientnet_b0        │
# │ • deeplabv3plus  │                 │ • efficientnet_b1        │
# │ • trans_unet     │                 │ • efficientnet_b2        │
# │ • unet           │                 │ • efficientnet_b3        │
# │ • unet_plus_plus │                 │ • efficientnet_b4        │
# │ • upernet        │                 │ • efficientnet_b5        │
# │                  │                 │ • efficientnet_b6        │
# │                  │                 │ • efficientnet_b7        │
# │                  │                 │ • efficientnet_b8        │
# │                  │                 │ • efficientnet_l2        │
# │                  │                 │ • efficientnet_v2_b0     │
# │                  │                 │ • efficientnet_v2_b1     │
# │                  │                 │ • efficientnet_v2_b2     │
# │                  │                 │ • efficientnet_v2_b3     │
# │                  │                 │ • efficientnet_v2_l      │
# │                  │                 │ • efficientnet_v2_m      │
# │                  │                 │ • efficientnet_v2_s      │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • segformer      │ mit             │ • mit_b0                 │
# │ • upernet        │                 │ • mit_b1                 │
# │                  │                 │ • mit_b2                 │
# │                  │                 │ • mit_b3                 │
# │                  │                 │ • mit_b4                 │
# │                  │                 │ • mit_b5                 │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ resnet          │ • resnet101              │
# │ • deeplabv3plus  │                 │ • resnet101_v2           │
# │ • trans_unet     │                 │ • resnet152              │
# │ • unet           │                 │ • resnet152_v2           │
# │ • unet_plus_plus │                 │ • resnet18               │
# │ • upernet        │                 │ • resnet200_vd           │
# │                  │                 │ • resnet34               │
# │                  │                 │ • resnet50               │
# │                  │                 │ • resnet50_v2            │
# │                  │                 │ • resnet50_vd            │
# │                  │                 │ • resnext101             │
# │                  │                 │ • resnext50              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ senet           │ • seresnet101            │
# │ • deeplabv3plus  │                 │ • seresnet101_v2         │
# │ • trans_unet     │                 │ • seresnet152            │
# │ • unet           │                 │ • seresnet152_v2         │
# │ • unet_plus_plus │                 │ • seresnet18             │
# │ • upernet        │                 │ • seresnet200_vd         │
# │                  │                 │ • seresnet34             │
# │                  │                 │ • seresnet50             │
# │                  │                 │ • seresnet50_v2          │
# │                  │                 │ • seresnet50_vd          │
# │                  │                 │ • seresnext101           │
# │                  │                 │ • seresnext50            │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • swin_unetr     │ swin            │ • swin_base              │
# │ • upernet        │                 │ • swin_base_v2           │
# │                  │                 │ • swin_small             │
# │                  │                 │ • swin_small_v2          │
# │                  │                 │ • swin_tiny              │
# │                  │                 │ • swin_tiny_v2           │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr_plusplus │ unetr_plusplus  │ • unetr_plusplus_encoder │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • unetr          │ vit             │ • vit_base               │
# │                  │                 │ • vit_huge               │
# │                  │                 │ • vit_large              │
# ├──────────────────┼─────────────────┼──────────────────────────┤
# │ • attention_unet │ xception        │ • xception               │
# │ • trans_unet     │                 │                          │
# │ • unet           │                 │                          │
# │ • unet_plus_plus │                 │                          │
# │ • upernet        │                 │                          │
# └──────────────────┴─────────────────┴──────────────────────────┘

# %%
def discover_pairs(ct_dir, gt_dir):
    pairs = []
    for ct_path in sorted(list(ct_dir.glob("*_img.nii.gz")) + list(ct_dir.glob("*_img.nii"))):
        scan_id = ct_path.name.replace("_img.nii.gz", "").replace("_img.nii", "")
        for ext in (".nii.gz", ".nii"):
            gt_path = gt_dir / scan_id / f"{scan_id}_binary{ext}"
            if gt_path.exists():
                pairs.append({"scan_id": scan_id, "image": str(ct_path), "label": str(gt_path)})
                break
    return pairs

pairs = discover_pairs(CT_DIR, GT_DIR)
print(f"Found {len(pairs)} pairs")

train_pairs, val_pairs = train_test_split(pairs, test_size=VAL_SPLIT, random_state=SEED)
print(f"Train={len(train_pairs)}  Val={len(val_pairs)}")
# Out:
# Found 47 pairs
# Train=39  Val=8

# %%
def load_pair(image_path, label_path):
    image_nii = nib.load(image_path)
    label_nii = nib.load(label_path)
    image  = image_nii.get_fdata().astype(np.float32)
    label  = label_nii.get_fdata().astype(np.float32)
    affine = np.array(image_nii.affine, dtype=np.float32)
    image  = np.transpose(image, (2, 1, 0))
    label  = np.transpose(label, (2, 1, 0))
    affine[:, :3] = affine[:, [2, 1, 0]]
    label = (label > 0.5).astype(np.float32)
    image = image[..., np.newaxis]
    label = label[..., np.newaxis]
    return {"image": image, "label": label}, {"affine": affine}

_d, _ = load_pair(pairs[0]["image"], pairs[0]["label"])
print(f"image: {_d['image'].shape}   label: {_d['label'].shape}")
print(f"Label fraction: {_d['label'].mean():.4f}")
# Out:
# image: (219, 309, 309, 1)   label: (219, 309, 309, 1)
# Label fraction: 0.1100

# %%
train_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=2, neg=1, num_samples=NUM_SAMPLES,
        image_reference_key="image", image_threshold=0,
    ),
    RandFlip(keys=["image", "label"], spatial_axis=[0], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[1], prob=0.5),
    RandFlip(keys=["image", "label"], spatial_axis=[2], prob=0.5),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(0, 1)),
    RandRotate90(keys=["image", "label"], prob=0.5, max_k=3, spatial_axes=(1, 2)),
    RandShiftIntensity(keys=["image"], offsets=0.2, prob=0.8),
])

val_transform = Compose([
    ScaleIntensityRange(
        keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
        b_min=0.0, b_max=1.0, clip=True,
    ),
    CropForeground(keys=("image", "label"), source_key="image"),
    RandCropByPosNegLabel(
        keys=["image", "label"], spatial_size=CROP_SHAPE,
        pos=1, neg=0, num_samples=1,
        image_reference_key="image", image_threshold=0,
    ),
])

print("Transforms ready")
# Out:
# Transforms ready

# %%
class HeartSegDataset(keras.utils.PyDataset):
    def __init__(self, pairs, transform, batch_size, num_samples=1, shuffle=False, **kw):
        super().__init__(**kw)
        self.pairs      = pairs
        self.transform  = transform
        self.batch_size = batch_size
        self.num_samples = num_samples
        self.shuffle    = shuffle
        self._build_index()

    def _build_index(self):
        self._index = [(vi, ci) for vi in range(len(self.pairs))
                                for ci in range(self.num_samples)]
        if self.shuffle:
            np.random.shuffle(self._index)

    def __len__(self):
        return math.ceil(len(self._index) / self.batch_size)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self._index)

    def __getitem__(self, idx):
        batch = self._index[idx * self.batch_size : (idx + 1) * self.batch_size]
        images, labels = [], []
        for vi, ci in batch:
            p = self.pairs[vi]
            data, meta = load_pair(p["image"], p["label"])
            out = self.transform(data, meta)
            img, lbl = out["image"], out["label"]
            if isinstance(img, list):
                ci = min(ci, len(img) - 1)
                img, lbl = img[ci], lbl[ci]
            if hasattr(img, "numpy"): img = img.numpy()
            if hasattr(lbl, "numpy"): lbl = lbl.numpy()
            images.append(img)
            labels.append(lbl)
        return np.stack(images), np.stack(labels)


train_ds = HeartSegDataset(
    train_pairs, train_transform,
    batch_size=BATCH_SIZE, num_samples=NUM_SAMPLES, shuffle=True,
)
val_ds = HeartSegDataset(
    val_pairs, val_transform,
    batch_size=1, num_samples=1, shuffle=False,
)

_x, _y = train_ds[0]
print(f"Batch: {_x.shape}  [{_x.min():.2f}, {_x.max():.2f}]")
print(f"Label: {_y.shape}  heart voxels={int(_y.sum())}")
print(f"Steps/epoch: {len(train_ds)} train, {len(val_ds)} val")
# Out:
# I0000 00:00:1774194050.984880      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Batch: (2, 128, 128, 128, 1)  [-0.01, 0.99]
# Label: (2, 128, 128, 128, 1)  heart voxels=2162205
# Steps/epoch: 20 train, 8 val

# %%
model = AttentionUNet(
    input_shape=(*CROP_SHAPE, 1),
    num_classes=1,
    encoder_name='resnet18',
    classifier_activation=None,
)

print(f"Parameters: {model.count_params():,}")
model.summary(line_length=100)
# Out:
# Parameters: 42,885,877
# Model: "AttentionUNet3D"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 128, 128, 128,   │              0 │ -                       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_pad (ZeroPadding3D)   │ (None, 134, 134, 134,   │              0 │ input_layer[0][0]       │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_conv (Conv3D)         │ (None, 64, 64, 64, 64)  │         21,952 │ conv1_pad[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_bn                    │ (None, 64, 64, 64, 64)  │            256 │ conv1_conv[0][0]        │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_relu (Activation)     │ (None, 64, 64, 64, 64)  │              0 │ conv1_bn[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool1_pad (ZeroPadding3D)   │ (None, 66, 66, 66, 64)  │              0 │ conv1_relu[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool1_pool (MaxPooling3D)   │ (None, 32, 32, 32, 64)  │              0 │ pool1_pad[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ pool1_pool[0][0]        │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block0_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_1_relu        │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_2_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_2_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_add (Add)     │ (None, 32, 32, 32, 64)  │              0 │ pool1_pool[0][0],       │
# │                             │                         │                │ stack0_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block0_out           │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_1_relu        │ (None, 32, 32, 32, 64)  │              0 │ stack0_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_2_conv        │ (None, 32, 32, 32, 64)  │        110,592 │ stack0_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_2_bn          │ (None, 32, 32, 32, 64)  │            256 │ stack0_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_add (Add)     │ (None, 32, 32, 32, 64)  │              0 │ stack0_block0_out[0][0… │
# │                             │                         │                │ stack0_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack0_block1_out           │ (None, 32, 32, 32, 64)  │              0 │ stack0_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_pad         │ (None, 34, 34, 34, 64)  │              0 │ stack0_block1_out[0][0] │
# │ (ZeroPadding3D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0_1_conv        │ (None, 16, 16, 16, 128) │        221,184 │ stack1_block0_1_pad[0]… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack1_block0
1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_1_relu        │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_0_conv        │ (None, 4, 4, 4, 512)    │        131,072 │ stack2_block1_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_2_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block0_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_0_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block0_0_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_2_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block0_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_add (Add)     │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_0_bn[0][… │
# │                             │                         │                │ stack3_block0_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block0_out           │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block0_out[0][0] │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block1_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_1_relu        │ (None, 4, 4, 4, 512)    │              0 │ stack3_block1_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_2_conv        │ (None, 4, 4, 4, 512)    │      7,077,888 │ stack3_block1_1_relu[0… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_2_bn          │ (None, 4, 4, 4, 512)    │          2,048 │ stack3_block1_2_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_add (Add)     │ (None, 4, 4, 4, 512)    │              0 │ stack3_block0_out[0][0… │
# │                             │                         │                │ stack3_block1_2_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stack3_block1_out           │ (None, 4, 4, 4, 512)    │              0 │ stack3_block1_add[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_upsampling_… │ (None, 8, 8, 8, 512)    │              0 │ stack3_block1_out[0][0] │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_attention_g… │ (None, 8, 8, 8, 256)    │        197,377 │ stack2_block1_out[0][0… │
# │ (AttentionGate)             │                         │                │ stack3_block1_out[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_concat       │ (None, 8, 8, 8, 768)    │              0 │ decoder_stage5_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage5_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_conv… │ (None, 8, 8, 8, 256)    │      5,308,416 │ decoder_stage5_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_1_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_conv… │ (None, 8, 8, 8, 256)    │      1,769,472 │ decoder_stage5_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_norm… │ (None, 8, 8, 8, 256)    │          1,024 │ decoder_stage5_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage5_conv_2_acti… │ (None, 8, 8, 8, 256)    │              0 │ decoder_stage5_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_upsampling_… │ (None, 16, 16, 16, 256) │              0 │ decoder_stage5_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_attention_g… │ (None, 16, 16, 16, 128) │         49,537 │ stack1_block1_out[0][0… │
# │ (AttentionGate)             │                         │                │ decoder_stage5_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_concat       │ (None, 16, 16, 16, 384) │              0 │ decoder_stage4_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage4_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_conv… │ (None, 16, 16, 16, 128) │      1,327,104 │ decoder_stage4_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_1_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_conv… │ (None, 16, 16, 16, 128) │        442,368 │ decoder_stage4_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_norm… │ (None, 16, 16, 16, 128) │            512 │ decoder_stage4_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage4_conv_2_acti… │ (None, 16, 16, 16, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_upsampling_… │ (None, 32, 32, 32, 128) │              0 │ decoder_stage4_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_attention_g… │ (None, 32, 32, 32, 64)  │         12,481 │ stack0_block1_out[0][0… │
# │ (AttentionGate)             │                         │                │ decoder_stage4_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_concat       │ (None, 32, 32, 32, 192) │              0 │ decoder_stage3_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage3_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_conv… │ (None, 32, 32, 32, 64)  │        331,776 │ decoder_stage3_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_1_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_conv… │ (None, 32, 32, 32, 64)  │        110,592 │ decoder_stage3_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_norm… │ (None, 32, 32, 32, 64)  │            256 │ decoder_stage3_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage3_conv_2_acti… │ (None, 32, 32, 32, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_upsampling_… │ (None, 64, 64, 64, 64)  │              0 │ decoder_stage3_conv_2_… │
# │ (UpSampling3D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_attention_g… │ (None, 64, 64, 64, 64)  │          4,193 │ conv1_relu[0][0],       │
# │ (AttentionGate)             │                         │                │ decoder_stage3_conv_2_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_concat       │ (None, 64, 64, 64, 128) │              0 │ decoder_stage2_upsampl… │
# │ (Concatenate)               │                         │                │ decoder_stage2_attenti… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_conv… │ (None, 64, 64, 64, 32)  │        110,592 │ decoder_stage2_concat[… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_1_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_1_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_1_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_conv… │ (None, 64, 64, 64, 32)  │         27,648 │ decoder_stage2_conv_1_… │
# │ (Conv3D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_norm… │ (None, 64, 64, 64, 32)  │            128 │ decoder_stage2_conv_2_… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage2_conv_2_acti… │ (None, 64, 64, 64, 32)  │              0 │ decoder_stage2_conv_2_… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_upsampling_… │ (None, 128, 128, 128,   │              0 │ decoder_stage2_conv_2_… │
# │ (UpSampling3D)              │ 32)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_conv… │ (None, 128, 128, 128,   │         13,824 │ decoder_stage1_upsampl… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_1_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_1_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_1_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_conv… │ (None, 128, 128, 128,   │          6,912 │ decoder_stage1_conv_1_… │
# │ (Conv3D)                    │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_norm… │ (None, 128, 128, 128,   │             64 │ decoder_stage1_conv_2_… │
# │ (BatchNormalization)        │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ decoder_stage1_conv_2_acti… │ (None, 128, 128, 128,   │              0 │ decoder_stage1_conv_2_… │
# │ (ReLU)                      │ 16)                     │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3d_12 (Conv3D)          │ (None, 128, 128, 128,   │             17 │ decoder_stage1_conv_2_… │
# │                             │ 1)                      │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ predictions (Activation)    │ (None, 128, 128, 128,   │              0 │ conv3d_12[0][0]         │
# │                             │ 1)                      │                │                         │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 42,885,877 (163.60 MB)
#  Trainable params: 42,874,293 (163.55 MB)
#  Non-trainable params: 11,584 (45.25 KB)

# %%
def warmup_cosine_lr(epoch, current_lr):
    if epoch < WARMUP_EPOCHS:
        return MIN_LR + (LEARNING_RATE - MIN_LR) * (epoch / WARMUP_EPOCHS)
    progress = (epoch - WARMUP_EPOCHS) / max(EPOCHS - WARMUP_EPOCHS, 1)
    return MIN_LR + 0.5 * (LEARNING_RATE - MIN_LR) * (1 + math.cos(math.pi * progress))

for e in [0, 10, 50, 100, 199]:
    print(f"Epoch {e:>3d}  LR = {warmup_cosine_lr(e, None):.2e}")
# Out:
# Epoch   0  LR = 1.00e-06
# Epoch  10  LR = 3.00e-04
# Epoch  50  LR = 2.68e-04
# Epoch 100  LR = 1.63e-04
# Epoch 199  LR = 1.02e-06

# %%
model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=MIN_LR,
        weight_decay=WEIGHT_DECAY,
    ),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

callbacks = [
    keras.callbacks.LearningRateScheduler(warmup_cosine_lr, verbose=0),
    keras.callbacks.ModelCheckpoint(
        filepath=str(OUT_DIR / "best_model.keras"),
        monitor="val_binary_dice_metric", mode="max",
        save_best_only=True, verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_binary_dice_metric", mode="max",
        patience=50, restore_best_weights=True, verbose=1,
    ),
    keras.callbacks.CSVLogger(str(OUT_DIR / "training_log.csv")),
]

print("Compiled")
# Out:
# Compiled

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

print(f"\nBest val Dice: {max(history.history.get('val_binary_dice_metric', [0])):.4f}")
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - binary_dice_score: 0.5760 - loss: 1.3916 - val_binary_dice_score: 0.6507 - val_loss: 1.1992 - learning_rate: 1.0000e-06
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.5682 - loss: 1.3189 - val_binary_dice_score: 0.6445 - val_loss: 1.1959 - learning_rate: 3.0900e-05
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7107 - loss: 1.0565 - val_binary_dice_score: 0.7362 - val_loss: 0.9308 - learning_rate: 6.0800e-05
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7338 - loss: 0.9776 - val_binary_dice_score: 0.1254 - val_loss: 1.4271 - learning_rate: 9.0700e-05
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.6616 - loss: 1.1418 - val_binary_dice_score: 0.7693 - val_loss: 1.0641 - learning_rate: 1.2060e-04
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7910 - loss: 0.8202 - val_binary_dice_score: 0.7858 - val_loss: 0.9703 - learning_rate: 1.5050e-04
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - binary_dice_score: 0.7077 - loss: 0.9841 - val_binary_dice_score: 0.4886 - val_loss: 1.2922 - learning_rate: 1.8040e-04
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7260 - loss: 0.8962 - val_binary_dice_score: 0.0192 - val_loss: 2.2954 - learning_rate: 2.1030e-04
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7987 - loss: 0.7787 - val_binary_dice_score: 0.0014 - val_loss: 1.5024 - learning_rate: 2.4020e-04
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.7506 - loss: 0.8828 - val_binary_dice_score: 0.0070 - val_loss: 4.5951 - learning_rate: 2.7010e-04
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0
200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8535 - loss: 0.5042 - val_binary_dice_score: 0.8634 - val_loss: 0.4967 - learning_rate: 2.4806e-04
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8574 - loss: 0.5203 - val_binary_dice_score: 0.8909 - val_loss: 0.3963 - learning_rate: 2.4618e-04
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8353 - loss: 0.5642 - val_binary_dice_score: 0.9019 - val_loss: 0.3850 - learning_rate: 2.4426e-04
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8016 - loss: 0.6586 - val_binary_dice_score: 0.8874 - val_loss: 0.4735 - learning_rate: 2.4232e-04
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8157 - loss: 0.6471 - val_binary_dice_score: 0.8695 - val_loss: 0.5232 - learning_rate: 2.4036e-04
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8497 - loss: 0.5127 - val_binary_dice_score: 1.2275e-04 - val_loss: 2.5111 - learning_rate: 2.3837e-04
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8607 - loss: 0.4785 - val_binary_dice_score: 1.5636e-13 - val_loss: 2.3202 - learning_rate: 2.3636e-04
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8194 - loss: 0.6396 - val_binary_dice_score: 0.8785 - val_loss: 0.4612 - learning_rate: 2.3433e-04
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8072 - loss: 0.6902 - val_binary_dice_score: 0.6895 - val_loss: 0.8124 - learning_rate: 2.3227e-04
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8280 - loss: 0.5775 - val_binary_dice_score: 0.8262 - val_loss: 0.6736 - learning_rate: 2.3019e-04
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7940 - loss: 0.6369 - val_binary_dice_score: 0.8108 - val_loss: 0.6508 - learning_rate: 2.2809e-04
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8386 - loss: 0.6003 - val_binary_dice_score: 0.0025 - val_loss: 2.0765 - learning_rate: 2.2596e-04
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8212 - loss: 0.5882 - val_binary_dice_score: 0.0213 - val_loss: 2.1799 - learning_rate: 2.2382e-04
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7481 - loss: 0.7773 - val_binary_dice_score: 0.8774 - val_loss: 0.4687 - learning_rate: 2.2165e-04
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8367 - loss: 0.5308 - val_binary_dice_score: 0.5086 - val_loss: 0.9673 - learning_rate: 2.1947e-04
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8165 - loss: 0.5936 - val_binary_dice_score: 0.8608 - val_loss: 0.5241 - learning_rate: 2.1727e-04
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8087 - loss: 0.6223 - val_binary_dice_score: 0.8528 - val_loss: 0.6616 - learning_rate: 2.1505e-04
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8628 - loss: 0.5433 - val_binary_dice_score: 0.8495 - val_loss: 0.4805 - learning_rate: 2.1281e-04
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8159 - loss: 0.6505 - val_binary_dice_score: 0.9102 - val_loss: 0.3563 - learning_rate: 2.1055e-04
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.7993 - loss: 0.6241 - val_binary_dice_score: 0.8510 - val_loss: 0.5773 - learning_rate: 2.0828e-04
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8652 - loss: 0.4771 - val_binary_dice_score: 0.3418 - val_loss: 1.5762 - learning_rate: 2.0599e-04
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8424 - loss: 0.5164 - val_binary_dice_score: 0.8946 - val_loss: 0.3747 - learning_rate: 2.0369e-04
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8452 - loss: 0.5280 - val_binary_dice_score: 0.8610 - val_loss: 0.5048 - learning_rate: 2.0137e-04
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8277 - loss: 0.5832 - val_binary_dice_score: 0.8398 - val_loss: 0.5766 - learning_rate: 1.9904e-04
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8352 - loss: 0.5426 - val_binary_dice_score: 0.3130 - val_loss: 1.6469 - learning_rate: 1.9670e-04
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8546 - loss: 0.5689 - val_binary_dice_score: 0.8446 - val_loss: 0.6631 - learning_rate: 1.9434e-04
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8188 - loss: 0.5405 - val_binary_dice_score: 0.7693 - val_loss: 0.6790 - learning_rate: 1.9197e-04
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8933 - loss: 0.3830 - val_binary_dice_score: 0.0370 - val_loss: 2.0989 - learning_rate: 1.8959e-04
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8538 - loss: 0.5157 - val_binary_dice_score: 0.8702 - val_loss: 0.4791 - learning_rate: 1.8720e-04
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8517 - loss: 0.5344 - val_binary_dice_score: 0.4757 - val_loss: 1.1044 - learning_rate: 1.8480e-04
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8307 - loss: 0.5411 - val_binary_dice_score: 0.9031 - val_loss: 0.3469 - learning_rate: 1.8239e-04
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8423 - loss: 0.5209 - val_binary_dice_score: 1.3296e-13 - val_loss: 2.7695 - learning_rate: 1.7997e-04
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8100 - loss: 0.7334 - val_binary_dice_score: 0.8565 - val_loss: 0.4772 - learning_rate: 1.7754e-04
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8531 - loss: 0.5131 - val_binary_dice_score: 0.0645 - val_loss: 1.7238 - learning_rate: 1.7511e-04
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8624 - loss: 0.5409 - val_binary_dice_score: 0.8964 - val_loss: 0.4135 - learning_rate: 1.7267e-04
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.7946 - loss: 0.7239 - val_binary_dice_score: 0.8638 - val_loss: 0.4569 - learning_rate: 1.7022e-04
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8590 - loss: 0.5073 - val_binary_dice_score: 0.8958 - val_loss: 0.3904 - learning_rate: 1.6776e-04
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8367 - loss: 0.5358 - val_binary_dice_score: 0.8771 - val_loss: 0.4636 - learning_rate: 1.6531e-04
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8666 - loss: 0.4583 - val_binary_dice_score: 0.9072 - val_loss: 0.3519 - learning_rate: 1.6285e-04
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8476 - loss: 0.5235 - val_binary_dice_score: 0.4374 - val_loss: 1.1865 - learning_rate: 1.6038e-04
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8870 - loss: 0.4578 - val_binary_dice_score: 0.8837 - val_loss: 0.4352 - learning_rate: 1.5791e-04
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8885 - loss: 0.3906 - val_binary_dice_score: 0.8701 - val_loss: 0.4515 - learning_rate: 1.5544e-04
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8616 - loss: 0.4760 - val_binary_dice_score: 0.8742 - val_loss: 0.4524 - learning_rate: 1.5297e-04
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8349 - loss: 0.5461 - val_binary_dice_score: 0.8606 - val_loss: 0.4577 - learning_rate: 1.5050e-04
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8257 - loss: 0.5511 - val_binary_dice_score: 0.8540 - val_loss: 0.4812 - learning_rate: 1.4803e-04
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8424 - loss: 0.5169 - val_binary_dice_score: 0.8919 - val_loss: 0.4163 - learning_rate: 1.4556e-04
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8731 - loss: 0.4850 - val_binary_dice_score: 0.8497 - val_loss: 0.5699 - learning_rate: 1.4309e-04
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8596 - loss: 0.5020 - val_binary_dice_score: 0.8511 - val_loss: 0.5044 - learning_rate: 1.4062e-04
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8759 - loss: 0.4165 - val_binary_dice_score: 0.8665 - val_loss: 0.5041 - learning_rate: 1.3815e-04
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8822 - loss: 0.4299 - val_binary_dice_score: 0.8275 - val_loss: 0.6445 - learning_rate: 1.3569e-04
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8922 - loss: 0.4308 - val_binary_dice_score: 0.8904 - val_loss: 0.4202 - learning_rate: 1.3324e-04
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8539 - loss: 0.4863 - val_binary_dice_score: 0.8771 - val_loss: 0.4532 - learning_rate: 1.3078e-04
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8652 - loss: 0.4966 - val_binary_dice_score: 0.8855 - val_loss: 0.4205 - learning_rate: 1.2833e-04
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8187 - loss: 0.6097 - val_binary_dice_score: 0.8694 - val_loss: 0.4437 - learning_rate: 1.2589e-04
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8368 - loss: 0.5044 - val_binary_dice_score: 0.7985 - val_loss: 0.6168 - learning_rate: 1.2346e-04
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8778 - loss: 0.4208 - val_binary_dice_score: 0.8641 - val_loss: 0.4512 - learning_rate: 1.2103e-04
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8664 - loss: 0.4724 - val_binary_dice_score: 0.9197 - val_loss: 0.3359 - learning_rate: 1.1861e-04
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8655 - loss: 0.4855 - val_binary_dice_score: 0.8870 - val_loss: 0.4013 - learning_rate: 1.1620e-04
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8156 - loss: 0.6193 - val_binary_dice_score: 0.9052 - val_loss: 0.3684 - learning_rate: 1.1380e-04
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8876 - loss: 0.4125 - val_binary_dice_score: 0.8824 - val_loss: 0.4428 - learning_rate: 1.1141e-04
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8727 - loss: 0.4458 - val_binary_dice_score: 0.7351 - val_loss: 0.7936 - learning_rate: 1.0903e-04
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8469 - loss: 0.5431 - val_binary_dice_score: 0.9052 - val_loss: 0.3511 - learning_rate: 1.0666e-04
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8863 - loss: 0.3837 - val_binary_dice_score: 0.9271 - val_loss: 0.3080 - learning_rate: 1.0430e-04
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8740 - loss: 0.4108 - val_binary_dice_score: 0.8766 - val_loss: 0.4487 - learning_rate: 1.0196e-04
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8959 - loss: 0.3817 - val_binary_dice_score: 0.8924 - val_loss: 0.3857 - learning_rate: 9.9626e-05
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8619 - loss: 0.5402 - val_binary_dice_score: 0.9295 - val_loss: 0.2827 - learning_rate: 9.7309e-05
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8676 - loss: 0.4661 - val_binary_dice_score: 0.1129 - val_loss: 1.9921 - learning_rate: 9.5006e-05
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8268 - loss: 0.6413 - val_binary_dice_score: 0.8622 - val_loss: 0.5306 - learning_rate: 9.2718e-05
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8370 - loss: 0.5384 - val_binary_dice_score: 0.8398 - val_loss: 0.5957 - learning_rate: 9.0447e-05
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8633 - loss: 0.4908 - val_binary_dice_score: 0.7658 - val_loss: 0.7598 - learning_rate: 8.8191e-05
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.
200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8606 - loss: 0.4797 - val_binary_dice_score: 0.9419 - val_loss: 0.2751 - learning_rate: 4.0509e-05
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8882 - loss: 0.3925 - val_binary_dice_score: 0.8959 - val_loss: 0.3943 - learning_rate: 3.8850e-05
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8612 - loss: 0.4792 - val_binary_dice_score: 0.9233 - val_loss: 0.3126 - learning_rate: 3.7222e-05
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8293 - loss: 0.5271 - val_binary_dice_score: 0.9122 - val_loss: 0.3324 - learning_rate: 3.5624e-05
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8595 - loss: 0.4673 - val_binary_dice_score: 0.9501 - val_loss: 0.2214 - learning_rate: 3.4058e-05
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9045 - loss: 0.3460 - val_binary_dice_score: 0.9226 - val_loss: 0.3186 - learning_rate: 3.2523e-05
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8908 - loss: 0.3652 - val_binary_dice_score: 0.9138 - val_loss: 0.3396 - learning_rate: 3.1021e-05
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8742 - loss: 0.4632 - val_binary_dice_score: 0.9015 - val_loss: 0.3577 - learning_rate: 2.9552e-05
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9003 - loss: 0.3896 - val_binary_dice_score: 0.9045 - val_loss: 0.3624 - learning_rate: 2.8116e-05
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9149 - loss: 0.3252 - val_binary_dice_score: 0.9256 - val_loss: 0.2942 - learning_rate: 2.6713e-05
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9118 - loss: 0.3376 - val_binary_dice_score: 0.9319 - val_loss: 0.2485 - learning_rate: 2.5344e-05
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9095 - loss: 0.3215 - val_binary_dice_score: 0.8728 - val_loss: 0.4487 - learning_rate: 2.4009e-05
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8789 - loss: 0.4175 - val_binary_dice_score: 0.9420 - val_loss: 0.2582 - learning_rate: 2.2708e-05
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.9117 - loss: 0.3389 - val_binary_dice_score: 0.9083 - val_loss: 0.3213 - learning_rate: 2.1443e-05
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9142 - loss: 0.3728 - val_binary_dice_score: 0.9594 - val_loss: 0.1725 - learning_rate: 2.0213e-05
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8853 - loss: 0.4668 - val_binary_dice_score: 0.8807 - val_loss: 0.4699 - learning_rate: 1.9019e-05
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8621 - loss: 0.4812 - val_binary_dice_score: 0.8966 - val_loss: 0.3547 - learning_rate: 1.7860e-05
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8703 - loss: 0.4707 - val_binary_dice_score: 0.8918 - val_loss: 0.4080 - learning_rate: 1.6738e-05
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8902 - loss: 0.3981 - val_binary_dice_score: 0.8685 - val_loss: 0.3805 - learning_rate: 1.5652e-05
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9070 - loss: 0.3854 - val_binary_dice_score: 0.8883 - val_loss: 0.4051 - learning_rate: 1.4604e-05
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8480 - loss: 0.5146 - val_binary_dice_score: 0.8867 - val_loss: 0.4445 - learning_rate: 1.3592e-05
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8029 - loss: 0.6201 - val_binary_dice_score: 0.9236 - val_loss: 0.3025 - learning_rate: 1.2618e-05
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8899 - loss: 0.4081 - val_binary_dice_score: 0.9163 - val_loss: 0.2933 - learning_rate: 1.1681e-05
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8781 - loss: 0.4238 - val_binary_dice_score: 0.9218 - val_loss: 0.3210 - learning_rate: 1.0783e-05
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8878 - loss: 0.3704 - val_binary_dice_score: 0.9458 - val_loss: 0.2483 - learning_rate: 9.9223e-06
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8256 - loss: 0.5629 - val_binary_dice_score: 0.9326 - val_loss: 0.2913 - learning_rate: 9.1003e-06
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8700 - loss: 0.4621 - val_binary_dice_score: 0.9170 - val_loss: 0.3146 - learning_rate: 8.3171e-06
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8968 - loss: 0.3855 - val_binary_dice_score: 0.9386 - val_loss: 0.2611 - learning_rate: 7.5727e-06
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8831 - loss: 0.4080 - val_binary_dice_score: 0.9268 - val_loss: 0.2855 - learning_rate: 6.8673e-06
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8781 - loss: 0.4564 - val_binary_dice_score: 0.9302 - val_loss: 0.2705 - learning_rate: 6.2013e-06
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8969 - loss: 0.3763 - val_binary_dice_score: 0.9006 - val_loss: 0.3720 - learning_rate: 5.5747e-06
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9011 - loss: 0.3471 - val_binary_dice_score: 0.9198 - val_loss: 0.3112 - learning_rate: 4.9877e-06
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8962 - loss: 0.3570 - val_binary_dice_score: 0.9170 - val_loss: 0.3534 - learning_rate: 4.4405e-06
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8689 - loss: 0.4359 - val_binary_dice_score: 0.9479 - val_loss: 0.2048 - learning_rate: 3.9332e-06
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8826 - loss: 0.4111 - val_binary_dice_score: 0.9062 - val_loss: 0.3409 - learning_rate: 3.4660e-06
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8698 - loss: 0.4634 - val_binary_dice_score: 0.9355 - val_loss: 0.2741 - learning_rate: 3.0390e-06
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - binary_dice_score: 0.8855 - loss: 0.4510 - val_binary_dice_score: 0.9358 - val_loss: 0.2686 - learning_rate: 2.6523e-06
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8838 - loss: 0.4228 - val_binary_dice_score: 0.9237 - val_loss: 0.3076 - learning_rate: 2.3060e-06
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8970 - loss: 0.3870 - val_binary_dice_score: 0.9270 - val_loss: 0.2625 - learning_rate: 2.0003e-06
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8873 - loss: 0.3936 - val_binary_dice_score: 0.9268 - val_loss: 0.3166 - learning_rate: 1.7351e-06
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8946 - loss: 0.3698 - val_binary_dice_score: 0.8941 - val_loss: 0.3576 - learning_rate: 1.5106e-06
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.9041 - loss: 0.3433 - val_binary_dice_score: 0.9303 - val_loss: 0.2791 - learning_rate: 1.3269e-06
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8660 - loss: 0.4572 - val_binary_dice_score: 0.9269 - val_loss: 0.3042 - learning_rate: 1.1839e-06
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - binary_dice_score: 0.8606 - loss: 0.4997 - val_binary_dice_score: 0.9408 - val_loss: 0.2291 - learning_rate: 1.0817e-06
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - binary_dice_score: 0.8900 - loss: 0.4330 - val_binary_dice_score: 0.9358 - val_loss: 0.2782 - learning_rate: 1.0204e-06
#
# Best val Dice: 0.0000

# %%
metric_key = [k for k in history.history.keys() if "dice" in k and "val" not in k][0]
val_metric_key = [k for k in history.history.keys() if "dice" in k and "val" in k][0]

fig, axes = plt.subplots(1, 3, figsize=(18, 4))

axes[0].plot(history.history["loss"],     label="Train", alpha=0.8)
axes[0].plot(history.history["val_loss"], label="Val", alpha=0.8)
axes[0].set_title("Loss"); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history[metric_key],     label="Train", alpha=0.8)
axes[1].plot(history.history[val_metric_key], label="Val", alpha=0.8)
axes[1].axhline(y=0.90, color='red', linestyle='--', alpha=0.5, label='Target')
axes[1].set_title("Dice"); axes[1].set_ylim(0, 1)
axes[1].legend(); axes[1].grid(alpha=0.3)

n = len(history.history["loss"])
axes[2].plot([warmup_cosine_lr(e, None) for e in range(n)])
axes[2].set_title("LR"); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(str(OUT_DIR / "training_curves.png"), dpi=150)
plt.show()

final_train = history.history[metric_key][-1]
final_val   = history.history[val_metric_key][-1]
print(f"Train Dice: {final_train:.4f}  Val Dice: {final_val:.4f}  Gap: {final_train - final_val:.4f}")
# Out:
# Train Dice: 0.8822  Val Dice: 0.9358  Gap: -0.0536

# %%
from medicai.utils.inference import SlidingWindowInference

def predict_volume(model, image_path, label_path):
    data, meta = load_pair(image_path, label_path)
    pre = Compose([
        ScaleIntensityRange(
            keys=["image"], a_min=HU_MIN, a_max=HU_MAX,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForeground(keys=("image", "label"), source_key="image"),
    ])
    out = pre(data, meta)
    ct = out["image"]
    gt = out["label"]
    if hasattr(ct, "numpy"): ct = ct.numpy()
    if hasattr(gt, "numpy"): gt = gt.numpy()

    swi = SlidingWindowInference(
        model=model, num_classes=1, roi_size=CROP_SHAPE,
        sw_batch_size=2, overlap=0.5, mode='gaussian',
    )
    pred     = np.array(swi(ct[np.newaxis]))[0]
    pred_bin = (1.0 / (1.0 + np.exp(-pred)) > 0.5).astype(np.float32)
    inter    = (pred_bin * gt).sum()
    dice     = float(2.0 * inter / (pred_bin.sum() + gt.sum() + 1e-6))
    return ct, gt, pred_bin, dice

# %%
best_model = keras.models.load_model(
    str(OUT_DIR / "best_model.keras"),
    custom_objects={
        "BinaryDiceCELoss": BinaryDiceCELoss,
        "BinaryDiceMetric": BinaryDiceMetric,
    },
    compile=False,
)
best_model.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=MIN_LR, weight_decay=WEIGHT_DECAY),
    loss=BinaryDiceCELoss(from_logits=True, num_classes=1),
    metrics=[BinaryDiceMetric(from_logits=True, num_classes=1)],
)

results = []
for p in val_pairs:
    _, _, _, dice = predict_volume(best_model, p["image"], p["label"])
    results.append({"scan_id": p["scan_id"], "dice": dice})
    print(f"  {p['scan_id']}  Dice={dice:.4f}")

dices = [r["dice"] for r in results]
print(f"\nMean={np.mean(dices):.4f}  Std={np.std(dices):.4f}  Min={np.min(dices):.4f}  Max={np.max(dices):.4f}")
# Out:
# Total patch 48: 100%|██████████| 24/24 [00:09<00:00,  2.65it/s]
#   be9fa3df918a  Dice=0.9076
# Total patch 48: 100%|██████████| 24/24 [00:08<00:00,  2.75it/s]
#   092c97ecec4b  Dice=0.8774
# Total patch 75: 100%|██████████| 38/38 [00:13<00:00,  2.74it/s]
#   ed66d74f6692  Dice=0.8863
# Total patch 48: 100%|██████████| 24/24 [00:08<00:00,  2.77it/s]
#   d86566fdb41c  Dice=0.9111
# Total patch 27: 100%|██████████| 14/14 [00:05<00:00,  2.77it/s]
#   2eb903f4f204  Dice=0.9046
# Total patch 32: 100%|██████████| 16/16 [00:05<00:00,  2.77it/s]
#   4d9723eef946  Dice=0.8758
# Total patch 75: 100%|██████████| 38/38 [00:13<00:00,  2.80it/s]
#   43ca4b1f6495  Dice=0.8899
# Total patch 32: 100%|██████████| 16/16 [00:05<00:00,  2.77it/s]
#   8781c0349102  Dice=0.7730
#
# Mean=0.8782  Std=0.0417  Min=0.7730  Max=0.9111

# %%
def visualise(ct, gt, pred, scan_id, dice, n_slices=6):
    D = ct.shape[0]
    idxs = np.linspace(D // 4, 3 * D // 4, n_slices, dtype=int)
    fig, axes = plt.subplots(3, n_slices, figsize=(3 * n_slices, 9))
    fig.suptitle(f"{scan_id}  Dice={dice:.4f}", fontsize=13, fontweight="bold")
    for col, idx in enumerate(idxs):
        s, g, p = ct[idx,:,:,0], gt[idx,:,:,0], pred[idx,:,:,0]
        axes[0,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[0,col].set_title(f"CT z={idx}", fontsize=8); axes[0,col].axis("off")
        axes[1,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[1,col].imshow(g, cmap="Reds",  alpha=0.45)
        axes[1,col].set_title("GT", fontsize=8); axes[1,col].axis("off")
        axes[2,col].imshow(s, cmap="gray", vmin=0, vmax=1)
        axes[2,col].imshow(p, cmap="Blues", alpha=0.45)
        axes[2,col].set_title("Pred", fontsize=8); axes[2,col].axis("off")
    plt.tight_layout()
    plt.savefig(str(OUT_DIR / f"{scan_id}_pred.png"), dpi=150, bbox_inches="tight")
    plt.show()

for res in [max(results, key=lambda r: r["dice"]), min(results, key=lambda r: r["dice"])]:
    p = next(x for x in val_pairs if x["scan_id"] == res["scan_id"])
    ct, gt, pred, dice = predict_volume(best_model, p["image"], p["label"])
    visualise(ct, gt, pred, res["scan_id"], dice)
# Out:
# Total patch 48: 100%|██████████| 24/24 [00:08<00:00,  2.78it/s]
# Total patch 32: 100%|██████████| 16/16 [00:05<00:00,  2.73it/s]

# %%
stats = {
    "model":         "UNet_resnet18",
    "backend":       keras.config.backend(),
    "mean_dice":     round(float(np.mean(dices)), 4),
    "std_dice":      round(float(np.std(dices)),  4),
    "n_train":       len(train_pairs),
    "n_val":         len(val_pairs),
    "crop_shape":    list(CROP_SHAPE),
    "hu_window":     [HU_MIN, HU_MAX],
    "epochs_trained": len(history.history["loss"]),
    "best_val_dice": round(float(max(history.history.get("val_binary_dice_metric", [0]))), 4),
    "total_params":  model.count_params(),
    "weight_decay":  WEIGHT_DECAY,
    "num_samples":   NUM_SAMPLES,
    "per_scan":      results,
}
with open(OUT_DIR / "eval_stats.json", "w") as f:
    json.dump(stats, f, indent=2)
print(json.dumps({k: v for k, v in stats.items() if k != "per_scan"}, indent=2))
# Out:
# {
#   "model": "UNet_resnet18",
#   "backend": "torch",
#   "mean_dice": 0.8782,
#   "std_dice": 0.0417,
#   "n_train": 39,
#   "n_val": 8,
#   "crop_shape": [
#     128,
#     128,
#     128
#   ],
#   "hu_window": [
#     -175,
#     400
#   ],
#   "epochs_trained": 200,
#   "best_val_dice": 0.0,
#   "total_params": 42885877,
#   "weight_decay": 0.0005,
#   "num_samples": 1
# }
